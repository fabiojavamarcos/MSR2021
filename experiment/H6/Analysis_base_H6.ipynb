# %%
import pandas as pd
import numpy as np
import csv 
import matplotlib.pyplot as plt
import seaborn as sns


#https://altair-viz.github.io/gallery/errorbars_with_std.html
import altair as alt
from vega_datasets import data

#defining paths
allAlgorithms_unigram_900terms = './boxplotH6.csv'
#classifierChain = './experiment/dfTesteClassifierChain_13Labels.csv'


dataBinary = pd.read_csv(allAlgorithms_unigram_900terms)
#dataClassifier = pd.read_csv(classifierChain)

# %%
dataBinary
# Out:
#    date_time  tf-IDF  #_TopTerms Stop_Word  Train/Test_Size  \
# 0    07:16.5  (1, 1)         900       Yes              0.2
# 1    07:16.8  (1, 1)         900       Yes              0.2
# 2    07:17.1  (1, 1)         900       Yes              0.2
# 3    07:17.3  (1, 1)         900       Yes              0.2
# 4    07:17.6  (1, 1)         900       Yes              0.2
# 5    07:17.9  (1, 1)         900       Yes              0.2
# 6    07:18.2  (1, 1)         900       Yes              0.2
# 7    07:18.5  (1, 1)         900       Yes              0.2
# 8    07:18.8  (1, 1)         900       Yes              0.2
# 9    07:19.1  (1, 1)         900       Yes              0.2
# 10   07:20.5  (1, 1)         900       Yes              0.2
# 11   07:20.6  (1, 1)         900       Yes              0.2
# 12   07:20.8  (1, 1)         900       Yes              0.2
# 13   07:20.9  (1, 1)         900       Yes              0.2
# 14   07:21.1  (1, 1)         900       Yes              0.2
# 15   07:21.2  (1, 1)         900       Yes              0.2
# 16   07:21.4  (1, 1)         900       Yes              0.2
# 17   07:21.5  (1, 1)         900       Yes              0.2
# 18   07:21.7  (1, 1)         900       Yes              0.2
# 19   07:21.8  (1, 1)         900       Yes              0.2
# 20   07:27.0  (1, 1)         900       Yes              0.2
# 21   07:30.6  (1, 1)         900       Yes              0.2
# 22   07:34.8  (1, 1)         900       Yes              0.2
# 23   07:38.5  (1, 1)         900       Yes              0.2
# 24   07:43.8  (1, 1)         900       Yes              0.2
# 25   07:48.7  (1, 1)         900       Yes              0.2
# 26   07:52.2  (1, 1)         900       Yes              0.2
# 27   07:56.2  (1, 1)         900       Yes              0.2
# 28   08:01.0  (1, 1)         900       Yes              0.2
# 29   08:05.1  (1, 1)         900       Yes              0.2
# 30   08:09.4  (1, 1)         900       Yes              0.2
# 31   08:12.7  (1, 1)         900       Yes              0.2
# 32   08:15.8  (1, 1)         900       Yes              0.2
# 33   08:19.0  (1, 1)         900       Yes              0.2
# 34   08:22.5  (1, 1)         900       Yes              0.2
# 35   08:25.8  (1, 1)         900       Yes              0.2
# 36   08:28.8  (1, 1)         900       Yes              0.2
# 37   08:31.9  (1, 1)         900       Yes              0.2
# 38   08:34.7  (1, 1)         900       Yes              0.2
# 39   08:37.7  (1, 1)         900       Yes              0.2
# 40   58:19.9  (1, 1)         900       Yes              0.2
# 41   58:21.2  (1, 1)         900       Yes              0.2
# 42   58:22.6  (1, 1)         900       Yes              0.2
# 43   58:24.0  (1, 1)         900       Yes              0.2
# 44   58:25.3  (1, 1)         900       Yes              0.2
# 45   58:26.7  (1, 1)         900       Yes              0.2
# 46   58:28.1  (1, 1)         900       Yes              0.2
# 47   58:29.4  (1, 1)         900       Yes              0.2
# 48   58:30.9  (1, 1)         900       Yes              0.2
# 49   58:32.2  (1, 1)         900       Yes              0.2
#
#              Algorithm  Accuracy_Score  Accuracy_Score_not_normalized  \
# 0         DecisionTree        0.147887                             21
# 1         DecisionTree        0.070423                             10
# 2         DecisionTree        0.063380                              9
# 3         DecisionTree        0.063380                              9
# 4         DecisionTree        0.112676                             16
# 5         DecisionTree        0.098592                             14
# 6         DecisionTree        0.098592                             14
# 7         DecisionTree        0.091549                             13
# 8         DecisionTree        0.091549                             13
# 9         DecisionTree        0.091549                             13
# 10  LogisticRegression        0.091549                             13
# 11  LogisticRegression        0.084507                             12
# 12  LogisticRegression        0.077465                             11
# 13  LogisticRegression        0.112676                             16
# 14  LogisticRegression        0.084507                             12
# 15  LogisticRegression        0.105634                             15
# 16  LogisticRegression        0.098592                             14
# 17  LogisticRegression        0.098592                             14
# 18  LogisticRegression        0.070423                             10
# 19  LogisticRegression        0.049296                              7
# 20       MLPClassifier        0.084507                             12
# 21       MLPClassifier        0.049296                              7
# 22       MLPClassifier        0.014085                              2
# 23       MLPClassifier        0.098592                             14
# 24       MLPClassifier        0.000000                              0
# 25       MLPClassifier        0.000000                              0
# 26       MLPClassifier        0.049296                              7
# 27       MLPClassifier        0.007042                              1
# 28       MLPClassifier        0.000000                              0
# 29       MLPClassifier        0.000000                              0
# 30               MLkNN        0.077465                             11
# 31               MLkNN        0.091549                             13
# 32               MLkNN        0.028169                              4
# 33               MLkNN        0.077465                             11
# 34               MLkNN        0.056338                              8
# 35               MLkNN        0.070423                             10
# 36               MLkNN        0.070423                             10
# 37               MLkNN        0.056338                              8
# 38               MLkNN        0.084507                             12
# 39               MLkNN        0.035211                              5
# 40        RandomForest        0.161972                             23
# 41        RandomForest        0.091549                             13
# 42        RandomForest        0.091549                             13
# 43        RandomForest        0.112676                             16
# 44        RandomForest        0.154930                             22
# 45        RandomForest        0.133803                             19
# 46        RandomForest        0.105634                             15
# 47        RandomForest        0.105634                             15
# 48        RandomForest        0.105634                             15
# 49        RandomForest        0.112676                             16
#
#     zero_one_loss    AUC-PR  hamming_loss_avg  Jaccard_samples  Jaccard_macro  \
# 0        0.852113  0.501143          0.190141         0.476056       0.455462
# 1        0.929577  0.436159          0.214789         0.389783       0.390000
# 2        0.936620  0.440612          0.216549         0.412218       0.404839
# 3        0.936620  0.448869          0.217136         0.407917       0.403226
# 4        0.887324  0.492742          0.198944         0.440334       0.436877
# 5        0.901408  0.450693          0.211854         0.413433       0.405272
# 6        0.901408  0.490053          0.200117         0.452213       0.438221
# 7        0.908451  0.410404          0.223005         0.385837       0.370861
# 8        0.908451  0.438822          0.208920         0.395858       0.397631
# 9        0.908451  0.430847          0.194249         0.411762       0.406810
# 10       0.908451  0.734796          0.164319         0.498837       0.492754
# 11       0.915493  0.651650          0.176643         0.461150       0.459605
# 12       0.922535  0.686347          0.176643         0.459775       0.453721
# 13       0.887324  0.677634          0.178404         0.455284       0.454219
# 14       0.915493  0.721885          0.171948         0.491192       0.479574
# 15       0.894366  0.713049          0.169014         0.490613       0.474453
# 16       0.901408  0.714632          0.174883         0.487654       0.476274
# 17       0.901408  0.653360          0.183099         0.452294       0.435805
# 18       0.929577  0.679045          0.167840         0.478655       0.476190
# 19       0.950704  0.651376          0.172535         0.442656       0.448405
# 20       0.915493  0.653256          0.177817         0.497605       0.484694
# 21       0.950704  0.584444          0.189554         0.457227       0.453469
# 22       0.985915  0.573866          0.221244         0.391164       0.384992
# 23       0.901408  0.578740          0.186033         0.474807       0.466330
# 24       1.000000  0.542307          0.198944         0.375810       0.369888
# 25       1.000000  0.376955          0.309272         0.191764       0.208709
# 26       0.950704  0.590151          0.217136         0.359479       0.335727
# 27       0.992958  0.587576          0.225939         0.432093       0.437135
# 28       1.000000  0.489204          0.274061         0.348172       0.355862
# 29       1.000000  0.312187          0.302817         0.113783       0.128378
# 30       0.922535  0.590516          0.207746         0.413034       0.397959
# 31       0.908451  0.558571          0.212441         0.381657       0.374784
# 32       0.971831  0.544988          0.234742         0.341952       0.332220
# 33       0.922535  0.571414          0.218897         0.389819       0.386513
# 34       0.943662  0.610901          0.216549         0.397773       0.387043
# 35       0.929577  0.571433          0.211268         0.409381       0.404959
# 36       0.929577  0.605762          0.214789         0.420953       0.399015
# 37       0.943662  0.508139          0.235329         0.373692       0.365506
# 38       0.915493  0.568702          0.211854         0.409675       0.390203
# 39       0.964789  0.502585          0.223005         0.381070       0.375000
# 40       0.838028  0.726639          0.165493         0.517684       0.500000
# 41       0.908451  0.654757          0.183099         0.457070       0.450704
# 42       0.908451  0.660442          0.183685         0.465118       0.456597
# 43       0.887324  0.669685          0.181925         0.468195       0.464594
# 44       0.845070  0.708615          0.164906         0.513400       0.501773
# 45       0.866197  0.692722          0.167840         0.499444       0.489286
# 46       0.894366  0.688532          0.176643         0.489873       0.478336
# 47       0.894366  0.620070          0.186033         0.450808       0.446771
# 48       0.894366  0.667117          0.169014         0.472720       0.479204
# 49       0.887324  0.634557          0.167840         0.466080       0.465421
#
#     Precision    Recall  Fmeasure_Score  i Hypothesis
# 0    0.640662  0.611738        0.625866  0         H6
# 1    0.576355  0.546729        0.561151  1         H6
# 2    0.555310  0.599045        0.576349  2         H6
# 3    0.576037  0.573394        0.574713  3         H6
# 4    0.632212  0.585746        0.608092  4         H6
# 5    0.585714  0.568129        0.576788  5         H6
# 6    0.636364  0.584615        0.609393  6         H6
# 7    0.541063  0.541063        0.541063  7         H6
# 8    0.571776  0.566265        0.569007  8         H6
# 9    0.560494  0.597368        0.578344  9         H6
# 10   0.713911  0.613995        0.660194  0         H6
# 11   0.664935  0.598131        0.629766  1         H6
# 12   0.654450  0.596659        0.624220  2         H6
# 13   0.676471  0.580275        0.624691  3         H6
# 14   0.703125  0.601336        0.648259  4         H6
# 15   0.693333  0.600462        0.643564  5         H6
# 16   0.703896  0.595604        0.645238  6         H6
# 17   0.634211  0.582126        0.607053  7         H6
# 18   0.664962  0.626506        0.645161  8         H6
# 19   0.609694  0.628947        0.619171  9         H6
# 20   0.662791  0.643341        0.652921  0         H6
# 21   0.621810  0.626168        0.623981  1         H6
# 22   0.548837  0.563246        0.555948  2         H6
# 23   0.636782  0.635321        0.636051  3         H6
# 24   0.690972  0.443207        0.540027  4         H6
# 25   0.373656  0.321016        0.345342  5         H6
# 26   0.647059  0.410989        0.502688  6         H6
# 27   0.525483  0.722222        0.608342  7         H6
# 28   0.454225  0.621687        0.524924  8         H6
# 29   0.263889  0.200000        0.227545  9         H6
# 30   0.617414  0.528217        0.569343  0         H6
# 31   0.589674  0.507009        0.545226  1         H6
# 32   0.525066  0.474940        0.498747  2         H6
# 33   0.577396  0.538991        0.557533  3         H6
# 34   0.603627  0.518931        0.558084  4         H6
# 35   0.587530  0.565820        0.576471  5         H6
# 36   0.612091  0.534066        0.570423  6         H6
# 37   0.514477  0.557971        0.535342  7         H6
# 38   0.566176  0.556627        0.561361  8         H6
# 39   0.500000  0.600000        0.545455  9         H6
# 40   0.699752  0.636569        0.666667  0   Baseline
# 41   0.646465  0.598131        0.621359  1   Baseline
# 42   0.626190  0.627685        0.626937  2   Baseline
# 43   0.652913  0.616972        0.634434  3   Baseline
# 44   0.711055  0.630290        0.668241  4   Baseline
# 45   0.683292  0.632794        0.657074  5   Baseline
# 46   0.693467  0.606593        0.647128  6   Baseline
# 47   0.616867  0.618357        0.617612  7   Baseline
# 48   0.657568  0.638554        0.647922  8   Baseline
# 49   0.616337  0.655263        0.635204  9   Baseline

# %%
dd=pd.melt(dataBinary,id_vars=['Hypothesis'],value_vars=['Precision','Recall','Fmeasure_Score'],var_name='Evaluation Metrics')

plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='value',x='Hypothesis',data=dd,hue='Evaluation Metrics')
plt.ylabel("Performance", size=14)
plt.xlabel("Evaluation Metrics by Hypothesis",size=14)

#labels=["Precision", "Recall", "F-measure"]
#h, l = ax.get_legend_handles_labels()
#ax.legend(h, labels, title="Evaluation Metrics",bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
#plt.title("Evaluation Metrics by Hypothesis", size=12)
plt.savefig("BaselinexH6.pdf")
plt.show()
#plt.savefig("grouped_boxplot_AlgorithmBinary.png")

# %%
dd=pd.melt(dataBinary,id_vars=['Algorithm'],value_vars=['Precision','Recall','Fmeasure_Score'],var_name='Evaluation Metrics')

plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='value',x='Algorithm',data=dd,hue='Evaluation Metrics')
plt.ylabel("Performance", size=14)
plt.xlabel("Evaluation Metrics by Hypothesis",size=14)

labels=["Precision", "Recall", "F-measure"]
#h, l = ax.get_legend_handles_labels()
#ax.legend(h, labels, title="Evaluation Metrics",bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
#plt.title("Evaluation Metrics by Algorithm", size=12)
plt.savefig("BaselinexH6Alg.pdf")

plt.show()
#plt.savefig("grouped_boxplot_AlgorithmBinary.png")

# %%
db_alg = dataBinary.groupby(['Algorithm']).mean()
db_alg
# Out:
#                     #_TopTerms  Train/Test_Size  Accuracy_Score  \
# Algorithm
# DecisionTree             900.0              0.2        0.092958
# LogisticRegression       900.0              0.2        0.087324
# MLPClassifier            900.0              0.2        0.030282
# MLkNN                    900.0              0.2        0.064789
# RandomForest             900.0              0.2        0.117606
#
#                     Accuracy_Score_not_normalized  zero_one_loss    AUC-PR  \
# Algorithm
# DecisionTree                                 13.2       0.907042  0.454034
# LogisticRegression                           12.4       0.912676  0.688377
# MLPClassifier                                 4.3       0.969718  0.528869
# MLkNN                                         9.2       0.935211  0.563301
# RandomForest                                 16.7       0.882394  0.672314
#
#                     hamming_loss_avg  Jaccard_samples  Jaccard_macro  \
# Algorithm
# DecisionTree                0.207570         0.418541       0.410920
# LogisticRegression          0.173533         0.471811       0.465100
# MLPClassifier               0.230282         0.364190       0.362518
# MLkNN                       0.218662         0.391901       0.381320
# RandomForest                0.174648         0.480039       0.473269
#
#                     Precision    Recall  Fmeasure_Score    i
# Algorithm
# DecisionTree         0.587599  0.577409        0.582077  4.5
# LogisticRegression   0.671899  0.602404        0.634732  4.5
# MLPClassifier        0.542550  0.518720        0.521777  4.5
# MLkNN                0.569345  0.538257        0.551798  4.5
# RandomForest         0.660391  0.626121        0.642258  4.5

# %%
db_alg[['Precision','Recall','Fmeasure_Score','hamming_loss_avg', ]]
# Out:
#                     Precision    Recall  Fmeasure_Score  hamming_loss_avg
# Algorithm
# DecisionTree         0.587599  0.577409        0.582077          0.207570
# LogisticRegression   0.671899  0.602404        0.634732          0.173533
# MLPClassifier        0.542550  0.518720        0.521777          0.230282
# MLkNN                0.569345  0.538257        0.551798          0.218662
# RandomForest         0.660391  0.626121        0.642258          0.174648

# %%
dataBinary.nlargest(5,['Precision','Fmeasure_Score'])
# Out:
#    date_time  tf-IDF  #_TopTerms Stop_Word  Train/Test_Size  \
# 10   07:20.5  (1, 1)         900       Yes              0.2
# 44   58:25.3  (1, 1)         900       Yes              0.2
# 16   07:21.4  (1, 1)         900       Yes              0.2
# 14   07:21.1  (1, 1)         900       Yes              0.2
# 40   58:19.9  (1, 1)         900       Yes              0.2
#
#              Algorithm  Accuracy_Score  Accuracy_Score_not_normalized  \
# 10  LogisticRegression        0.091549                             13
# 44        RandomForest        0.154930                             22
# 16  LogisticRegression        0.098592                             14
# 14  LogisticRegression        0.084507                             12
# 40        RandomForest        0.161972                             23
#
#     zero_one_loss    AUC-PR  hamming_loss_avg  Jaccard_samples  Jaccard_macro  \
# 10       0.908451  0.734796          0.164319         0.498837       0.492754
# 44       0.845070  0.708615          0.164906         0.513400       0.501773
# 16       0.901408  0.714632          0.174883         0.487654       0.476274
# 14       0.915493  0.721885          0.171948         0.491192       0.479574
# 40       0.838028  0.726639          0.165493         0.517684       0.500000
#
#     Precision    Recall  Fmeasure_Score  i Hypothesis
# 10   0.713911  0.613995        0.660194  0         H6
# 44   0.711055  0.630290        0.668241  4   Baseline
# 16   0.703896  0.595604        0.645238  6         H6
# 14   0.703125  0.601336        0.648259  4         H6
# 40   0.699752  0.636569        0.666667  0   Baseline

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='AUC-PR',x='Algorithm',data=dataBinary)
plt.ylabel("AUCpr distribution", size=12)
plt.xlabel("Algorithm",size=12)
plt.title("Classifier Chain - AUCpr Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='hamming_loss_avg',x='Algorithm',data=dataBinary)
plt.ylabel("Hamming Loss Average distribution", size=12)
plt.xlabel("Algorithm",size=12)
plt.title("Classifier Chain - Hamming Loss Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='Accuracy_Score_not_normalized',x='Algorithm',data=dataBinary)
plt.ylabel("PR's correctly predicted", size=12)
plt.xlabel("Algorithms",size=12)
plt.title("Classifier Chain - Number of PR correctly predict considering all APIs", size=12)
plt.show()

# %%
def cliffsDelta(lst1, lst2, **dull):

    """Returns delta and true if there are more than 'dull' differences"""
    if not dull:
        dull = {'small': 0.147, 'medium': 0.33, 'large': 0.474} # effect sizes from (Hess and Kromrey, 2004)
    m, n = len(lst1), len(lst2)
    lst2 = sorted(lst2)
    j = more = less = 0
    for repeats, x in runs(sorted(lst1)):
        while j <= (n - 1) and lst2[j] < x:
            j += 1
        more += j*repeats
        while j <= (n - 1) and lst2[j] == x:
            j += 1
        less += (n - j)*repeats
    d = (more - less) / (m*n)
    size = lookup_size(d, dull)
    return d, size


def lookup_size(delta: float, dull: dict) -> str:
    """
    :type delta: float
    :type dull: dict, a dictionary of small, medium, large thresholds.
    """
    delta = abs(delta)
    if delta < dull['small']:
        return 'negligible'
    if dull['small'] <= delta < dull['medium']:
        return 'small'
    if dull['medium'] <= delta < dull['large']:
        return 'medium'
    if delta >= dull['large']:
        return 'large'


def runs(lst):
    """Iterator, chunks repeated values"""
    for j, two in enumerate(lst):
        if j == 0:
            one, i = two, 0
        if one != two:
            yield j - i, one
            i = j
        one = two
    yield j - i + 1, two

# %%
#https://machinelearningmastery.com/effect-size-measures-in-python/
#Small Effect Size: d=0.20
#Medium Effect Size: d=0.50
#Large Effect Size: d=0.80

from numpy import mean
from numpy import var
from math import sqrt

def cohend(d1, d2):
	# calculate the size of samples
	n1, n2 = len(d1), len(d2)
	# calculate the variance of the samples
	s1, s2 = var(d1, ddof=1), var(d2, ddof=1)
	# calculate the pooled standard deviation
	s = sqrt(((n1 - 1) * s1 + (n2 - 1) * s2) / (n1 + n2 - 2))
	# calculate the means of the samples
	u1, u2 = mean(d1), mean(d2)
	# calculate the effect size
	return (u1 - u2) / s

# %%
RF_binary = dataBinary[dataBinary.Algorithm == 'RandomForest']
RF_FMeasure = RF_binary['Fmeasure_Score']

LogisticRegression_binary = dataBinary[dataBinary.Algorithm == 'LogisticRegression']
LogisticRegression_FMeasure = LogisticRegression_binary['Fmeasure_Score']

MLPC_binary = dataBinary[dataBinary.Algorithm == 'MLPClassifier']
MLPC_FMeasure = MLPC_binary['Fmeasure_Score']

DT_binary = dataBinary[dataBinary.Algorithm == 'DecisionTree']
DT_FMeasure = DT_binary['Fmeasure_Score']

MlkNN_binary = dataBinary[dataBinary.Algorithm == 'MLkNN']
MlkNN_FMeasure = MlkNN_binary['Fmeasure_Score']

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_FMeasure, LogisticRegression_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_FMeasure, MLPC_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
    #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_FMeasure, DT_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
        #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_FMeasure, MlkNN_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
        #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(LogisticRegression_FMeasure, MLPC_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
            #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(LogisticRegression_FMeasure, DT_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(LogisticRegression_FMeasure, MlkNN_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(MLPC_FMeasure, DT_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(MLPC_FMeasure, MlkNN_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                    #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(MlkNN_FMeasure, DT_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

   
#Effect_Size RandomForest Vs others   
print(cliffsDelta(RF_FMeasure, LogisticRegression_FMeasure))
print(cliffsDelta(RF_FMeasure, MLPC_FMeasure))
print(cliffsDelta(RF_FMeasure, DT_FMeasure))
print(cliffsDelta(RF_FMeasure, MlkNN_FMeasure)) #divisionByZero error

#Effect_Size LogisticRegression Vs others
print(cliffsDelta(LogisticRegression_FMeasure, MLPC_FMeasure))
print(cliffsDelta(LogisticRegression_FMeasure, DT_FMeasure))
print(cliffsDelta(LogisticRegression_FMeasure, MlkNN_FMeasure))

#Effect_Size MLPC Vs others
print(cliffsDelta(MLPC_FMeasure, DT_FMeasure))
print(cliffsDelta(MLPC_FMeasure, MlkNN_FMeasure))

#Effect_Size MlkNN Vs others
print(cliffsDelta(MlkNN_FMeasure,DT_FMeasure))
# Out:
# Statistics=38.000, p=0.192
# Same distribution (fail to reject H0)
# Statistics=14.000, p=0.004
# Different distribution (reject H0)
# Statistics=2.000, p=0.000
# Different distribution (reject H0)
# Statistics=0.000, p=0.000
# Different distribution (reject H0)
# Statistics=17.000, p=0.007
# Different distribution (reject H0)
# Statistics=6.000, p=0.001
# Different distribution (reject H0)
# Statistics=0.000, p=0.000
# Different distribution (reject H0)
# Statistics=38.000, p=0.192
# Same distribution (fail to reject H0)
# Statistics=48.000, p=0.455
# Same distribution (fail to reject H0)
# Statistics=17.000, p=0.007
# Different distribution (reject H0)
# (0.24, 'small')
# (0.72, 'large')
# (0.96, 'large')
# (1.0, 'large')
# (0.66, 'large')
# (0.88, 'large')
# (1.0, 'large')
# (-0.24, 'small')
# (-0.04, 'negligible')
# (-0.66, 'large')

# %%
##Kruskall Wallis - Group Comparison

#Fail to Reject H0: Paired sample distributions are equal.
#Reject H0: Paired sample distributions are not equal.
    
from scipy.stats import kruskal
# seed the random number generator


# compare samples
stat, p = kruskal(RF_FMeasure,LogisticRegression_FMeasure, MLPC_FMeasure,DT_FMeasure,MlkNN_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=28.612, p=0.000
# Different distributions (reject H0)

# %%
#https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
from scipy.stats import friedmanchisquare

# compare samples
stat, p = friedmanchisquare(RF_FMeasure,LogisticRegression_FMeasure,MLPC_FMeasure,DT_FMeasure,MlkNN_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=26.400, p=0.000
# Different distributions (reject H0)

# %%
###Precision analysis
#Subsetting data to compute Stats

RF_binary = dataBinary[dataBinary.Algorithm == 'RandomForest']
RF_Precision = RF_binary['Precision']

LogisticRegression_binary = dataBinary[dataBinary.Algorithm == 'LogisticRegression']
LogisticRegression_Precision = LogisticRegression_binary['Precision']

MLPC_binary = dataBinary[dataBinary.Algorithm == 'MLPClassifier']
MLPC_Precision = MLPC_binary['Precision']

DT_binary = dataBinary[dataBinary.Algorithm == 'DecisionTree']
DT_Precision = DT_binary['Precision']

MlkNN_binary = dataBinary[dataBinary.Algorithm == 'MLkNN']
MlkNN_Precision = MlkNN_binary['Precision']

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_Precision, LogisticRegression_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')

#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_Precision, MLPC_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
    #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_Precision, DT_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
        #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(RF_Precision, MlkNN_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
        #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(LogisticRegression_Precision, MLPC_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
            #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(LogisticRegression_Precision, DT_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(LogisticRegression_Precision, MlkNN_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(MLPC_Precision, DT_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(MLPC_Precision, MlkNN_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
                    #### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(MlkNN_Precision, DT_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
    
#Effect_Size RandomForest Vs others   
print(cliffsDelta(RF_Precision, LogisticRegression_Precision))
print(cliffsDelta(RF_Precision, MLPC_Precision))
print(cliffsDelta(RF_Precision, DT_Precision))
print(cliffsDelta(RF_Precision, MlkNN_Precision)) #divisionByZero error

#Effect_Size LogisticRegression Vs others
print(cliffsDelta(LogisticRegression_Precision, MLPC_Precision))
print(cliffsDelta(LogisticRegression_Precision, DT_Precision))
print(cliffsDelta(LogisticRegression_Precision, MlkNN_Precision))

#Effect_Size MLPC Vs others
print(cliffsDelta(MLPC_Precision, DT_Precision))
print(cliffsDelta(MLPC_Precision, MlkNN_Precision))

#Effect_Size MlkNN Vs others
print(cliffsDelta(MlkNN_Precision,DT_Precision))
# Out:
# Statistics=39.000, p=0.214
# Same distribution (fail to reject H0)
# Statistics=22.000, p=0.019
# Different distribution (reject H0)
# Statistics=9.000, p=0.001
# Different distribution (reject H0)
# Statistics=2.000, p=0.000
# Different distribution (reject H0)
# Statistics=14.000, p=0.004
# Different distribution (reject H0)
# Statistics=5.000, p=0.000
# Different distribution (reject H0)
# Statistics=2.000, p=0.000
# Different distribution (reject H0)
# Statistics=47.000, p=0.425
# Same distribution (fail to reject H0)
# Statistics=44.000, p=0.339
# Same distribution (fail to reject H0)
# Statistics=44.000, p=0.339
# Same distribution (fail to reject H0)
# (-0.22, 'small')
# (0.56, 'large')
# (0.82, 'large')
# (0.96, 'large')
# (0.72, 'large')
# (0.9, 'large')
# (0.96, 'large')
# (-0.06, 'negligible')
# (0.12, 'negligible')
# (-0.12, 'negligible')

# %%
##Kruskall Wallis - Group Comparison

#Fail to Reject H0: Paired sample distributions are equal.
#Reject H0: Paired sample distributions are not equal.
    
from scipy.stats import kruskal
# seed the random number generator


# compare samples
stat, p = kruskal(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=24.541, p=0.000
# Different distributions (reject H0)

# %%
#https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
from scipy.stats import friedmanchisquare

# compare samples
stat, p = friedmanchisquare(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=31.680, p=0.000
# Different distributions (reject H0)

# %%
#Subsetting data to compute Stats

Baseline_binary = dataBinary[dataBinary.Hypothesis == 'Baseline']
Baseline_FMeasure = Baseline_binary['Fmeasure_Score']

H6_binary = dataBinary[dataBinary.Hypothesis == 'H6']
H6_FMeasure = H6_binary['Fmeasure_Score']

# %%
##Kruskall Wallis - Group Comparison

#Fail to Reject H0: Paired sample distributions are equal.
#Reject H0: Paired sample distributions are not equal.
    
from scipy.stats import kruskal
# seed the random number generator


# compare samples
stat, p = kruskal(Baseline_FMeasure,H6_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=8.852, p=0.003
# Different distributions (reject H0)

# %%
#https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
from scipy.stats import friedmanchisquare

# compare samples
stat, p = friedmanchisquare(Baseline_FMeasure,H6_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-319e737478c8> in <module>
#       3
#       4 # compare samples
# ----> 5 stat, p = friedmanchisquare(Baseline_FMeasure,H6_FMeasure)
#       6 print('Statistics=%.3f, p=%.3f' % (stat, p))
#       7 # interpret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py in friedmanchisquare(*args)
#    5926     k = len(args)
#    5927     if k < 3:
# -> 5928         raise ValueError('Less than 3 levels.  Friedman test not appropriate.')
#    5929
#    5930     n = len(args[0])
#
# ValueError: Less than 3 levels.  Friedman test not appropriate.

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(Baseline_FMeasure,H6_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=100.000, p=0.002
# Different distribution (reject H0)

# %%
#Effect_Size RandomForest Vs others   
print(cliffsDelta(Baseline_FMeasure, H6_FMeasure))
#print(cliffsDelta(RF_FMeasure, MLPC_FMeasure))
#print(cliffsDelta(RF_FMeasure, DT_FMeasure))
#print(cliffsDelta(RF_FMeasure, MlkNN_FMeasure)) #divisionByZero error

#Effect_Size LogisticRegression Vs others
#print(cliffsDelta(LogisticRegression_FMeasure, MLPC_FMeasure))
#print(cliffsDelta(LogisticRegression_FMeasure, DT_FMeasure))
#print(cliffsDelta(LogisticRegression_FMeasure, MlkNN_FMeasure))

#Effect_Size MLPC Vs others
#print(cliffsDelta(MLPC_FMeasure, DT_FMeasure))
#print(cliffsDelta(MLPC_FMeasure, MlkNN_FMeasure))

#Effect_Size MlkNN Vs others
#print(cliffsDelta(MlkNN_FMeasure,DT_FMeasure))
# Out:
# (0.6, 'large')

# %%
#Effect_Size RandomForest Vs others   
print('Cohens d: %.3f' % cohend(RF_FMeasure, LogisticRegression_FMeasure))    
print('Cohens d: %.3f' % cohend(RF_FMeasure, MLPC_FMeasure))
print('Cohens d: %.3f' % cohend(RF_FMeasure, DT_FMeasure))
print('Cohens d: %.3f' % cohend(RF_FMeasure, MlkNN_FMeasure))

#Effect_Size LogisticRegression Vs others
print('Cohens d: %.3f' % cohend(LogisticRegression_FMeasure, MLPC_FMeasure))    
print('Cohens d: %.3f' % cohend(LogisticRegression_FMeasure, DT_FMeasure))    
print('Cohens d: %.3f' % cohend(LogisticRegression_FMeasure, MlkNN_FMeasure))    

#Effect_Size MLPC Vs others
print('Cohens d: %.3f' % cohend(MLPC_FMeasure, DT_FMeasure))    
print('Cohens d: %.3f' % cohend(MLPC_FMeasure, MlkNN_FMeasure))    

#Effect_Size MlkNN Vs others
print('Cohens d: %.3f' % cohend(MlkNN_FMeasure,DT_FMeasure))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-391fb3cbb90c> in <module>
#       1 #Effect_Size RandomForest Vs others
# ----> 2 print('Cohens d: %.3f' % cohend(RF_FMeasure, LogisticRegression_FMeasure))
#       3 print('Cohens d: %.3f' % cohend(RF_FMeasure, MLPC_FMeasure))
#       4 print('Cohens d: %.3f' % cohend(RF_FMeasure, DT_FMeasure))
#       5 print('Cohens d: %.3f' % cohend(RF_FMeasure, MlkNN_FMeasure))
#
# NameError: name 'RF_FMeasure' is not defined

# %%
### Wilcoxon paired and dependent samples

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

#from scipy.stats import wilcoxon

#stat, p = wilcoxon(data1, data2)
#print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
#alpha = 0.05
#if p > alpha:
#	print('Same distribution (fail to reject H0)')
#else:
#	print('Different distribution (reject H0)')

# %%
###Precision analysis
#Subsetting data to compute Stats

Baseline_binary = dataBinary[dataBinary.Hypothesis == 'Baseline']
Baseline_Precision = Baseline_binary['Precision']

H6_binary = dataBinary[dataBinary.Hypothesis == 'H6']
H6_Precision = H6_binary['Precision']

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(Baseline_Precision, H6_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=137.000, p=0.013
# Different distribution (reject H0)

# %%
#Effect_Size RandomForest Vs others   
print(cliffsDelta(Baseline_Precision, H6_Precision))
#print(cliffsDelta(RF_Precision, MLPC_Precision))
#print(cliffsDelta(RF_Precision, DT_Precision))
#print(cliffsDelta(RF_Precision, MlkNN_Precision)) #divisionByZero error

#Effect_Size LogisticRegression Vs others
#print(cliffsDelta(LogisticRegression_Precision, MLPC_Precision))
#print(cliffsDelta(LogisticRegression_Precision, DT_Precision))
#print(cliffsDelta(LogisticRegression_Precision, MlkNN_Precision))

#Effect_Size MLPC Vs others
#print(cliffsDelta(MLPC_Precision, DT_Precision))
#print(cliffsDelta(MLPC_Precision, MlkNN_Precision))

#Effect_Size MlkNN Vs others
#print(cliffsDelta(MlkNN_Precision,DT_Precision))
# Out:
# (0.452, 'medium')

# %%
##Kruskall Wallis - Group Comparison

#Fail to Reject H0: Paired sample distributions are equal.
#Reject H0: Paired sample distributions are not equal.
    
from scipy.stats import kruskal
# seed the random number generator


# compare samples
stat, p = kruskal(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a2453d842cc2> in <module>
#       9
#      10 # compare samples
# ---> 11 stat, p = kruskal(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision)
#      12 print('Statistics=%.3f, p=%.3f' % (stat, p))
#      13 # interpret
#
# NameError: name 'RF_Precision' is not defined

# %%
#https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
from scipy.stats import friedmanchisquare

# compare samples
stat, p = friedmanchisquare(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-109873b250b2> in <module>
#       3
#       4 # compare samples
# ----> 5 stat, p = friedmanchisquare(RF_Precision,LogisticRegression_Precision, MLPC_Precision,DT_Precision,MlkNN_Precision)
#       6 print('Statistics=%.3f, p=%.3f' % (stat, p))
#       7 # interpret
#
# NameError: name 'RF_Precision' is not defined
