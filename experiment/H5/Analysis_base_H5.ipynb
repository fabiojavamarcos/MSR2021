# %%
import pandas as pd
import numpy as np
import csv 
import matplotlib.pyplot as plt
import seaborn as sns


#https://altair-viz.github.io/gallery/errorbars_with_std.html
import altair as alt
from vega_datasets import data

#defining paths
allAlgorithms_unigram_900terms = './boxplotH5.csv'
#classifierChain = './experiment/dfTesteClassifierChain_13Labels.csv'


dataBinary = pd.read_csv(allAlgorithms_unigram_900terms)
#dataClassifier = pd.read_csv(classifierChain)

# %%
dataBinary
# Out:
#    date_time  tf-IDF  #_TopTerms Stop_Word  Train/Test_Size     Algorithm  \
# 0    58:19.9  (1, 1)         900       Yes              0.2  RandomForest
# 1    58:21.2  (1, 1)         900       Yes              0.2  RandomForest
# 2    58:22.6  (1, 1)         900       Yes              0.2  RandomForest
# 3    58:24.0  (1, 1)         900       Yes              0.2  RandomForest
# 4    58:25.3  (1, 1)         900       Yes              0.2  RandomForest
# 5    58:26.7  (1, 1)         900       Yes              0.2  RandomForest
# 6    58:28.1  (1, 1)         900       Yes              0.2  RandomForest
# 7    58:29.4  (1, 1)         900       Yes              0.2  RandomForest
# 8    58:30.9  (1, 1)         900       Yes              0.2  RandomForest
# 9    58:32.2  (1, 1)         900       Yes              0.2  RandomForest
# 10   47:33.3  (2, 2)         900       Yes              0.2  RandomForest
# 11   47:34.7  (2, 2)         900       Yes              0.2  RandomForest
# 12   47:36.1  (2, 2)         900       Yes              0.2  RandomForest
# 13   47:37.5  (2, 2)         900       Yes              0.2  RandomForest
# 14   47:39.0  (2, 2)         900       Yes              0.2  RandomForest
# 15   47:40.3  (2, 2)         900       Yes              0.2  RandomForest
# 16   47:41.9  (2, 2)         900       Yes              0.2  RandomForest
# 17   47:43.4  (2, 2)         900       Yes              0.2  RandomForest
# 18   47:44.8  (2, 2)         900       Yes              0.2  RandomForest
# 19   47:46.3  (2, 2)         900       Yes              0.2  RandomForest
# 20   47:48.9  (3, 3)         900       Yes              0.2  RandomForest
# 21   47:50.4  (3, 3)         900       Yes              0.2  RandomForest
# 22   47:51.9  (3, 3)         900       Yes              0.2  RandomForest
# 23   47:53.4  (3, 3)         900       Yes              0.2  RandomForest
# 24   47:54.8  (3, 3)         900       Yes              0.2  RandomForest
# 25   47:56.3  (3, 3)         900       Yes              0.2  RandomForest
# 26   47:57.8  (3, 3)         900       Yes              0.2  RandomForest
# 27   47:59.2  (3, 3)         900       Yes              0.2  RandomForest
# 28   48:00.8  (3, 3)         900       Yes              0.2  RandomForest
# 29   48:02.4  (3, 3)         900       Yes              0.2  RandomForest
# 30   48:05.0  (4, 4)         900       Yes              0.2  RandomForest
# 31   48:06.5  (4, 4)         900       Yes              0.2  RandomForest
# 32   48:08.0  (4, 4)         900       Yes              0.2  RandomForest
# 33   48:09.5  (4, 4)         900       Yes              0.2  RandomForest
# 34   48:11.1  (4, 4)         900       Yes              0.2  RandomForest
# 35   48:12.6  (4, 4)         900       Yes              0.2  RandomForest
# 36   48:14.1  (4, 4)         900       Yes              0.2  RandomForest
# 37   48:15.7  (4, 4)         900       Yes              0.2  RandomForest
# 38   48:17.4  (4, 4)         900       Yes              0.2  RandomForest
# 39   48:18.8  (4, 4)         900       Yes              0.2  RandomForest
#
#     Accuracy_Score  Accuracy_Score_not_normalized  zero_one_loss    AUC-PR  \
# 0         0.161972                             23       0.838028  0.726639
# 1         0.091549                             13       0.908451  0.654757
# 2         0.091549                             13       0.908451  0.660442
# 3         0.112676                             16       0.887324  0.669685
# 4         0.154930                             22       0.845070  0.708615
# 5         0.133803                             19       0.866197  0.692722
# 6         0.105634                             15       0.894366  0.688532
# 7         0.105634                             15       0.894366  0.620070
# 8         0.105634                             15       0.894366  0.667117
# 9         0.112676                             16       0.887324  0.634557
# 10        0.126761                             18       0.873239  0.688761
# 11        0.077465                             11       0.922535  0.642633
# 12        0.077465                             11       0.922535  0.639294
# 13        0.105634                             15       0.894366  0.648695
# 14        0.119718                             17       0.880282  0.676876
# 15        0.126761                             18       0.873239  0.673980
# 16        0.105634                             15       0.894366  0.668780
# 17        0.112676                             16       0.887324  0.605402
# 18        0.098592                             14       0.901408  0.656756
# 19        0.098592                             14       0.901408  0.641237
# 20        0.119718                             17       0.880282  0.667090
# 21        0.077465                             11       0.922535  0.635185
# 22        0.070423                             10       0.929577  0.635509
# 23        0.119718                             17       0.880282  0.646706
# 24        0.147887                             21       0.852113  0.689820
# 25        0.133803                             19       0.866197  0.658158
# 26        0.084507                             12       0.915493  0.659221
# 27        0.105634                             15       0.894366  0.591099
# 28        0.091549                             13       0.908451  0.653343
# 29        0.098592                             14       0.901408  0.622894
# 30        0.091549                             13       0.908451  0.657992
# 31        0.063380                              9       0.936620  0.617386
# 32        0.056338                              8       0.943662  0.618495
# 33        0.105634                             15       0.894366  0.652426
# 34        0.133803                             19       0.866197  0.681957
# 35        0.098592                             14       0.901408  0.634286
# 36        0.084507                             12       0.915493  0.657201
# 37        0.098592                             14       0.901408  0.581726
# 38        0.084507                             12       0.915493  0.628202
# 39        0.077465                             11       0.922535  0.613915
#
#     hamming_loss_avg  Jaccard_samples  Jaccard_macro  Precision    Recall  \
# 0           0.165493         0.517684       0.500000   0.699752  0.636569
# 1           0.183099         0.457070       0.450704   0.646465  0.598131
# 2           0.183685         0.465118       0.456597   0.626190  0.627685
# 3           0.181925         0.468195       0.464594   0.652913  0.616972
# 4           0.164906         0.513400       0.501773   0.711055  0.630290
# 5           0.167840         0.499444       0.489286   0.683292  0.632794
# 6           0.176643         0.489873       0.478336   0.693467  0.606593
# 7           0.186033         0.450808       0.446771   0.616867  0.618357
# 8           0.169014         0.472720       0.479204   0.657568  0.638554
# 9           0.167840         0.466080       0.465421   0.616337  0.655263
# 10          0.173122         0.508604       0.499151   0.668182  0.663657
# 11          0.188380         0.452817       0.451282   0.627078  0.616822
# 12          0.183685         0.467164       0.463122   0.622120  0.644391
# 13          0.177817         0.482984       0.482935   0.653580  0.649083
# 14          0.176056         0.496688       0.487179   0.676960  0.634744
# 15          0.174883         0.500998       0.484429   0.658824  0.646651
# 16          0.176056         0.510999       0.492386   0.681499  0.639560
# 17          0.192488         0.458800       0.445008   0.597727  0.635266
# 18          0.173709         0.479779       0.478873   0.640000  0.655422
# 19          0.177817         0.460614       0.455036   0.589744  0.665789
# 20          0.172535         0.507783       0.498294   0.671264  0.659142
# 21          0.189554         0.450782       0.450680   0.623529  0.619159
# 22          0.180751         0.470568       0.468966   0.628176  0.649165
# 23          0.180164         0.479653       0.477891   0.648961  0.644495
# 24          0.164319         0.529150       0.515571   0.697892  0.663697
# 25          0.177230         0.500947       0.481990   0.651972  0.648961
# 26          0.178991         0.494215       0.483926   0.677725  0.628571
# 27          0.187207         0.463724       0.455631   0.608200  0.644928
# 28          0.176056         0.473726       0.472759   0.635934  0.648193
# 29          0.178991         0.459205       0.452424   0.587413  0.663158
# 30          0.178404         0.493581       0.484746   0.660508  0.645598
# 31          0.190728         0.442567       0.445392   0.622912  0.609813
# 32          0.182512         0.469042       0.464716   0.625000  0.644391
# 33          0.182512         0.475908       0.471986   0.645012  0.637615
# 34          0.165493         0.524572       0.513793   0.694639  0.663697
# 35          0.181338         0.486544       0.469983   0.646226  0.632794
# 36          0.178404         0.497736       0.483871   0.680191  0.626374
# 37          0.191901         0.455558       0.443878   0.600000  0.630435
# 38          0.174296         0.473726       0.474336   0.641148  0.645783
# 39          0.180164         0.451224       0.443841   0.587530  0.644737
#
#     Fmeasure_Score  i Hypothesis
# 0         0.666667  0   Baseline
# 1         0.621359  1   Baseline
# 2         0.626937  2   Baseline
# 3         0.634434  3   Baseline
# 4         0.668241  4   Baseline
# 5         0.657074  5   Baseline
# 6         0.647128  6   Baseline
# 7         0.617612  7   Baseline
# 8         0.647922  8   Baseline
# 9         0.635204  9   Baseline
# 10        0.665912  0         H5
# 11        0.621908  1         H5
# 12        0.633060  2         H5
# 13        0.651323  3         H5
# 14        0.655172  4         H5
# 15        0.652681  5         H5
# 16        0.659864  6         H5
# 17        0.615925  7         H5
# 18        0.647619  8         H5
# 19        0.625464  9         H5
# 20        0.665148  0         H5
# 21        0.621336  1         H5
# 22        0.638498  2         H5
# 23        0.646720  3         H5
# 24        0.680365  4         H5
# 25        0.650463  5         H5
# 26        0.652223  6         H5
# 27        0.626026  7         H5
# 28        0.642005  8         H5
# 29        0.622991  9         H5
# 30        0.652968  0         H5
# 31        0.616293  1         H5
# 32        0.634548  2         H5
# 33        0.641292  3         H5
# 34        0.678815  4         H5
# 35        0.639440  5         H5
# 36        0.652174  6         H5
# 37        0.614841  7         H5
# 38        0.643457  8         H5
# 39        0.614806  9         H5

# %%
dd=pd.melt(dataBinary,id_vars=['Hypothesis'],value_vars=['Precision','Recall','Fmeasure_Score'],var_name='Evaluation Metrics')

plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='value',x='Hypothesis',data=dd,hue='Evaluation Metrics')
#ax = sns.boxplot(y='value',x='Hypothesis',data=dd)
plt.ylabel("Performance", size=14)
plt.xlabel("Evaluation Metrics by Hypothesis",size=14)

labels=["Precision", "Recall", "F-measure"]
#h, l = ax.get_legend_handles_labels()
#ax.legend(h, labels, title="Evaluation Metrics",bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
#plt.title("Evaluation Metrics by Hypothesis", size=12)
plt.savefig("BaselinexH5.pdf")

plt.show()
#plt.savefig("grouped_boxplot_AlgorithmBinary.png")

# %%
dd=pd.melt(dataBinary,id_vars=['tf-IDF'],value_vars=['Precision','Recall','Fmeasure_Score'],var_name='Evaluation Metrics')

plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='value',x='tf-IDF',data=dd,hue='Evaluation Metrics')
#ax = sns.boxplot(y='value',x='tf-IDF',data=dd)
plt.ylabel("Performance", size=14)
plt.xlabel("Evaluation Metrics by tf-IDF",size=14)

labels=["Precision", "Recall", "F-measure"]
h, l = ax.get_legend_handles_labels()
#ax.legend(h, labels, title="Evaluation Metrics",bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
#plt.title("Evaluation Metrics by tf-IDF", size=12)
plt.savefig("BaselinexH5tfidf.pdf")
plt.show()

# %%
dataBinary.groupby(['Hypothesis']).mean()
# Out:
#             #_TopTerms  Train/Test_Size  Accuracy_Score  \
# Hypothesis
# Baseline         900.0              0.2        0.117606
# H5               900.0              0.2        0.099765
#
#             Accuracy_Score_not_normalized  zero_one_loss    AUC-PR  \
# Hypothesis
# Baseline                        16.700000       0.882394  0.672314
# H5                              14.166667       0.900235  0.644834
#
#             hamming_loss_avg  Jaccard_samples  Jaccard_macro  Precision  \
# Hypothesis
# Baseline            0.174648         0.480039       0.473269   0.660391
# H5                  0.179519         0.480655       0.473136   0.641665
#
#               Recall  Fmeasure_Score    i
# Hypothesis
# Baseline    0.626121        0.642258  4.5
# H5          0.643403        0.642111  4.5

# %%
dataBinary.groupby(['tf-IDF']).mean()
# Out:
#         #_TopTerms  Train/Test_Size  Accuracy_Score  \
# tf-IDF
# (1, 1)       900.0              0.2        0.117606
# (2, 2)       900.0              0.2        0.104930
# (3, 3)       900.0              0.2        0.104930
# (4, 4)       900.0              0.2        0.089437
#
#         Accuracy_Score_not_normalized  zero_one_loss    AUC-PR  \
# tf-IDF
# (1, 1)                           16.7       0.882394  0.672314
# (2, 2)                           14.9       0.895070  0.654241
# (3, 3)                           14.9       0.895070  0.645902
# (4, 4)                           12.7       0.910563  0.634359
#
#         hamming_loss_avg  Jaccard_samples  Jaccard_macro  Precision    Recall  \
# tf-IDF
# (1, 1)          0.174648         0.480039       0.473269   0.660391  0.626121
# (2, 2)          0.179401         0.481945       0.473940   0.641571  0.645139
# (3, 3)          0.178580         0.482975       0.475813   0.643107  0.646947
# (4, 4)          0.180575         0.477046       0.469654   0.640317  0.638124
#
#         Fmeasure_Score    i
# tf-IDF
# (1, 1)        0.642258  4.5
# (2, 2)        0.642893  4.5
# (3, 3)        0.644578  4.5
# (4, 4)        0.638863  4.5

# %%
dataBinary.nlargest(5,['Precision','Fmeasure_Score'])
# Out:
#    date_time  tf-IDF  #_TopTerms Stop_Word  Train/Test_Size     Algorithm  \
# 4    58:25.3  (1, 1)         900       Yes              0.2  RandomForest
# 0    58:19.9  (1, 1)         900       Yes              0.2  RandomForest
# 24   47:54.8  (3, 3)         900       Yes              0.2  RandomForest
# 34   48:11.1  (4, 4)         900       Yes              0.2  RandomForest
# 6    58:28.1  (1, 1)         900       Yes              0.2  RandomForest
#
#     Accuracy_Score  Accuracy_Score_not_normalized  zero_one_loss    AUC-PR  \
# 4         0.154930                             22       0.845070  0.708615
# 0         0.161972                             23       0.838028  0.726639
# 24        0.147887                             21       0.852113  0.689820
# 34        0.133803                             19       0.866197  0.681957
# 6         0.105634                             15       0.894366  0.688532
#
#     hamming_loss_avg  Jaccard_samples  Jaccard_macro  Precision    Recall  \
# 4           0.164906         0.513400       0.501773   0.711055  0.630290
# 0           0.165493         0.517684       0.500000   0.699752  0.636569
# 24          0.164319         0.529150       0.515571   0.697892  0.663697
# 34          0.165493         0.524572       0.513793   0.694639  0.663697
# 6           0.176643         0.489873       0.478336   0.693467  0.606593
#
#     Fmeasure_Score  i Hypothesis
# 4         0.668241  4   Baseline
# 0         0.666667  0   Baseline
# 24        0.680365  4         H5
# 34        0.678815  4         H5
# 6         0.647128  6   Baseline

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='AUC-PR',x='Hypothesis',data=dataBinary)
plt.ylabel("AUCpr distribution", size=12)
plt.xlabel("Hypothesis",size=12)
plt.title("Classifier Chain - AUCpr Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='AUC-PR',x='tf-IDF',data=dataBinary)
plt.ylabel("AUCpr distribution", size=12)
plt.xlabel("tf-IDF",size=12)
plt.title("Classifier Chain - AUCpr Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='hamming_loss_avg',x='Hypothesis',data=dataBinary)
plt.ylabel("Hamming Loss Average distribution", size=12)
plt.xlabel("Hypothesis",size=12)
plt.title("Classifier Chain - Hamming Loss Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='hamming_loss_avg',x='tf-IDF',data=dataBinary)
plt.ylabel("Hamming Loss Average distribution", size=12)
plt.xlabel("tf-IDF",size=12)
plt.title("Classifier Chain - Hamming Loss Analysis", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='Accuracy_Score_not_normalized',x='Hypothesis',data=dataBinary)
plt.ylabel("PR's correctly predicted", size=12)
plt.xlabel("Hypothesis",size=12)
plt.title("Classifier Chain - Number of PR correctly predict considering all APIs", size=12)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(y='Accuracy_Score_not_normalized',x='tf-IDF',data=dataBinary)
plt.ylabel("PR's correctly predicted", size=12)
plt.xlabel("tf-IDF",size=12)
plt.title("Classifier Chain - Number of PR correctly predict considering all APIs", size=12)
plt.show()

# %%
def cliffsDelta(lst1, lst2, **dull):

    """Returns delta and true if there are more than 'dull' differences"""
    if not dull:
        dull = {'small': 0.147, 'medium': 0.33, 'large': 0.474} # effect sizes from (Hess and Kromrey, 2004)
    m, n = len(lst1), len(lst2)
    lst2 = sorted(lst2)
    j = more = less = 0
    for repeats, x in runs(sorted(lst1)):
        while j <= (n - 1) and lst2[j] < x:
            j += 1
        more += j*repeats
        while j <= (n - 1) and lst2[j] == x:
            j += 1
        less += (n - j)*repeats
    d = (more - less) / (m*n)
    size = lookup_size(d, dull)
    return d, size


def lookup_size(delta: float, dull: dict) -> str:
    """
    :type delta: float
    :type dull: dict, a dictionary of small, medium, large thresholds.
    """
    delta = abs(delta)
    if delta < dull['small']:
        return 'negligible'
    if dull['small'] <= delta < dull['medium']:
        return 'small'
    if dull['medium'] <= delta < dull['large']:
        return 'medium'
    if delta >= dull['large']:
        return 'large'


def runs(lst):
    """Iterator, chunks repeated values"""
    for j, two in enumerate(lst):
        if j == 0:
            one, i = two, 0
        if one != two:
            yield j - i, one
            i = j
        one = two
    yield j - i + 1, two

# %%
#https://machinelearningmastery.com/effect-size-measures-in-python/
#Small Effect Size: d=0.20
#Medium Effect Size: d=0.50
#Large Effect Size: d=0.80

from numpy import mean
from numpy import var
from math import sqrt

def cohend(d1, d2):
	# calculate the size of samples
	n1, n2 = len(d1), len(d2)
	# calculate the variance of the samples
	s1, s2 = var(d1, ddof=1), var(d2, ddof=1)
	# calculate the pooled standard deviation
	s = sqrt(((n1 - 1) * s1 + (n2 - 1) * s2) / (n1 + n2 - 2))
	# calculate the means of the samples
	u1, u2 = mean(d1), mean(d2)
	# calculate the effect size
	return (u1 - u2) / s

# %%
dataBinary['tf-IDF']
# Out:
# 0     (1, 1)
# 1     (1, 1)
# 2     (1, 1)
# 3     (1, 1)
# 4     (1, 1)
# 5     (1, 1)
# 6     (1, 1)
# 7     (1, 1)
# 8     (1, 1)
# 9     (1, 1)
# 10    (2, 2)
# 11    (2, 2)
# 12    (2, 2)
# 13    (2, 2)
# 14    (2, 2)
# 15    (2, 2)
# 16    (2, 2)
# 17    (2, 2)
# 18    (2, 2)
# 19    (2, 2)
# 20    (3, 3)
# 21    (3, 3)
# 22    (3, 3)
# 23    (3, 3)
# 24    (3, 3)
# 25    (3, 3)
# 26    (3, 3)
# 27    (3, 3)
# 28    (3, 3)
# 29    (3, 3)
# 30    (4, 4)
# 31    (4, 4)
# 32    (4, 4)
# 33    (4, 4)
# 34    (4, 4)
# 35    (4, 4)
# 36    (4, 4)
# 37    (4, 4)
# 38    (4, 4)
# 39    (4, 4)
# Name: tf-IDF, dtype: object

# %%
#Subsetting data to compute Stats

Baseline_binary = dataBinary[dataBinary['tf-IDF'] == '(1, 1)']
Baseline_FMeasure = Baseline_binary['Fmeasure_Score']

H5_22_binary = dataBinary[dataBinary['tf-IDF'] == '(2, 2)']
H5_22_FMeasure = H5_22_binary['Fmeasure_Score']

H5_33_binary = dataBinary[dataBinary['tf-IDF'] == '(3, 3)']
H5_33_FMeasure = H5_33_binary['Fmeasure_Score']

H5_44_binary = dataBinary[dataBinary['tf-IDF'] == '(4, 4)']
H5_44_FMeasure = H5_44_binary['Fmeasure_Score']

# %%
Baseline_FMeasure
# Out:
# 0    0.666667
# 1    0.621359
# 2    0.626937
# 3    0.634434
# 4    0.668241
# 5    0.657074
# 6    0.647128
# 7    0.617612
# 8    0.647922
# 9    0.635204
# Name: Fmeasure_Score, dtype: float64

# %%
#Subsetting data to compute Stats

Baseline_binary = dataBinary[dataBinary.Hypothesis == 'Baseline']
Baseline_FMeasure = Baseline_binary['Fmeasure_Score']

H5_binary = dataBinary[dataBinary.Hypothesis == 'H5']
H5_FMeasure = H5_binary['Fmeasure_Score']

# %%
##Kruskall Wallis - Group Comparison

#Fail to Reject H0: Paired sample distributions are equal.
#Reject H0: Paired sample distributions are not equal.
    
from scipy.stats import kruskal
# seed the random number generator


# compare samples
stat, p = kruskal(Baseline_FMeasure,H5_22_FMeasure, H5_33_FMeasure, H5_44_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=0.730, p=0.866
# Same distributions (fail to reject H0)

# %%
#https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
from scipy.stats import friedmanchisquare

# compare samples
stat, p = friedmanchisquare(Baseline_FMeasure,H5_22_FMeasure, H5_33_FMeasure, H5_44_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=5.280, p=0.152
# Same distributions (fail to reject H0)

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(Baseline_FMeasure,H5_FMeasure)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=145.000, p=0.444
# Same distribution (fail to reject H0)

# %%
#Effect_Size RandomForest Vs others   
#print(cliffsDelta(Baseline_FMeasure, H5_FMeasure))
print(cliffsDelta(Baseline_FMeasure, H5_22_FMeasure))
print(cliffsDelta(Baseline_FMeasure, H5_33_FMeasure))
print(cliffsDelta(Baseline_FMeasure, H5_44_FMeasure)) #divisionByZero error

#Effect_Size LogisticRegression Vs others
print(cliffsDelta(H5_22_FMeasure, H5_33_FMeasure))
print(cliffsDelta(H5_22_FMeasure, H5_44_FMeasure))
#print(cliffsDelta(LogisticRegression_FMeasure, MlkNN_FMeasure))

#Effect_Size MLPC Vs others
print(cliffsDelta(H5_33_FMeasure, H5_44_FMeasure))
#print(cliffsDelta(MLPC_FMeasure, MlkNN_FMeasure))

#Effect_Size MlkNN Vs others
#print(cliffsDelta(MlkNN_FMeasure,DT_FMeasure))
# Out:
# (0.0, 'negligible')
# (-0.04, 'negligible')
# (0.14, 'negligible')
# (0.04, 'negligible')
# (0.2, 'small')
# (0.2, 'small')

# %%
#Effect_Size RandomForest Vs others   
print('Cohens d: %.3f' % cohend(RF_FMeasure, LogisticRegression_FMeasure))    
print('Cohens d: %.3f' % cohend(RF_FMeasure, MLPC_FMeasure))
print('Cohens d: %.3f' % cohend(RF_FMeasure, DT_FMeasure))
print('Cohens d: %.3f' % cohend(RF_FMeasure, MlkNN_FMeasure))

#Effect_Size LogisticRegression Vs others
print('Cohens d: %.3f' % cohend(LogisticRegression_FMeasure, MLPC_FMeasure))    
print('Cohens d: %.3f' % cohend(LogisticRegression_FMeasure, DT_FMeasure))    
print('Cohens d: %.3f' % cohend(LogisticRegression_FMeasure, MlkNN_FMeasure))    

#Effect_Size MLPC Vs others
print('Cohens d: %.3f' % cohend(MLPC_FMeasure, DT_FMeasure))    
print('Cohens d: %.3f' % cohend(MLPC_FMeasure, MlkNN_FMeasure))    

#Effect_Size MlkNN Vs others
print('Cohens d: %.3f' % cohend(MlkNN_FMeasure,DT_FMeasure))

# %%
### Wilcoxon paired and dependent samples

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

#from scipy.stats import wilcoxon

#stat, p = wilcoxon(data1, data2)
#print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
#alpha = 0.05
#if p > alpha:
#	print('Same distribution (fail to reject H0)')
#else:
#	print('Different distribution (reject H0)')

# %%
#Subsetting data to compute Stats

Baseline_binary = dataBinary[dataBinary['tf-IDF'] == '(1, 1)']
Baseline_Precision = Baseline_binary['Precision']

H5_22_binary = dataBinary[dataBinary['tf-IDF'] == '(2, 2)']
H5_22_Precision = H5_22_binary['Precision']

H5_33_binary = dataBinary[dataBinary['tf-IDF'] == '(3, 3)']
H5_33_Precision = H5_33_binary['Precision']

H5_44_binary = dataBinary[dataBinary['tf-IDF'] == '(4, 4)']
H5_44_Precision = H5_44_binary['Precision']

# %%
###Precision analysis
#Subsetting data to compute Stats

Baseline_binary = dataBinary[dataBinary.Hypothesis == 'Baseline']
Baseline_Precision = Baseline_binary['Precision']

H5_binary = dataBinary[dataBinary.Hypothesis == 'H5']
H5_Precision = H5_binary['Precision']

# %%
#### MANN-U Independent Samples
from scipy.stats import mannwhitneyu

#Fail to Reject H0: Sample distributions are equal.
#Reject H0: Sample distributions are not equal.

##### Defining variables to be comparede

# compare samples
stat, p = mannwhitneyu(Baseline_Precision, H5_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distribution (fail to reject H0)')
else:
	print('Different distribution (reject H0)')
# Out:
# Statistics=106.000, p=0.087
# Same distribution (fail to reject H0)

# %%
#Effect_Size RandomForest Vs others   
#print(cliffsDelta(Baseline_Precision, H5_Precision))
print(cliffsDelta(Baseline_Precision, H5_22_Precision))
print(cliffsDelta(Baseline_Precision, H5_33_Precision))
print(cliffsDelta(Baseline_Precision, H5_44_Precision)) #divisionByZero error

#Effect_Size LogisticRegression Vs others
print(cliffsDelta(H5_22_Precision, H5_33_Precision))
print(cliffsDelta(H5_22_Precision, H5_44_Precision))
#print(cliffsDelta(LogisticRegression_Precision, MlkNN_Precision))

#Effect_Size MLPC Vs others
print(cliffsDelta(H5_33_Precision, H5_44_Precision))
#print(cliffsDelta(MLPC_Precision, MlkNN_Precision))

#Effect_Size MlkNN Vs others
#print(cliffsDelta(MlkNN_Precision,DT_Precision))
# Out:
# (0.26, 'small')
# (0.28, 'small')
# (0.34, 'medium')
# (0.0, 'negligible')
# (0.02, 'negligible')
# (0.06, 'negligible')

# %%
##Kruskall Wallis - Group Comparison

#Fail to Reject H0: Paired sample distributions are equal.
#Reject H0: Paired sample distributions are not equal.
    
from scipy.stats import kruskal
# seed the random number generator


# compare samples
stat, p = kruskal(Baseline_Precision,H5_22_Precision, H5_33_Precision, H5_44_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=1.933, p=0.586
# Same distributions (fail to reject H0)

# %%
#https://machinelearningmastery.com/nonparametric-statistical-significance-tests-in-python/
from scipy.stats import friedmanchisquare

# compare samples
stat, p = friedmanchisquare(Baseline_Precision,H5_22_Precision, H5_33_Precision, H5_44_Precision)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Same distributions (fail to reject H0)')
else:
	print('Different distributions (reject H0)')
# Out:
# Statistics=14.760, p=0.002
# Different distributions (reject H0)
