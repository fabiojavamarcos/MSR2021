# %%
import pandas as pd
import numpy as np
import csv 
import string
import nltk 
import re 
import time
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import os
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer
import sys
import warnings
from os import path
import ast
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from skmultilearn.problem_transform import BinaryRelevance
from skmultilearn.problem_transform import LabelPowerset
from skmultilearn.problem_transform import ClassifierChain
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, average_precision_score, precision_recall_fscore_support
from sklearn.metrics import accuracy_score
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import zero_one_loss
from sklearn.metrics import jaccard_score
import sklearn.metrics as skm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
import numpy as np
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import time
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from skmultilearn.adapt import MLkNN
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from skmultilearn.adapt import BRkNNaClassifier
from sklearn.linear_model import RidgeClassifierCV

pd.options.display.max_seq_items = 2000
pd.options.display.max_colwidth = 90
pd.options.display.max_rows = 999

loggingFile = './experiment//TitleBody3GramTFIDF.txt'
binaryBodyTitle = './experiment/binaryBodyTitle.csv'
template = './experiment/dfTeste.csv'

# %%
#organizing data_frame to issue order
def organize():
    data_classes = pd.read_csv(binaryBodyTitle, header = 0, sep=";")
    data_classes

    del data_classes['prIssue']
    del data_classes['issueTitle']
    del data_classes['issueBody']

    data_classes.rename(columns={'issueComments': 'prComments','Comments': 'prCodeReviewComments','issueTitleLink': 'issueTitle','issueBodyLink': 'issueBody','issueCommentsLink': 'issue_Comments','pr': 'prNumber','issue': 'issueNumber', 'Title': 'prTitle','Body': 'prBody'}, inplace=True)
    categories = data_classes.columns.values.tolist()


    data_classes = data_classes[['issueNumber', 'prNumber', 'issueTitle', 'issueBody', 'issue_Comments',
                            'prTitle','prBody','prComments','prCodeReviewComments','commitMessage','isPR','isTrain',
                             'Google Common','Test','SO','IO','UI','Network','Security',
                            'OpenOffice Documents','Database','Utils','PDF','Logging','Latex']]

    data_classes['issueNumber'] = data_classes['issueNumber'].astype('Int64')
    
    return data_classes

# %%
#data_classes = organize()

# %%
#Filtering issues with PRs
def filtering(data_classes):
    IssuePRDataset = data_classes[data_classes["isTrain"] == 0]

    #invalid number of issue = NaN
    IssuePRDataset = IssuePRDataset.drop([1805])

    categories = IssuePRDataset.columns.values.tolist()
    
    return categories, IssuePRDataset

# %%
#categories, IssuePRDataset = filtering(data_classes)

# %%
# RQ1.a - o quão sensível o resultado é em relação ao algoritmo? 
#vários algoritmos - BinaryRelevance
#todas as palavras, bootstrap, unigram 
#somente o título
def dataset_config(IssuePRDataset):
    data_test1 = IssuePRDataset[['issueNumber','prNumber','issueTitle','Google Common', 'Test', 'SO', 'IO', 'UI', 'Network', 'Security', 
                           'OpenOffice Documents', 'Database', 'Utils', 'PDF', 'Logging', 'Latex']].copy()

    data_test1["corpus"] = data_test1["issueTitle"].map(str)
    del data_test1["issueTitle"]

    #removing utils because we won't to predict a so simple API that is basically used in all PRs
    del data_test1["Utils"]

    data_test1 = data_test1.reset_index(drop=True)
    
    return data_test1

# %%
#data_test1 = dataset_config(IssuePRDataset)

# %%
#preprocessing text

#We first convert the comments to lower-case 
#then use custom made functions to remove html-tags, punctuation and non-alphabetic characters from the TitleBody.

def clean_data(data_test1):
    if not sys.warnoptions:
        warnings.simplefilter("ignore")

    def cleanHtml(sentence):
        cleanr = re.compile('<.*?>')
        cleantext = re.sub(cleanr, ' ', str(sentence))
        return cleantext

    def cleanPunc(sentence): #function to clean the word of any punctuation or special characters
        cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
        cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
        cleaned = cleaned.strip()
        cleaned = cleaned.replace("\n"," ")
        return cleaned

    def keepAlpha(sentence):
        alpha_sent = ""
        for word in sentence.split():
            alpha_word = re.sub('[^a-z A-Z]+', ' ', word)
            alpha_sent += alpha_word
            alpha_sent += " "
        alpha_sent = alpha_sent.strip()
        return alpha_sent

    #function pra remover palavras com menos de 3 tokens

    data_test1['corpus'] = data_test1['corpus'].str.lower()
    data_test1['corpus'] = data_test1['corpus'].apply(cleanHtml)
    data_test1['corpus'] = data_test1['corpus'].apply(cleanPunc)
    data_test1['corpus'] = data_test1['corpus'].apply(keepAlpha)
    
    return data_test1

# %%
#data_test1 = clean_data(data_test1)

# %%
#### removing stopwords

def remove_stop_words():
    stop_words = set(stopwords.words('english'))
    stop_words.update(['pr','zero','one','two','three','four','five','six','seven','eight','nine','ten','may','also','across','among','beside','however','yet','within','jabref','org','github','com','md','https','ad','changelog','','joelparkerhenderson','localizationupd',' localizationupd','localizationupd ','i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the','Mr', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now'])
    #stop_words.update(['i', 'me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the","Mr", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"])

    re_stop_words = re.compile(r"\b(" + "|".join(stop_words) + ")\\W", re.I)

    return re_stop_words

# %%
#re_stop_words = remove_stop_words()

# %%
def removeStopWords(sentence, re_stop_words):
    #global re_stop_words
    #print(sentence)
    return re_stop_words.sub(" ", sentence)

#removing words with less than 3 characters
#data_classes['titleBody'] = data_classes['titleBody'].str.findall('\w{3,}').str.join(' ')

# %%
#data_test1['corpus'] = data_test1['corpus'].apply(removeStopWords, re_stop_words=re_stop_words)

# %%
def apply_stem(data_test1):
    stemmer = SnowballStemmer("english")
    
    def stemming(sentence):
        stemSentence = ""
        for word in sentence.split():
            stem = stemmer.stem(word)
            stemSentence += stem
            stemSentence += " "
        stemSentence = stemSentence.strip()
        return stemSentence
    
    data_test1['corpus'] = data_test1['corpus'].apply(stemming)
    print(data_test1['corpus'])
    
    return data_test1

# %%
#data_test1 = apply_stem(data_test1)

# %%
#TF-ID
def run_tf_idf(data, configurationTFIDF, num_feature, tfIDFoutputFile):
    #we need to text max_feature with 10, 20, 25, 50 
    #, max_features=num_feature
    vectorizer = TfidfVectorizer(strip_accents='unicode', analyzer='word', ngram_range = configurationTFIDF, max_features=num_feature)
        
    tf_idf_results = vectorizer.fit_transform(data['corpus'])

    features = vectorizer.get_feature_names()

    print(features)

    scores = (tf_idf_results.toarray())
    output_tf_idf = pd.DataFrame(scores)
    
    output_tf_idf = pd.concat([data['issueNumber'], output_tf_idf], axis=1)

    output_tf_idf.to_csv(tfIDFoutputFile, encoding='utf-8', header=False, index=False, sep=',')


    # remove words occuring less than 5 times
    #tfidf = TfidfVectorizer(min_df=5)
    #you can also remove common words:

    # remove words occuring in more than half the documents
    #tfidf = TfidfVectorizer(max_df=0.5)
    #you can also remove stopwords like this:

# %%
#use one of the data_test's (1 to 11) e.g data_test5

#run_tf_idf(data_test1, configurationTFIDF, num_feature, tfIDFoutputFile)

# %%
#analyzing frequency of TOP 50 terms

def analyze_top(data, termFrequencyTop50):
    docs = data['corpus'].tolist()

    cv = CountVectorizer()
    cv_fit=cv.fit_transform(docs)

    #print(cv.get_feature_names())
    #print(cv_fit.toarray())

    word_list = cv.get_feature_names()   

    count_list = cv_fit.toarray().sum(axis=0)
    term_frequency = dict(zip(word_list,count_list))

    a = sorted(term_frequency.items(), key=lambda x: x[1], reverse=True) 

    top50 = a[:100]
    df_frequency = pd.DataFrame(top50, columns =['term', 'frequency'])  

    print(df_frequency)

    df_frequency.to_csv(termFrequencyTop50, encoding='utf-8', header=False, index=False, sep=',')

    sns.set(font_scale = 2)
    plt.figure(figsize=(18,17))
    plt.xticks(rotation=90)
    plt.title("Frequency of terms ")
    plt.ylabel('term', fontsize=20)
    plt.xlabel('frequency', fontsize=20)
    ax = sns.barplot(x="frequency", y="term", data=df_frequency)
    
    return docs

# %%
#docs = analyze_top(data_test1, termFrequencyTop50)

# %%
#merging features TF-IDF with data_frame
def merging(data_test1, tfIDFoutputFile):
    feature = pd.read_csv(tfIDFoutputFile, header=None, sep=",")
    feature.rename(columns={0: 'issueNumber'}, inplace=True)

    data_classifier = data_test1.join(feature, lsuffix='issueNumber', rsuffix='issueNumber')

    categories = data_classifier.columns.values.tolist()
    
    return data_classifier, categories

# %%
#data_classifier, categories = merging(data_test1)

# %%
def eval_metrics(predictions, probabilities, y_test):
    
    y_pred = predictions.values
    y_proba = probabilities.values

    #receiving the y_test true value from each pull request
    y_true = y_test.to_numpy()

    print("Accuracy Score")
    acc_ml = accuracy_score(y_true, y_pred)
    print(acc_ml)

    print("---------")
    print("")

    print("Accuracy Score not normalized")
    acc_score = accuracy_score(y_true, y_pred, normalize=False)
    print(acc_score)

    print("---------")
    print("")

    print("zero_one_loss")
    zeroOne = zero_one_loss(y_true, y_pred)
    print(zeroOne)

    print("---------")
    print("")

    print("Fmeasure Score")
    fmeasure_score = f1_score(y_true,y_pred, average='micro')
    #fmeasure_score = f1_score(y_true,y_pred, average='macro')
    print(fmeasure_score)

    print("---------")
    print("")

    #AUC-PR
    print("AUC-PR")
    pr_score = average_precision_score(y_true,y_proba,average='micro')
    print(pr_score)
    #pr_score = average_precision_score(y_true,y_proba,average='macro')

    print("---------")
    print("")


    print("hamming loss average")
    hamming_loss = skm.hamming_loss(y_true, y_pred)
    print(hamming_loss)

    print("---------")
    print("")

    print("Jaccard samples")
    jaccard_score_samples = jaccard_score(y_true, y_pred, average='samples')
    print(jaccard_score_samples)

    print("---------")
    print("")


    print("Jaccard macro")
    jaccard_macro = jaccard_score(y_true, y_pred, average='micro')
    print(jaccard_macro)
    #jaccard_score(y_true, y_pred, average=None)

    print("---------")
    print("")

    return y_true, y_proba, y_pred, acc_ml, acc_score, zeroOne, fmeasure_score, pr_score, hamming_loss, jaccard_score_samples, jaccard_macro

# %%
def plot_classes(probability, y_true, y_test):
    precision = dict()
    recall = dict()
    average_precision = dict()

    n_classes = y_test.shape[1]

    for i in range(n_classes):
        precision[i], recall[i], _ = precision_recall_curve(y_true[:, i], probability[:, i])
        average_precision[i] = average_precision_score(y_true[:, i], probability[:, i])

    precision["micro"], recall["micro"], _ = precision_recall_curve(y_true.ravel(),probability.ravel())

    average_precision["micro"] = average_precision_score(y_true, probability, average="micro")

    print('Average precision score, micro-averaged over all classes: {0:0.2f}'
          .format(average_precision["micro"]))

    plt.figure()
    plt.step(recall['micro'], precision['micro'], where='post')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title(
        'Average precision score, micro-averaged over all classes: AP={0:0.2f}'
        .format(average_precision["micro"]))

# %%
import io
def confusion_matrix(y_true, y_pred, confusionMatrix, i):

    data = multilabel_confusion_matrix(y_true, y_pred)
    
    labels = ['Google Common', 'Test', 'SO', 'IO', 'UI', 'Network',
              'Security', 'OpenOffice Documents', 'Database','PDF',
              'Logging','Latex']
      
    metrics = pd.DataFrame()
    line = []
    dataLine = ""
    dataLine = "Label, TN, FP, FN, TP"
    line.append((dataLine))

    for j in range (0,12):
        print(j)
        row = data[j]
        dataLine=""
        dataLine = labels[j] 
        print(dataLine)
        for x in np.nditer(row):
            dataLine = dataLine + "," + str(x)
            print(dataLine)
        line.append((dataLine))
        print(line)
        
        metrics = pd.DataFrame(line)
    
    metrics.to_csv(confusionMatrix + str(i) +'.csv' , encoding='utf-8', header=True, index=False , sep=',')

# %%
#build the model 

def build_model(test_type):

    if test_type == "DecisionTree":
        clf = BinaryRelevance(classifier=DecisionTreeClassifier(), require_dense = [False, True])
        #clf = ClassifierChain(classifier=DecisionTreeClassifier(), require_dense = [False, True])
    if test_type == "LogisticRegression":
        clf = BinaryRelevance(classifier=LogisticRegression(random_state=0), require_dense = [False, True])
        #clf = ClassifierChain(classifier=LogisticRegression(random_state=0), require_dense = [False, True])
    if test_type == "RandomForest": 
        clf = BinaryRelevance(classifier=RandomForestClassifier(criterion='entropy',max_depth= 50, min_samples_leaf= 1, min_samples_split= 3, n_estimators= 50), require_dense = [False, True])
        #clf = ClassifierChain(classifier=RandomForestClassifier(criterion='entropy',max_depth= 50, min_samples_leaf= 1, min_samples_split= 3, n_estimators= 50), require_dense = [False, True])
    if test_type == "MLPClassifier":
        clf = BinaryRelevance(classifier=MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu',solver='adam',random_state=1), require_dense = [False, True])
        #clf = ClassifierChain(classifier=MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu',solver='adam',random_state=1), require_dense = [False, True])
    if test_type == "MLkNN":
        clf = BinaryRelevance(MLkNN(k=3))
        #clf = ClassifierChain(classifier=MLkNN(k=3))

    #This three works without probability
    if test_type == "LinearSVC":
        clf = BinaryRelevance(classifier=LinearSVC(), require_dense = [False, True])
    if test_type == "GaussianNB":
        clf = BinaryRelevance(classifier=GaussianNB(), require_dense = [False, True])
    if test_type == "RidgeClassifierCV":
        clf = BinaryRelevance(classifier=RidgeClassifierCV(alphas=[1e-3, 1e-2, 1e-1, 1]), require_dense = [False, True]) 
    if test_type == "BRkNNaClassifier":
        clf = BinaryRelevance(BRkNNaClassifier(k=3))

        
    return clf

# %%
def save_metrics(y_true, y_pred, acc_ml,acc_score,zeroOne,pr_score,hamming_loss,jaccard_score_samples,jaccard_macro, modelMatrix, metrics_by_class, i, configurationTFIDF ,num_feature ,stop_word ,size_test,test_type):

    line=[] 
    # line to csv report file
    
    names = ['Google Common',
'Test',
'SO',
'IO',
'UI',
'Network',
'Security',
'OpenOffice Documents',
'Database',
'PDF',
'Logging',
'Latex']
    

    prec, rec, fscore, sup = precision_recall_fscore_support(y_true,y_pred, average='micro')


    arr = [acc_ml,acc_score,zeroOne,pr_score,hamming_loss,jaccard_score_samples,jaccard_macro,prec,rec, fscore]
    columns = ['Accuracy','Acc-Score','zero_one_loss','AUC-PR','hamming loss average','Jaccard samples','Jaccard macro','Precision','Recall','Fmeasure']
  
    df_metrics2 = pd.DataFrame([arr],columns=columns)
    print(df_metrics2)

    print("---------")
    print("")

    x = precision_recall_fscore_support(y_true,y_pred, average=None)
    print("")
    print("")

    df_metrics_by_class = pd.DataFrame.from_records(x, columns=names, index=['precision','recall','f-measure','samples_tested'])
    print(df_metrics_by_class)

    print("---------")
    print("")

    df_metrics2.to_csv(modelMatrix, encoding='utf-8', header=True, index=False, sep=',')    

    df_metrics_by_class.to_csv(metrics_by_class, encoding='utf-8', header=True, index=False, sep=',')    

    dataLine = ""
    dataLine = "tf-IDFMin, tf-IDFMax, #_TopTerms,Stop_Word,Train/Test_Size,Algorithm,Accuracy_Score,Accuracy_Score_not_normalized,zero_one_loss, AUC-PR,hamming_loss_avg,Jaccard_samples,Jaccard_macro,Precision,Recall,Fmeasure_Score, i"
    line.append((dataLine))
    dataLine =  str(configurationTFIDF) + "," + str(num_feature) + "," + stop_word + "," + str(size_test) + "," + str(test_type) + "," + str(acc_ml) + ","+ str(acc_score) + ","+ str(zeroOne) + "," + str(pr_score) + ","+ str(hamming_loss) + ","+ str(jaccard_score_samples) + ","+ str(jaccard_macro)+"," + str(prec)+","+str(rec)+","+str(fscore)+","+str(i) 
    line.append((dataLine))
    print(line)

    metrics = pd.DataFrame(line)
    metrics.to_csv('./experiment/report'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+str(i)+'.csv', encoding='utf-8', header=False, index=False, sep=',')    
    np.savetxt(r'./experiment/report'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+str(i)+'.txt', metrics.values, fmt='%s', delimiter=',')

    return prec, rec, fscore, sup

# %%
import datetime

def persist_data(configurationTFIDF ,num_feature , stop_word , size_test , test_type , acc_ml , 
           acc_score , zeroOne , pr_score, hamming_loss, jaccard_score_samples, 
           jaccard_macro , prec , rec, fscore, i):
    now = datetime.datetime.now()

    templateData = pd.read_csv(template, sep=',')
    
    print ("Current date and time : ")
    print (now.strftime("%Y-%m-%d %H:%M:%S"))
    headerdf = ['date_time','tf-IDF', '#_TopTerms','Stop_Word','Train/Test_Size','Algorithm','Accuracy_Score',
                'Accuracy_Score_not_normalized','zero_one_loss', 'AUC-PR','hamming_loss_avg','Jaccard_samples',
                'Jaccard_macro','Precision','Recall','Fmeasure_Score','i']


    tup = ( now,str(configurationTFIDF) ,str(num_feature) , stop_word , str(size_test) , str(test_type) , str(acc_ml) , 
           str(acc_score) , str(zeroOne) , str(pr_score) , str(hamming_loss) , str(jaccard_score_samples) , 
           str(jaccard_macro) , str(prec) , str(rec) , str(fscore) ,str(i))

    print("tupla:", tup)
    print(len(tup))

    list_tup  = [ now,str(configurationTFIDF) ,str(num_feature) , stop_word , str(size_test) , str(test_type) , str(acc_ml) , 
           str(acc_score) , str(zeroOne) , str(pr_score) , str(hamming_loss) , str(jaccard_score_samples) , 
           str(jaccard_macro) , str(prec) , str(rec) , str(fscore) ,str(i)]


    dfTeste = pd.DataFrame.from_records(data=[tup], columns=[headerdf])

    data_list = templateData.values.tolist()
    data_list.append(list_tup)
    new_data = pd.DataFrame(data_list)  
    for row in templateData.itertuples():
        print(row)

    new_data.to_csv('./experiment/dfTeste.csv', encoding='utf-8', index=False, sep=',', header=headerdf)

# %%
def run_split(data_classifier, test_type, confusionMatrix, modelMatrix, metrics_by_class, configurationTFIDF ,num_feature ,stop_word ,size_test):
    train = []
    test = []

    X = data_classifier

    rs = ShuffleSplit(n_splits=splits, test_size= size_test, random_state=52)
    rs.get_n_splits(X)

    for train_index, test_index in rs.split(X):
         #print("%s %s" % (train_index, test_index))
         train.append(train_index)
         test.append(test_index)
        
    for i in range(0, len(train)):
 
        size_features = len(X.columns)
        data = data_classifier.ix[train[i]]
        X_train = data.iloc[:,15:size_features]
        #del X_train['issueNumberissueNumber']
        y_train = data.loc[:,'Google Common':'Latex']

        data = data_classifier.ix[test[i]]
        X_test = data.iloc[:,15:size_features]
        y_test = data.loc[:,'Google Common':'Latex']

        categories = y_test.columns.values.tolist()
        ids = y_test.index

        classifier_setup = build_model(test_type)
    
        clf = classifier_setup
        clf.fit(X_train,y_train)

        predict = clf.predict(X_test).toarray()
        probability = clf.predict_proba(X_test).toarray()

        predictions = pd.DataFrame(predict, index=ids, columns=categories) # with header
        probabilities = pd.DataFrame(probability, index=ids, columns=categories) # with header

        y_pred = predictions.values
        y_proba = probabilities.values

        y_true = y_test.to_numpy()

        y_true, y_proba, y_pred, acc_ml, acc_score, zeroOne, fmeasure_score, pr_score, hamming_loss, jaccard_score_samples, jaccard_macro = eval_metrics(predictions, probabilities, y_test)

        plot_classes(probability, y_true, y_test)

        confusion_matrix(y_true, y_pred, confusionMatrix, i)
        
        prec, rec, fscore, sup = save_metrics(y_true, y_pred, acc_ml,acc_score,zeroOne,pr_score,hamming_loss,jaccard_score_samples,jaccard_macro, modelMatrix, metrics_by_class, i, configurationTFIDF ,num_feature ,stop_word ,size_test,test_type)

        persist_data(configurationTFIDF ,num_feature , stop_word , size_test , test_type , acc_ml , 
           acc_score , zeroOne , pr_score, hamming_loss, jaccard_score_samples, 
           jaccard_macro , prec , rec, fscore, i)

# %%
#number of shuffles (folds)
splits=10

#defining paths
loggingFile = './experiment//TitleBody3GramTFIDF.txt'
binaryBodyTitle = './experiment/binaryBodyTitle.csv'
template = './experiment/dfTeste.csv'

configurationTFIDFList = [(1,1)]
#configurationTFIDFList = [(1,1),(2,2),(3,3),(4,4)]
#num_featureList = [25,50,100,500,1000,2500,5000]
num_featureList = [900]
size_testList = [0.2]
#size_testList = [0.2,0.3,0.4]
stop_wordList = ["Yes"]
#test_typeList = ["RandomForest","DecisionTree","LogisticRegression","MLPClassifier","MLkNN"]
test_typeList = ["RandomForest"]

#examples
#configurationTFIDFList = [(1,1),(2,2)]
#num_featureList = [25,50]
#size_testList = [0.2,0.3]
#stop_wordList = ["Yes","No"]
#test_typeList = ["RandomForest","DecisionTree"]

configurationTFIDF=(1,1)
num_feature=25

size_test=0.2

#stop_word = stop_wordList[i]
stop_word = "Yes"

test_type = "RandomForest"
# dont forget to have the file dfTeste.csv ready in the files folder only with the header!

def __main__():

    # getting length of list 
    lengthT = len(configurationTFIDFList) 
    lengthF = len(num_featureList) 
    lengthS = len(size_testList)
    lengthY = len(test_typeList)
    
    # Iterating the index 
    # same as 'for i in range(len(list))' 
    for t in range(lengthT): 
        for f in range(lengthF): 
            for s in range(lengthS):
                for y in range(lengthY):
                    print("----------------") 
                    print(configurationTFIDFList[t]) 
                    print(num_featureList[f]) 
                    print(size_testList[s]) 
                    print(test_typeList[y]) 
                    print("----------------") 

                    configurationTFIDF=configurationTFIDFList[t]
                    num_feature=num_featureList[f]

                    size_test=size_testList[s]

                    #stop_word = stop_wordList[i]
                    stop_word = "Yes"

                    test_type = test_typeList[y]
                    
                    tfIDFoutputFile = './experiment/tfIDFoutputFile'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    classifierFeatureInput='./experiment/train_file_test'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    termFrequencyTop50 = './experiment/termFrequencyTop50'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    predictions_result = './experiment/predict_file_'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    probabilities_result = './experiment/probability_file_'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    modelMatrix = './experiment/modelMatrix'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    metrics_by_class = './experiment/metrics_By_Class'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'  
                    confusionMatrix = './experiment/CM'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)
                    

                    data_classes = organize()
                    categories, IssuePRDataset = filtering(data_classes)
                    data_test1 = dataset_config(IssuePRDataset)
                    data_test1 = clean_data(data_test1)
                    
                    re_stop_words = remove_stop_words()
                    data_test1['corpus'] = data_test1['corpus'].apply(removeStopWords, re_stop_words=re_stop_words)
                    data = data_test1
                    data_test1 = apply_stem(data)
                    run_tf_idf(data_test1, configurationTFIDF, num_feature, tfIDFoutputFile)
                    
                    docs = analyze_top(data_test1, termFrequencyTop50)
                    data_classifier, categories = merging(data_test1, tfIDFoutputFile)
                    run_split(data_classifier, test_type, confusionMatrix, modelMatrix, metrics_by_class, configurationTFIDF ,num_feature ,stop_word ,size_test)

# %%
__main__()
# Out:
# ----------------
# (1, 1)
# 900
# 0.2
# RandomForest
# ----------------
# 0                                                                       extract unifi gui action
# 1                                                                 advanc support journal abbrevi
# 2                                                                             increas save speed
# 3                                                                  featur right click text field
# 4                                                                                   doaj bibjson
# 5                                             improv dialog save discard chang exit better usabl
# 6                                                                                utf instead utf
# 7                                                                          proxi authent support
# 8                                                                     biblatex mode per file set
# 9                                                                     rate colum header descript
# 10                                                                       tooltip titl long field
# 11                                    gui click rank col header switch posit doi column entrytyp
# 12                                         move rank column move visual function still old place
# 13                                                main tabl right click doi field allow copi doi
# 14                                                                  open pdf file click pdf icon
# 15                                              add file link dialog open default file locat set
# 16                                                          defin altern field display main tabl
# 17                                                    add close other databas tab menu file menu
# 18                                                                    biblatex mode per file set
# 19                                                                 code problem entri entri type
# 20                                                                 code problem entri entri type
# 21                                            defin optim serial format variat drop reviv format
# 22                                                    highlightn stop work regular express activ
# 23                                                            cite command seem effect texstudio
# 24                                            defin optim serial format variat drop reviv format
# 25                                                           cannot insert refer list libreoffic
# 26                                                            acm fetcher cannot pars number hit
# 27                                                                 code problem entri entri type
# 28                                                                                   copi format
# 29                                                                                error open bib
# 30                                                                   ver comment written correct
# 31                                                                    write bib file format read
# 32                                                            hash pound sign caus url link fail
# 33                                                                find unlink file freez use pdf
# 34                                                                         move file sort button
# 35                                                           make bibtex biblatex mode file base
# 36                                            defin optim serial format variat drop reviv format
# 37                                                                   ver comment written correct
# 38                                                                    write bib file format read
# 39                                                                           reformat entri save
# 40                                                                                 keyword separ
# 41                                                                 entri editor tab remain field
# 42                                                                      urldownload vs getresult
# 43                                                                             error new databas
# 44                                                                      npe save reset save flag
# 45                                                                      cant export mysql jabref
# 46                                                 copi clipboard disabl everi field fieldeditor
# 47                                                                      cant export mysql jabref
# 48                                                        writeabl field caus rewrit whole entri
# 49                                                                                  organ prefer
# 50                                                                    cur brace ignor text citat
# 51                                                     openoffic manual connect click brows noth
# 52                                                                      chang case multipl refer
# 53                                              cleanup entri renam pdfs doesnt preserv key case
# 54                                                                         npe cleanup pdf renam
# 55                                                                                npe renam file
# 56                                                              reset prefer tool clear registri
# 57                                                 add test check pars jabref metadata group etc
# 58                                                                   key bind work preview panel
# 59                                                                find unlink file freez use pdf
# 60                                                           preview panel updat entri cut delet
# 61                                                               web search display name databas
# 62                                                              undo cut delet entri doesnt work
# 63                                                               web search display name databas
# 64                                                                                  tabl formatt
# 65                                                                field properti futur implement
# 66                                                                   click tab first field focus
# 67                                                                  size databas properti dialog
# 68                                            insert entri empti databas lead keycollisionexcept
# 69                                                               save action better field select
# 70                                                                  size databas properti dialog
# 71                                                                 error export endot ris format
# 72                                                                   dont catch except unit test
# 73                                                                     autoset link infinit loop
# 74                                                  immedi search increment search disabl option
# 75                                                              nicer serial databas bibtex mode
# 76                                                                     autoset link infinit loop
# 77                                                                             entri sort export
# 78                                                           npe getsortedentri export extern db
# 79                                                                          fix width file field
# 80                                                    render problem gtk look feel linux openjdk
# 81                                                                   gui blank ubuntu wake sleep
# 82                                                                         prefer open file open
# 83                                                                         unabl import ris file
# 84                                                                     normal bibtex name format
# 85                                                                         year sort doesnt work
# 86                                                           preview panel updat entri cut delet
# 87                                                       bibtextimport encod specifi importentri
# 88                                              file import current databas default still window
# 89                                                                  preserv capit umlaut cleanup
# 90                                        warn display use illeg unescap charact bibtex field eg
# 91                                                                         save file cannot read
# 92                                                                               structur import
# 93                                        warn display use illeg unescap charact bibtex field eg
# 94                                                               compil new custom import filter
# 95                                                          jstyle file improp handl quotat mark
# 96                                                                        cleanup renam pdf work
# 97                                                            code overwrit bibentryequ use test
# 98                                             entri tabl author name display partial first name
# 99                                                                        dialog enabl copi past
# 100                                                                         menu help onlin help
# 101                                                                         menu help onlin help
# 102                                         small issu regard new style select dialog libreoffic
# 103                                                                       view sort tab give npe
# 104                                                                 updat contribut local inform
# 105                                                                                open url work
# 106                                         small issu regard new style select dialog libreoffic
# 107                                                     updat bbtex key key fetch dialog display
# 108                                                              inconsist protect term behavior
# 109                                                                           error consol resiz
# 110                                          bug dev number element contain group alway shown as
# 111                                                                            unifi past action
# 112                                        file link contain blank broken non default viewer set
# 113                                                                      import pubm nbib format
# 114                                                              export html html code well form
# 115                                                                        posit variabl guiglob
# 116                                                       enhanc request repres chang case entri
# 117                                    auto download respect file pattern propos correct filenam
# 118                                                           author parser problem latex symbol
# 119                                                              code placement pars write logic
# 120                                                                 add auto updat develop build
# 121                                                           doi fetcher throw npe result found
# 122                                                                 backport remov splash screen
# 123                                                      entri editor miss chang autocomplet set
# 124                                                              remov comment insid bibtex code
# 125                                                           static group convert dynam one dev
# 126                                                                      import pubm nbib format
# 127                                                                           wrong number group
# 128                                                           export ms offic xml shorttitl miss
# 129                                                       implement getextens getdescript import
# 130                                                             keyword manag work comma delimit
# 131                                                      journal abbrevi dialog mock javafx port
# 132                                                                   search bar differ bib file
# 133                                                       featur request clickabl crossref field
# 134                                                    integr checker check odd number url field
# 135                                                                      add html unicod formatt
# 136                                                                               googleurlclean
# 137                                                                         caron render correct
# 138                                                               get bibtex data doi remov mark
# 139                                                              compil new custom import filter
# 140                                                                                 date formatt
# 141                                                                                 cleanup issn
# 142                                                                         b menu item translat
# 143                                                          libreoffic wrong number citat label
# 144                                                                            desir architectur
# 145                                                                            desir architectur
# 146                                                  instal add instal j instead icon instal app
# 147                                                      add setup icon instal j instal procedur
# 148                                                       latex command field display list refer
# 149                                                                    unrobust read bad comment
# 150                                                     import entri export bibtexml format fail
# 151                                                                              bibtexml syntax
# 152                                                                    newli open bib file focus
# 153                                                          cannot connect ot libreoffic ubuntu
# 154                                       ooplugin shouldnt permit cite public doesnt bibtex key
# 155                                                        pars write entri field contain broken
# 156                                                                big undo redo text status bar
# 157                                        concurrentmodificationexcept remov field sourc editor
# 158                                          isbn bibtex add word seiten biblatex pagetot number
# 159                                                       brace author editor name treat correct
# 160                                                                                      localis
# 161                                                      support relax author first name abbrevi
# 162                                                   biblatex export word xml date field export
# 163                                                 find duplic window add button open help file
# 164                                                                    arxiv fetcher seem broken
# 165                                              wrong tabl background color author editor field
# 166                                                  work directori set full path includ filenam
# 167                                                            url field vanish run check integr
# 168                                                         month field ascend descend sort swap
# 169                                                                              b gui draw issu
# 170                                                                     imposs set etalstr empti
# 171                                                                     imposs set etalstr empti
# 172                                                  open merg bibtex dialog multi monitor setup
# 173                   fulltext download dialog show doc latest select entri multipl time trigger
# 174                                                                       new databas mark chang
# 175                                                                      invalid bibtexkey freez
# 176                            key generat obtain lastnamelastnam wordsoftitlewithupperfirstlett
# 177                                          featur move file subfold articlebook file directori
# 178                                                       integr check report year consist numer
# 179                                                                integr check check field edit
# 180                                                            integr check extract checker file
# 181                                                                     add support citationstyl
# 182                                                                   ms offic xml import export
# 183                                                                     import export mod format
# 184                                                              use xmlunit xml comparison test
# 185                                                       keyword separ behaviour group perspect
# 186                                                                      featur hierarch keyword
# 187                                                                                keyword separ
# 188                                                            wrong error messag file directori
# 189                                                                         improv javafx dialog
# 190                                      url encod html charact shown violat regard integr check
# 191                                                                    toggl icon icon stay same
# 192                                                                    help point wrong web page
# 193                                                                month field brace result warn
# 194                                                                    action activ databas open
# 195                                                                 ris import work journal titl
# 196                                                                                   ris import
# 197                                                         local test refer nonexist gradl task
# 198                                                                  bad web search error messag
# 199                                                        shortcut copi url link name bibtexkey
# 200                                               main tabl right click doi field allow copi doi
# 201                                                                      perform issu new search
# 202                                                                             ignor updat work
# 203                                                                month field brace result warn
# 204                                                                regress unnecessari field tab
# 205                                                             import prefer dont set font size
# 206                         cannot import non xml prefer cannot import bibtex key generat prefer
# 207                                                                regress unnecessari field tab
# 208                                                       googl search issu version fix devbuild
# 209                                                  namespac jaxb reli intern java comsun class
# 210                                                                      perform issu new search
# 211                         cannot import non xml prefer cannot import bibtex key generat prefer
# 212                                                                      perform issu new search
# 213                                                empti modal error box save databas pars error
# 214                                                        ctrl doesnt trigger pars error messag
# 215                                                       investig xml export import test execut
# 216                                                                 new entri focus search activ
# 217                                                                          fosshub hack affect
# 218                                                     articl longer assign group via dragndrop
# 219                                                          subgroup longer creat use dragndrop
# 220                                                        matcheshighlight doensnt respect html
# 221                                                                         ad fetcher test fail
# 222                                                    memori leak brows bibtex file editor open
# 223                                                            clear bibtexkey nullpointerexcept
# 224                                         unexpect behaviour assign articl group use dragndrop
# 225                                                                        shortcut check integr
# 226                                  move default focus search main tabl better handl past entri
# 227                                                                          improv error consol
# 228                                                                          improv error consol
# 229                                                                  look full text arxiv broken
# 230                                                                           entri editor freez
# 231                                                         astrophys data system fetcher broken
# 232                                                              fetch medlin longer work enforc
# 233                                                              month field shown biblatex mode
# 234                                                                       proxi prefer work site
# 235                                                                      isbn bibtex fetch updat
# 236                                                                         collect usag statist
# 237                                                                   chang file permiss databas
# 238                                                      cannot complet save databas empti key s
# 239                                                        metadata lost reconnect share databas
# 240                                                       customiz drop menus general field gone
# 241                                                                     dblp fetcher seem broken
# 242                                             integr check report bibtex key fit expect scheme
# 243                                            reset prefer import prefer work custom entri type
# 244                                                               custom entri type freez jabref
# 245                                                              save custom entri type bib file
# 246                                                  refactor entri type custom entri type logic
# 247                                                                        custom entri type bug
# 248                                             biblatex cleanup move year month date field work
# 249                                                look full text document shortcut download all
# 250                                                                     better default save file
# 251                                              integr check report empti bibtexkey problem too
# 252                                                                month field brace result warn
# 253                                                                             latex code group
# 254                                                                       group name match wrong
# 255                                      remov entri select group remov entri similar name group
# 256                                              doi bibtex fail catch journaltitl sciencedirect
# 257                                                             add support biblatex field alias
# 258                                                                 wrong usag bibentri field id
# 259                                           relev read status cell doubl click behavior invert
# 260                                                                    add cleanup escap comment
# 261                                                                         bibtexml vs bibtexmp
# 262                                            integr check show wrong institut biblatex element
# 263                                        group name includ bracket space filter group anymor v
# 264                                                                               timestamp work
# 265                                                  group function requir lower case field name
# 266                                                       move file file directori overwrit file
# 267                                     move link file move file app directori set bib directori
# 268                                                   cleanup renam accord format move file sinc
# 269                                                           group interfac collaps subtre work
# 270                                                              doi url generat creat entri doi
# 271                                                              doi url generat creat entri doi
# 272                                                       arxiv fetcher cannot deal arxiv prefix
# 273                                                     escap sequenc display correct entri tabl
# 274                                                     escap sequenc display correct entri tabl
# 275                                                                 acm fetcher add junk databas
# 276                                                            forc shutdown accept extern chang
# 277                                                cannot edit dynam group regular express activ
# 278                                                  escap sequenc display correct entri preview
# 279                                  entri preview wrong display apostroph treat special charact
# 280                                                           import ris elsevi get journal name
# 281                                     repeat clean sign abstract field result give latex error
# 282                                     repeat clean sign abstract field result give latex error
# 283                                                                         possibl save databas
# 284                                                                     download articl doi titl
# 285                                                               latex unicod author field fail
# 286                                                       combin accent work unicod convert more
# 287                                                        switch latex unicod lib instead handl
# 288                                         clear rank rank tag bibtex remain rank instead remov
# 289                                                            replac common collect googl guava
# 290                                                           renam packag netsfjabref orgjabref
# 291                                               edit keyword clear prioriti rank qualiti relev
# 292                                                                           automat bug report
# 293                                                                   propos enhanc search group
# 294                                             goe mad click enabl save action databas properti
# 295                                                                   camel key doesnt seem work
# 296                                                  bibtex key pattern result dont match expect
# 297                          databas corrupt due incorrect ad delet subgroup group number exceed
# 298                                                                 cleanup window possibl resiz
# 299                                                                 cannot call texstudio jabref
# 300                                              cannot chang file folder download fulltext file
# 301                                                           keyword group updat new entri save
# 302                                                                   rememb group expans status
# 303                                                             import window display background
# 304                                                             integr plugin automat bug report
# 305                                                                      cant connect open offic
# 306                                                             add crossreforg sourc web search
# 307                                                   libreoffic plugin problem italic text titl
# 308                                                      add option clear log insid error consol
# 309                                                                 issu new group panel version
# 310                                                                 error consol updat new event
# 311                                                              lookup doi sometim freez jabref
# 312                               filenam field file annot tab small filenam exceed length field
# 313                                                           export ms offic xml author compani
# 314                                                                      featur hierarch keyword
# 315                                                                      improv architectur test
# 316                                                                               group issu osx
# 317                                      get fulltext find mani file use regexp year auth extens
# 318                 click get fulltext trigger null pointer except databs open current directori
# 319                                                              replac databas librari translat
# 320                 click get fulltext trigger null pointer except databs open current directori
# 321                                                         file annoat tab give npe pdf avaiabl
# 322                                                                        illeg file annot type
# 323                                                entri editor rework possibl enter date manual
# 324                                 use right click attch file open file dialog select directori
# 325                                                                   allow select multipl group
# 326                          msbibentri offic xml import export yearaccess monthaccess dayaccess
# 327                                                             allow resort group use drag drop
# 328                                                                       bibliograph field miss
# 329                                                dev snapshot master ebdjar display edit field
# 330                                                                     custom keybind view open
# 331                                         dblp fetcher negat oper longer work server side issu
# 332                                                           context menu file tabl general tab
# 333                                                         keybind except ctrl z shift sth work
# 334                                                                    way see relat articl link
# 335                                                                        command x work proper
# 336                                                      delet file entri editor delet file disk
# 337                                                look full text document shortcut download all
# 338                                                        shortcut copi url link name bibtexkey
# 339                                                               press escap close entri editor
# 340                                                              add menu option remov link file
# 341                                                                duplic finder ignor book edit
# 342                                                    entri editor trigger db chang event often
# 343                                      chang group edit entri editor longer mark databas dirti
# 344                                                                     autocomplet work perfect
# 345                                                        resiz window select file scale proper
# 346                                                                    add prefer migrat keybind
# 347                                                    string edit field updat match sourc field
# 348                                                 anyon test docbook export recent export fail
# 349                                 key bind delet tri delet whole entri file select general tab
# 350                                                     sao nasa ad plugin write garbag bib file
# 351                                          small font group panel entri editor high dpi screen
# 352                                                                     ad doi generat timestamp
# 353                                                     focus entri editor tab open entri editor
# 354                                                            tab get updat edit biblatex sourc
# 355                                        chang sourc tab save correct without switch anoth tab
# 356                                              sourc panel entri editor updat correct circumst
# 357                                                               move group work like add group
# 358                                         main tabl non updat proper newli assign articl group
# 359                                                                    releas unus heap frequent
# 360                                            check integr action filter option select none all
# 361                                                               miss normal bibtex name format
# 362                                                                          link file bad align
# 363                                                           general tab entri editor scrollabl
# 364                                                               sever problem new entri editor
# 365                                            call function export pdfs select entri new folder
# 366                                                         add prefer option disabl field valid
# 367                                                             valid messag display wrong posit
# 368                                               extern chang open entri sync back entri editor
# 369                                                                      protect term lead freez
# 370                                             protect term add select text bring previous list
# 371                                                               sever problem new entri editor
# 372                                                              cant remov move onlin file link
# 373                                                       undo entryeditor sourc tab lead except
# 374                                                               left right key work search bar
# 375                                        rewrit logic consist check requir option bibtex field
# 376                                delet group via group interfac remov group refer bibtex sourc
# 377                                                             latexeditor defunct drop support
# 378                                                                 lose hyphen prefix last name
# 379                                                  descript linkedfil sync bibtex code databas
# 380                                                                       renam file fail silent
# 381                                                           improv error handl renam link file
# 382                                                             except renam file main directori
# 383                                                                       import entri clipboard
# 384                                                        bibtexkey generat use crossref inform
# 385                                                                            jabr x exit clean
# 386                                                                           connect libreoffic
# 387                    pdf file highlight without comment file annot display n better leav empti
# 388                                                         unabl open folder case filenam space
# 389                                             cannot resolv textendash etc display articl titl
# 390                                               mous group titl inaccur group descript display
# 391                                                refresh button file annot tab refresh content
# 392                                                                         except open bib file
# 393                                                                          cite command employ
# 394                                                              filepath save window open linux
# 395                                                        automat set file link shortcut f work
# 396                                                         crossref websearch fail parser error
# 397                                                                          check integr status
# 398                                        npe save new databas entri databasechangemonitor null
# 399                                                              filepath save window open linux
# 400                                                             fatal error content allow prolog
# 401                                                    duplic field corrupt entri editor display
# 402                                           flag relev qualityassur cannot remov persist entri
# 403                                                               html code tooltip search field
# 404                                                                    auto creat group aux file
# 405                                                        java jdk compat block java jdk compat
# 406                                                            make fileannotationtab look great
# 407                                    indexoutofbound except chane entri type open entri editor
# 408                                                        check integr link entryeditor problem
# 409                                                    space charact caus cursor jump start line
# 410                                                         import acm digit librari hang select
# 411                                          citat preview increment increas memori usag preview
# 412                                                                  key generat fail pars colon
# 413                                                                    possibl delet attach file
# 414                                                         doubl click entri file list open pdf
# 415                               default set filenam format autolink file dont play nice togeth
# 416                                                               search box miss newest version
# 417                                                                extern group chang result npe
# 418                                          citat preview increment increas memori usag preview
# 419                                                      custom data type field techreport store
# 420                                              automat ad file link absolut instead relat path
# 421                                         perform problem new group search filter larg databas
# 422                                                                         miss dot file export
# 423                                                                  delet entri caus npe except
# 424                                                   colour item count group panel work reliabl
# 425                                                         latex textit reder correct main tabl
# 426                                  select new entri caus edit panel becom corrupt accept input
# 427                                                              npe exportfactori prevent start
# 428                                                              disabl autocomplet search field
# 429                                                                         miss dot file export
# 430                                                            export dialog unclear format list
# 431                                                             entri preview editor blank after
# 432                                                   biblatex export word xml date field export
# 433                                                      ris import ignor l full text link field
# 434                                                                          incorrect ris field
# 435                                                                          incorrect ris field
# 436                                                                  parameter test execut travi
# 437                                                                       chain modifi work case
# 438                                              delet disk default option select delet file tab
# 439                                  manual protect text case add around select text doesnt work
# 440                                                  find duplic mark differ book chapter duplic
# 441                                                                     magnifi chang color more
# 442                                                              save custom entri type bib file
# 443                                                                         bibtexml vs bibtexmp
# 444                                                              add cleanup oper replac ligatur
# 445                                                              rewrit entir journal list addit
# 446                                                                  menu bar wrong posit mac os
# 447                                                                      improv architectur test
# 448                                                                       improv ux main toolbar
# 449                      osx maintabl beta joptionpan load backup file startup show freez jabref
# 450                                             throw except start anoth languag miss fxml local
# 451                                                                    except tri save link file
# 452                                                                download longer show progress
# 453                                                                    except tri save link file
# 454                                                                    except tri save link file
# 455                                                         except entri editor brace dont match
# 456                                                                    magnifi chang color wrong
# 457                                                                         link file devonthink
# 458                                                                group fast access view option
# 459                                   remov file link general edit entri lead errnon doubl remov
# 460                                                                       fetcher messag mislead
# 461                                                        add proper way set extern applic push
# 462                                                   render problem gtk look feel linux openjdk
# 463                                                                group fast access view option
# 464                                                        url column miss maintabl beta version
# 465                                                           fetcher broken without anyon notic
# 466                                                              problem find fulltext ieeexplor
# 467                                                              problem find fulltext ieeexplor
# 468                                             featur suggest text file export find unlink file
# 469                                                                   ieee preview display month
# 470                                                                   ieee preview display month
# 471                                                                     add rfc standard fetcher
# 472                                                                               copi clipboard
# 473                                                              unabl launch overriden font set
# 474                                                                 still freez maco high sierra
# 475                                                               reimplement tooltip url column
# 476                                                              custom export filter cannot use
# 477                                                                     fetcher titl remov space
# 478                                                                       problem web search acm
# 479                                                                   featur request openssl sql
# 480                                                                                     cli work
# 481                                                                      overwrit exist key work
# 482                                                                  longer push citat texstudio
# 483                                                            entri editor produc constant load
# 484                                                                  comment shown entri preview
# 485                                                  ctrl open folder current directori bib file
# 486                                                  move next entri entri editor longer support
# 487                                                           singl word journal titl show alert
# 488                clean oper move file file field pdf field afterward longer open direct jabref
# 489                                         set better default window size maintabl beta version
# 490                                                                   ctrl f select search field
# 491                                                                  encod issu relat articl tab
# 492                                                               dev respect standard directori
# 493                                                                  name standard bibtex format
# ...
# 9
# PDF
# PDF,136
# PDF,136,2
# PDF,136,2,4
# PDF,136,2,4,0
# ['Label, TN, FP, FN, TP', 'Google Common,98,3,35,6', 'Test,96,6,35,5', 'SO,133,0,9,0', 'IO,9,39,6,88', 'UI,14,38,7,83', 'Network,97,4,33,8', 'Security,139,0,3,0', 'OpenOffice Documents,140,0,2,0', 'Database,137,0,5,0', 'PDF,136,2,4,0']
# 10
# Logging
# Logging,13
# Logging,13,46
# Logging,13,46,8
# Logging,13,46,8,75
# ['Label, TN, FP, FN, TP', 'Google Common,98,3,35,6', 'Test,96,6,35,5', 'SO,133,0,9,0', 'IO,9,39,6,88', 'UI,14,38,7,83', 'Network,97,4,33,8', 'Security,139,0,3,0', 'OpenOffice Documents,140,0,2,0', 'Database,137,0,5,0', 'PDF,136,2,4,0', 'Logging,13,46,8,75']
# 11
# Latex
# Latex,139
# Latex,139,0
# Latex,139,0,3
# Latex,139,0,3,0
# ['Label, TN, FP, FN, TP', 'Google Common,98,3,35,6', 'Test,96,6,35,5', 'SO,133,0,9,0', 'IO,9,39,6,88', 'UI,14,38,7,83', 'Network,97,4,33,8', 'Security,139,0,3,0', 'OpenOffice Documents,140,0,2,0', 'Database,137,0,5,0', 'PDF,136,2,4,0', 'Logging,13,46,8,75', 'Latex,139,0,3,0']
#    Accuracy  Acc-Score  zero_one_loss    AUC-PR  hamming loss average  \
# 0  0.105634         15       0.894366  0.667117              0.169014
#
#    Jaccard samples  Jaccard macro  Precision    Recall  Fmeasure
# 0          0.47272       0.479204   0.657568  0.638554  0.647922
# ---------
#
#
#
#                 Google Common       Test   SO         IO         UI  \
# precision            0.666667   0.454545  0.0   0.692913   0.685950
# recall               0.146341   0.125000  0.0   0.936170   0.922222
# f-measure            0.240000   0.196078  0.0   0.796380   0.786730
# samples_tested      41.000000  40.000000  9.0  94.000000  90.000000
#
#                   Network  Security  OpenOffice Documents  Database  PDF  \
# precision        0.666667       0.0                   0.0       0.0  0.0
# recall           0.195122       0.0                   0.0       0.0  0.0
# f-measure        0.301887       0.0                   0.0       0.0  0.0
# samples_tested  41.000000       3.0                   2.0       5.0  4.0
#
#                   Logging  Latex
# precision        0.619835    0.0
# recall           0.903614    0.0
# f-measure        0.735294    0.0
# samples_tested  83.000000    3.0
# ---------
#
# ['tf-IDFMin, tf-IDFMax, #_TopTerms,Stop_Word,Train/Test_Size,Algorithm,Accuracy_Score,Accuracy_Score_not_normalized,zero_one_loss, AUC-PR,hamming_loss_avg,Jaccard_samples,Jaccard_macro,Precision,Recall,Fmeasure_Score, i', '(1, 1),900,Yes,0.2,RandomForest,0.1056338028169014,15,0.8943661971830986,0.6671169098285499,0.16901408450704225,0.4727196512407781,0.47920433996383366,0.6575682382133995,0.6385542168674698,0.647921760391198,8']
# Current date and time :
# 2020-05-13 15:58:30
# tupla: (datetime.datetime(2020, 5, 13, 15, 58, 30, 869061), '(1, 1)', '900', 'Yes', '0.2', 'RandomForest', '0.1056338028169014', '15', '0.8943661971830986', '0.6671169098285499', '0.16901408450704225', '0.4727196512407781', '0.47920433996383366', '0.6575682382133995', '0.6385542168674698', '0.647921760391198', '8')
# 17
# Pandas(Index=0, date_time='2020-05-13 15:58:19.880684', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1619718309859155, Accuracy_Score_not_normalized=23, zero_one_loss=0.8380281690140845, _10=0.7266390940425825, hamming_loss_avg=0.16549295774647887, Jaccard_samples=0.5176838810641627, Jaccard_macro=0.5, Precision=0.6997518610421837, Recall=0.636568848758465, Fmeasure_Score=0.6666666666666666, i=0)
# Pandas(Index=1, date_time='2020-05-13 15:58:21.230550', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.09154929577464788, Accuracy_Score_not_normalized=13, zero_one_loss=0.908450704225352, _10=0.6547566295700364, hamming_loss_avg=0.18309859154929573, Jaccard_samples=0.4570701989716074, Jaccard_macro=0.4507042253521127, Precision=0.6464646464646465, Recall=0.5981308411214953, Fmeasure_Score=0.6213592233009709, i=1)
# Pandas(Index=2, date_time='2020-05-13 15:58:22.584590', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.09154929577464788, Accuracy_Score_not_normalized=13, zero_one_loss=0.9084507042253521, _10=0.6604420492601462, hamming_loss_avg=0.18368544600938969, Jaccard_samples=0.465118488710038, Jaccard_macro=0.4565972222222222, Precision=0.6261904761904762, Recall=0.6276849642004774, Fmeasure_Score=0.6269368295589989, i=2)
# Pandas(Index=3, date_time='2020-05-13 15:58:24.003014', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.11267605633802814, Accuracy_Score_not_normalized=16, zero_one_loss=0.8873239436619719, _10=0.6696846449252578, hamming_loss_avg=0.18192488262910805, Jaccard_samples=0.4681952828079589, Jaccard_macro=0.4645941278065631, Precision=0.6529126213592233, Recall=0.6169724770642202, Fmeasure_Score=0.6344339622641509, i=3)
# Pandas(Index=4, date_time='2020-05-13 15:58:25.343822', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.15492957746478872, Accuracy_Score_not_normalized=22, zero_one_loss=0.8450704225352113, _10=0.7086150660099813, hamming_loss_avg=0.16490610328638494, Jaccard_samples=0.5133998435054774, Jaccard_macro=0.5017730496453899, Precision=0.7110552763819096, Recall=0.6302895322939867, Fmeasure_Score=0.6682408500590319, i=4)
# Pandas(Index=5, date_time='2020-05-13 15:58:26.712769', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.13380281690140844, Accuracy_Score_not_normalized=19, zero_one_loss=0.8661971830985915, _10=0.6927218855213091, hamming_loss_avg=0.16784037558685447, Jaccard_samples=0.4994438855354349, Jaccard_macro=0.4892857142857143, Precision=0.6832917705735662, Recall=0.6327944572748267, Fmeasure_Score=0.6570743405275778, i=5)
# Pandas(Index=6, date_time='2020-05-13 15:58:28.112914', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1056338028169014, Accuracy_Score_not_normalized=15, zero_one_loss=0.8943661971830986, _10=0.6885316818401407, hamming_loss_avg=0.1766431924882629, Jaccard_samples=0.4898725687458082, Jaccard_macro=0.4783362218370884, Precision=0.6934673366834171, Recall=0.6065934065934065, Fmeasure_Score=0.6471277842907386, i=6)
# Pandas(Index=7, date_time='2020-05-13 15:58:29.447424', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1056338028169014, Accuracy_Score_not_normalized=15, zero_one_loss=0.8943661971830986, _10=0.620070275074966, hamming_loss_avg=0.18603286384976525, Jaccard_samples=0.4508076235188912, Jaccard_macro=0.4467713787085515, Precision=0.6168674698795181, Recall=0.6183574879227053, Fmeasure_Score=0.6176115802171291, i=7)
# Accuracy Score
# 0.11267605633802817
# ---------
#
# Accuracy Score not normalized
# 16
# ---------
#
# zero_one_loss
# 0.8873239436619719
# ---------
#
# Fmeasure Score
# 0.6352040816326531
# ---------
#
# AUC-PR
# 0.6345574033117757
# ---------
#
# hamming loss average
# 0.16784037558685447
# ---------
#
# Jaccard samples
# 0.4660798122065728
# ---------
#
# Jaccard macro
# 0.4654205607476635
# ---------
#
# Average precision score, micro-averaged over all classes: 0.63
# 0
# Google Common
# Google Common,96
# Google Common,96,7
# Google Common,96,7,30
# Google Common,96,7,30,9
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9']
# 1
# Test
# Test,97
# Test,97,4
# Test,97,4,33
# Test,97,4,33,8
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8']
# 2
# SO
# SO,133
# SO,133,2
# SO,133,2,6
# SO,133,2,6,1
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8', 'SO,133,2,6,1']
# 3
# IO
# IO,12
# IO,12,39
# IO,12,39,6
# IO,12,39,6,85
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8', 'SO,133,2,6,1', 'IO,12,39,6,85']
# 4
# UI
# UI,12
# UI,12,50
# UI,12,50,5
# UI,12,50,5,75
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8', 'SO,133,2,6,1', 'IO,12,39,6,85', 'UI,12,50,5,75']
# 5
# Network
# Network,108
# Network,108,2
# Network,108,2,26
# Network,108,2,26,6
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8', 'SO,133,2,6,1', 'IO,12,39,6,85', 'UI,12,50,5,75', 'Network,108,2,26,6']
# 6
# Security
# Security,138
# Security,138,0
# Security,138,0,4
# Security,138,0,4,0
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8', 'SO,133,2,6,1', 'IO,12,39,6,85', 'UI,12,50,5,75', 'Network,108,2,26,6', 'Security,138,0,4,0']
# 7
# OpenOffice Documents
# OpenOffice Documents,138
# OpenOffice Documents,138,0
# OpenOffice Documents,138,0,4
# OpenOffice Documents,138,0,4,0
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8', 'SO,133,2,6,1', 'IO,12,39,6,85', 'UI,12,50,5,75', 'Network,108,2,26,6', 'Security,138,0,4,0', 'OpenOffice Documents,138,0,4,0']
# 8
# Database
# Database,137
# Database,137,0
# Database,137,0,5
# Database,137,0,5,0
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8', 'SO,133,2,6,1', 'IO,12,39,6,85', 'UI,12,50,5,75', 'Network,108,2,26,6', 'Security,138,0,4,0', 'OpenOffice Documents,138,0,4,0', 'Database,137,0,5,0']
# 9
# PDF
# PDF,140
# PDF,140,0
# PDF,140,0,2
# PDF,140,0,2,0
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8', 'SO,133,2,6,1', 'IO,12,39,6,85', 'UI,12,50,5,75', 'Network,108,2,26,6', 'Security,138,0,4,0', 'OpenOffice Documents,138,0,4,0', 'Database,137,0,5,0', 'PDF,140,0,2,0']
# 10
# Logging
# Logging,18
# Logging,18,51
# Logging,18,51,8
# Logging,18,51,8,65
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8', 'SO,133,2,6,1', 'IO,12,39,6,85', 'UI,12,50,5,75', 'Network,108,2,26,6', 'Security,138,0,4,0', 'OpenOffice Documents,138,0,4,0', 'Database,137,0,5,0', 'PDF,140,0,2,0', 'Logging,18,51,8,65']
# 11
# Latex
# Latex,140
# Latex,140,0
# Latex,140,0,2
# Latex,140,0,2,0
# ['Label, TN, FP, FN, TP', 'Google Common,96,7,30,9', 'Test,97,4,33,8', 'SO,133,2,6,1', 'IO,12,39,6,85', 'UI,12,50,5,75', 'Network,108,2,26,6', 'Security,138,0,4,0', 'OpenOffice Documents,138,0,4,0', 'Database,137,0,5,0', 'PDF,140,0,2,0', 'Logging,18,51,8,65', 'Latex,140,0,2,0']
#    Accuracy  Acc-Score  zero_one_loss    AUC-PR  hamming loss average  \
# 0  0.112676         16       0.887324  0.634557               0.16784
#
#    Jaccard samples  Jaccard macro  Precision    Recall  Fmeasure
# 0          0.46608       0.465421   0.616337  0.655263  0.635204
# ---------
#
#
#
#                 Google Common       Test        SO         IO         UI  \
# precision            0.562500   0.666667  0.333333   0.685484   0.600000
# recall               0.230769   0.195122  0.142857   0.934066   0.937500
# f-measure            0.327273   0.301887  0.200000   0.790698   0.731707
# samples_tested      39.000000  41.000000  7.000000  91.000000  80.000000
#
#                 Network  Security  OpenOffice Documents  Database  PDF  \
# precision        0.7500       0.0                   0.0       0.0  0.0
# recall           0.1875       0.0                   0.0       0.0  0.0
# f-measure        0.3000       0.0                   0.0       0.0  0.0
# samples_tested  32.0000       4.0                   4.0       5.0  2.0
#
#                   Logging  Latex
# precision        0.560345    0.0
# recall           0.890411    0.0
# f-measure        0.687831    0.0
# samples_tested  73.000000    2.0
# ---------
#
# ['tf-IDFMin, tf-IDFMax, #_TopTerms,Stop_Word,Train/Test_Size,Algorithm,Accuracy_Score,Accuracy_Score_not_normalized,zero_one_loss, AUC-PR,hamming_loss_avg,Jaccard_samples,Jaccard_macro,Precision,Recall,Fmeasure_Score, i', '(1, 1),900,Yes,0.2,RandomForest,0.11267605633802817,16,0.8873239436619719,0.6345574033117757,0.16784037558685447,0.4660798122065728,0.4654205607476635,0.6163366336633663,0.6552631578947369,0.6352040816326531,9']
# Current date and time :
# 2020-05-13 15:58:32
# tupla: (datetime.datetime(2020, 5, 13, 15, 58, 32, 217853), '(1, 1)', '900', 'Yes', '0.2', 'RandomForest', '0.11267605633802817', '16', '0.8873239436619719', '0.6345574033117757', '0.16784037558685447', '0.4660798122065728', '0.4654205607476635', '0.6163366336633663', '0.6552631578947369', '0.6352040816326531', '9')
# 17
# Pandas(Index=0, date_time='2020-05-13 15:58:19.880684', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1619718309859155, Accuracy_Score_not_normalized=23, zero_one_loss=0.8380281690140845, _10=0.7266390940425825, hamming_loss_avg=0.16549295774647887, Jaccard_samples=0.5176838810641627, Jaccard_macro=0.5, Precision=0.6997518610421837, Recall=0.636568848758465, Fmeasure_Score=0.6666666666666666, i=0)
# Pandas(Index=1, date_time='2020-05-13 15:58:21.230550', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.09154929577464788, Accuracy_Score_not_normalized=13, zero_one_loss=0.9084507042253521, _10=0.6547566295700364, hamming_loss_avg=0.18309859154929573, Jaccard_samples=0.4570701989716074, Jaccard_macro=0.4507042253521127, Precision=0.6464646464646465, Recall=0.5981308411214953, Fmeasure_Score=0.6213592233009709, i=1)
# Pandas(Index=2, date_time='2020-05-13 15:58:22.584590', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.09154929577464788, Accuracy_Score_not_normalized=13, zero_one_loss=0.908450704225352, _10=0.6604420492601462, hamming_loss_avg=0.18368544600938969, Jaccard_samples=0.46511848871003797, Jaccard_macro=0.4565972222222222, Precision=0.6261904761904762, Recall=0.6276849642004774, Fmeasure_Score=0.6269368295589989, i=2)
# Pandas(Index=3, date_time='2020-05-13 15:58:24.003014', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.11267605633802814, Accuracy_Score_not_normalized=16, zero_one_loss=0.8873239436619719, _10=0.6696846449252578, hamming_loss_avg=0.18192488262910805, Jaccard_samples=0.4681952828079589, Jaccard_macro=0.4645941278065631, Precision=0.6529126213592233, Recall=0.6169724770642202, Fmeasure_Score=0.6344339622641509, i=3)
# Pandas(Index=4, date_time='2020-05-13 15:58:25.343822', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.15492957746478872, Accuracy_Score_not_normalized=22, zero_one_loss=0.8450704225352113, _10=0.7086150660099813, hamming_loss_avg=0.16490610328638494, Jaccard_samples=0.5133998435054774, Jaccard_macro=0.5017730496453899, Precision=0.7110552763819096, Recall=0.6302895322939867, Fmeasure_Score=0.6682408500590319, i=4)
# Pandas(Index=5, date_time='2020-05-13 15:58:26.712769', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.13380281690140844, Accuracy_Score_not_normalized=19, zero_one_loss=0.8661971830985915, _10=0.6927218855213091, hamming_loss_avg=0.16784037558685447, Jaccard_samples=0.4994438855354349, Jaccard_macro=0.4892857142857143, Precision=0.6832917705735662, Recall=0.6327944572748267, Fmeasure_Score=0.6570743405275778, i=5)
# Pandas(Index=6, date_time='2020-05-13 15:58:28.112914', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1056338028169014, Accuracy_Score_not_normalized=15, zero_one_loss=0.8943661971830986, _10=0.6885316818401407, hamming_loss_avg=0.1766431924882629, Jaccard_samples=0.4898725687458082, Jaccard_macro=0.4783362218370884, Precision=0.6934673366834171, Recall=0.6065934065934065, Fmeasure_Score=0.6471277842907386, i=6)
# Pandas(Index=7, date_time='2020-05-13 15:58:29.447424', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1056338028169014, Accuracy_Score_not_normalized=15, zero_one_loss=0.8943661971830986, _10=0.620070275074966, hamming_loss_avg=0.18603286384976525, Jaccard_samples=0.4508076235188912, Jaccard_macro=0.4467713787085515, Precision=0.6168674698795181, Recall=0.6183574879227053, Fmeasure_Score=0.6176115802171291, i=7)
# Pandas(Index=8, date_time='2020-05-13 15:58:30.869061', _2='(1, 1)', _3=900, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1056338028169014, Accuracy_Score_not_normalized=15, zero_one_loss=0.8943661971830986, _10=0.6671169098285499, hamming_loss_avg=0.16901408450704225, Jaccard_samples=0.4727196512407781, Jaccard_macro=0.4792043399638337, Precision=0.6575682382133995, Recall=0.6385542168674698, Fmeasure_Score=0.647921760391198, i=8)
