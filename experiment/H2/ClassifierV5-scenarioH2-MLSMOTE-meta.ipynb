# %%
import pandas as pd
import numpy as np
import csv 
import string
import nltk 
import re 
import time
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import os
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer
import sys
import warnings
from os import path
import ast
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from skmultilearn.problem_transform import BinaryRelevance
from skmultilearn.problem_transform import LabelPowerset
from skmultilearn.problem_transform import ClassifierChain
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, average_precision_score, precision_recall_fscore_support
from sklearn.metrics import accuracy_score
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import zero_one_loss
from sklearn.metrics import jaccard_score
import sklearn.metrics as skm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
import numpy as np
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import time
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from skmultilearn.adapt import MLkNN
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from skmultilearn.adapt import BRkNNaClassifier
from sklearn.linear_model import RidgeClassifierCV

pd.options.display.max_seq_items = 2000
pd.options.display.max_colwidth = 90
pd.options.display.max_rows = 999

loggingFile = './experiment//TitleBody3GramTFIDF.txt'
binaryBodyTitle = './experiment/binaryBodyTitle.csv'
template = './experiment/dfTeste.csv'

# %%
# -*- coding: utf-8 -*-
# Importing required Library
import numpy as np
import pandas as pd
import random
from sklearn.datasets import make_classification
from sklearn.neighbors import NearestNeighbors

# %%
def create_dataset(n_sample=1000):
    ''' 
    Create a unevenly distributed sample data set multilabel  
    classification using make_classification function
    
    args
    nsample: int, Number of sample to be created
    
    return
    X: pandas.DataFrame, feature vector dataframe with 10 features 
    y: pandas.DataFrame, target vector dataframe with 5 labels
    '''
    X, y = make_classification(n_classes=5, class_sep=2, 
                           weights=[0.1,0.025, 0.205, 0.008, 0.9], n_informative=3, n_redundant=1, flip_y=0,
                           n_features=10, n_clusters_per_class=1, n_samples=1000, random_state=10)
    y = pd.get_dummies(y, prefix='class')
    return pd.DataFrame(X), y

def get_tail_label(df):
    """
    Give tail label colums of the given target dataframe
    
    args
    df: pandas.DataFrame, target label df whose tail label has to identified
    
    return
    tail_label: list, a list containing column name of all the tail label
    """
    columns = df.columns
    n = len(columns)
    irpl = np.zeros(n)
    for column in range(n):
        irpl[column] = df[columns[column]].value_counts()[1]
    irpl = max(irpl)/irpl
    mir = np.average(irpl)
    tail_label = []
    for i in range(n):
        if irpl[i] > mir:
            tail_label.append(columns[i])
    return tail_label

def get_index(df):
  """
  give the index of all tail_label rows
  args
  df: pandas.DataFrame, target label df from which index for tail label has to identified
    
  return
  index: list, a list containing index number of all the tail label
  """
  tail_labels = get_tail_label(df)
  index = set()
  for tail_label in tail_labels:
    sub_index = set(df[df[tail_label]==1].index)
    index = index.union(sub_index)
  return list(index)

def get_minority_instace(X, y):
    """
    Give minority dataframe containing all the tail labels
    
    args
    X: pandas.DataFrame, the feature vector dataframe
    y: pandas.DataFrame, the target vector dataframe
    
    return
    X_sub: pandas.DataFrame, the feature vector minority dataframe
    y_sub: pandas.DataFrame, the target vector minority dataframe
    """
    index = get_index(y)
    X_sub = X[X.index.isin(index)].reset_index(drop = True)
    y_sub = y[y.index.isin(index)].reset_index(drop = True)
    return X_sub, y_sub

def nearest_neighbour(X):
    """
    Give index of 5 nearest neighbor of all the instance
    
    args
    X: np.array, array whose nearest neighbor has to find
    
    return
    indices: list of list, index of 5 NN of each element in X
    """
    nbs=NearestNeighbors(n_neighbors=5,metric='euclidean',algorithm='kd_tree').fit(X)
    euclidean,indices= nbs.kneighbors(X)
    return indices

def MLSMOTE(X,y, n_sample):
    """
    Give the augmented data using MLSMOTE algorithm
    
    args
    X: pandas.DataFrame, input vector DataFrame
    y: pandas.DataFrame, feature vector dataframe
    n_sample: int, number of newly generated sample
    
    return
    new_X: pandas.DataFrame, augmented feature vector data
    target: pandas.DataFrame, augmented target vector data
    """
    indices2 = nearest_neighbour(X)
    n = len(indices2)
    new_X = np.zeros((n_sample, X.shape[1]))
    target = np.zeros((n_sample, y.shape[1]))
    for i in range(n_sample):
        reference = random.randint(0,n-1)
        neighbour = random.choice(indices2[reference,1:])
        all_point = indices2[reference]
        nn_df = y[y.index.isin(all_point)]
        ser = nn_df.sum(axis = 0, skipna = True)
        target[i] = np.array([1 if val>2 else 0 for val in ser])
        ratio = random.random()
        gap = X.loc[reference,:] - X.loc[neighbour,:]
        new_X[i] = np.array(X.loc[reference,:] + ratio * gap)
    new_X = pd.DataFrame(new_X, columns=X.columns)
    target = pd.DataFrame(target, columns=y.columns)
    new_X = pd.concat([X, new_X], axis=0)
    target = pd.concat([y, target], axis=0)
    return new_X, target

# %%
#organizing data_frame to issue order
def organize():
    data_classes = pd.read_csv(binaryBodyTitle, header = 0, sep=";")
    data_classes

    del data_classes['prIssue']
    del data_classes['issueTitle']
    del data_classes['issueBody']

    data_classes.rename(columns={'issueComments': 'prComments','Comments': 'prCodeReviewComments','issueTitleLink': 'issueTitle','issueBodyLink': 'issueBody','issueCommentsLink': 'issue_Comments','pr': 'prNumber','issue': 'issueNumber', 'Title': 'prTitle','Body': 'prBody'}, inplace=True)
    categories = data_classes.columns.values.tolist()


    data_classes = data_classes[['issueNumber', 'prNumber', 'issueTitle', 'issueBody', 'issue_Comments',
                            'prTitle','prBody','prComments','prCodeReviewComments','commitMessage','isPR','isTrain',
                             'Google Common','Test','SO','IO','UI','Network','Security',
                            'OpenOffice Documents','Database','Utils','PDF','Logging','Latex']]

    data_classes['issueNumber'] = data_classes['issueNumber'].astype('Int64')
    
    return data_classes

# %%
#Filtering issues with PRs
def filtering(data_classes):
    IssuePRDataset = data_classes[data_classes["isTrain"] == 0]

    #invalid number of issue = NaN
    IssuePRDataset = IssuePRDataset.drop([1805])

    categories = IssuePRDataset.columns.values.tolist()
    
    return categories, IssuePRDataset

# %%
# RQ1.a - o quão sensível o resultado é em relação ao algoritmo? 
#vários algoritmos - BinaryRelevance
#todas as palavras, bootstrap, unigram 
#somente o título
def dataset_config(IssuePRDataset):
    #data_test1 = IssuePRDataset[['issueNumber','prNumber','issueBody','Google Common', 'Test', 'SO', 'IO', 'UI', 'Network', 'Security', 
    #                       'OpenOffice Documents', 'Database', 'Utils', 'PDF', 'Logging', 'Latex']].copy()

    data_test1 = IssuePRDataset[['issueNumber','prNumber','issueTitle','issueBody','Google Common', 'Test', 'SO', 'IO', 'UI', 'Network', 'Security', 
                           'OpenOffice Documents', 'Database', 'Utils', 'PDF', 'Logging', 'Latex']].copy()

    #data_test1["corpus"] = data_test1["issueBody"].map(str)
    #del data_test1["issueBody"]
    data_test1["corpus"] = data_test1["issueTitle"].map(str) + ' ' + data_test1["issueBody"].map(str)
    del data_test1["issueTitle"]
    del data_test1["issueBody"]


    #removing utils because we won't to predict a so simple API that is basically used in all PRs
    del data_test1["Utils"]

    data_test1 = data_test1.reset_index(drop=True)
    
    return data_test1

# %%
#preprocessing text

#We first convert the comments to lower-case 
#then use custom made functions to remove html-tags, punctuation and non-alphabetic characters from the TitleBody.

def clean_data(data_test1):
    if not sys.warnoptions:
        warnings.simplefilter("ignore")

    def cleanHtml(sentence):
        cleanr = re.compile('<.*?>')
        cleantext = re.sub(cleanr, ' ', str(sentence))
        return cleantext

    def cleanPunc(sentence): #function to clean the word of any punctuation or special characters
        cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
        cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
        cleaned = cleaned.strip()
        cleaned = cleaned.replace("\n"," ")
        return cleaned

    def keepAlpha(sentence):
        alpha_sent = ""
        for word in sentence.split():
            alpha_word = re.sub('[^a-z A-Z]+', ' ', word)
            alpha_sent += alpha_word
            alpha_sent += " "
        alpha_sent = alpha_sent.strip()
        return alpha_sent

    #function pra remover palavras com menos de 3 tokens

    data_test1['corpus'] = data_test1['corpus'].str.lower()
    data_test1['corpus'] = data_test1['corpus'].apply(cleanHtml)
    data_test1['corpus'] = data_test1['corpus'].apply(cleanPunc)
    data_test1['corpus'] = data_test1['corpus'].apply(keepAlpha)
    
    return data_test1

# %%
#### removing stopwords

def remove_stop_words():
    stop_words = set(stopwords.words('english'))
    stop_words.update(['pr','zero','one','two','three','four','five','six','seven','eight','nine','ten','may','also','across','among','beside','however','yet','within','jabref','org','github','com','md','https','ad','changelog','','joelparkerhenderson','localizationupd',' localizationupd','localizationupd ','i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the','Mr', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now'])
    #stop_words.update(['i', 'me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the","Mr", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"])

    re_stop_words = re.compile(r"\b(" + "|".join(stop_words) + ")\\W", re.I)

    return re_stop_words

# %%
def removeStopWords(sentence, re_stop_words):
    #global re_stop_words
    #print(sentence)
    return re_stop_words.sub(" ", sentence)

#removing words with less than 3 characters
#data_classes['titleBody'] = data_classes['titleBody'].str.findall('\w{3,}').str.join(' ')

# %%
def apply_stem(data_test1):
    stemmer = SnowballStemmer("english")
    
    def stemming(sentence):
        stemSentence = ""
        for word in sentence.split():
            stem = stemmer.stem(word)
            stemSentence += stem
            stemSentence += " "
        stemSentence = stemSentence.strip()
        return stemSentence
    
    data_test1['corpus'] = data_test1['corpus'].apply(stemming)
    print(data_test1['corpus'])
    
    return data_test1

# %%
#TF-ID
def run_tf_idf(data, configurationTFIDF, num_feature, tfIDFoutputFile):
    #we need to text max_feature with 10, 20, 25, 50 
    #, max_features=num_feature
    vectorizer = TfidfVectorizer(strip_accents='unicode', analyzer='word', ngram_range = configurationTFIDF, max_features=num_feature)
        
    tf_idf_results = vectorizer.fit_transform(data['corpus'])

    features = vectorizer.get_feature_names()

    #print(features)

    scores = (tf_idf_results.toarray())
    output_tf_idf = pd.DataFrame(scores)
    
    output_tf_idf = pd.concat([data['issueNumber'], output_tf_idf], axis=1)

    output_tf_idf.to_csv(tfIDFoutputFile, encoding='utf-8', header=False, index=False, sep=',')


    # remove words occuring less than 5 times
    #tfidf = TfidfVectorizer(min_df=5)
    #you can also remove common words:

    # remove words occuring in more than half the documents
    #tfidf = TfidfVectorizer(max_df=0.5)
    #you can also remove stopwords like this:

# %%
#analyzing frequency of TOP 50 terms

def analyze_top(data, termFrequencyTop50):
    docs = data['corpus'].tolist()

    cv = CountVectorizer()
    cv_fit=cv.fit_transform(docs)

    #print(cv.get_feature_names())
    #print(cv_fit.toarray())

    word_list = cv.get_feature_names()   

    count_list = cv_fit.toarray().sum(axis=0)
    term_frequency = dict(zip(word_list,count_list))

    a = sorted(term_frequency.items(), key=lambda x: x[1], reverse=True) 
    
    #print('SIZE OF TERMS', len(a))
    
    top50 = a[:100]
    df_frequency = pd.DataFrame(top50, columns =['term', 'frequency'])  

    #print(df_frequency)

    df_frequency.to_csv(termFrequencyTop50, encoding='utf-8', header=False, index=False, sep=',')

    sns.set(font_scale = 2)
    plt.figure(figsize=(18,17))
    plt.xticks(rotation=90)
    plt.title("Frequency of terms ")
    plt.ylabel('term', fontsize=20)
    plt.xlabel('frequency', fontsize=20)
    ax = sns.barplot(x="frequency", y="term", data=df_frequency)
    
    return docs

# %%
#merging features TF-IDF with data_frame
def merging(data_test1, tfIDFoutputFile):
    feature = pd.read_csv(tfIDFoutputFile, header=None, sep=",")
    feature.rename(columns={0: 'issueNumber'}, inplace=True)

    data_classifier = data_test1.join(feature, lsuffix='issueNumber', rsuffix='issueNumber')

    categories = data_classifier.columns.values.tolist()
    
    return data_classifier, categories

# %%
def eval_metrics(predictions, probabilities, y_test):
    
    y_pred = predictions.values
    y_proba = probabilities.values

    #receiving the y_test true value from each pull request
    y_true = y_test.to_numpy()

    print("Accuracy Score")
    acc_ml = accuracy_score(y_true, y_pred)
    print(acc_ml)

    print("---------")
    print("")

    print("Accuracy Score not normalized")
    acc_score = accuracy_score(y_true, y_pred, normalize=False)
    print(acc_score)

    print("---------")
    print("")

    print("zero_one_loss")
    zeroOne = zero_one_loss(y_true, y_pred)
    print(zeroOne)

    print("---------")
    print("")

    print("Fmeasure Score")
    fmeasure_score = f1_score(y_true,y_pred, average='micro')
    #fmeasure_score = f1_score(y_true,y_pred, average='macro')
    print(fmeasure_score)

    print("---------")
    print("")

    #AUC-PR
    print("AUC-PR")
    pr_score = average_precision_score(y_true,y_proba,average='micro')
    print(pr_score)
    #pr_score = average_precision_score(y_true,y_proba,average='macro')

    print("---------")
    print("")


    print("hamming loss average")
    hamming_loss = skm.hamming_loss(y_true, y_pred)
    print(hamming_loss)

    print("---------")
    print("")

    print("Jaccard samples")
    jaccard_score_samples = jaccard_score(y_true, y_pred, average='samples')
    print(jaccard_score_samples)

    print("---------")
    print("")


    print("Jaccard macro")
    jaccard_macro = jaccard_score(y_true, y_pred, average='micro')
    print(jaccard_macro)
    #jaccard_score(y_true, y_pred, average=None)

    print("---------")
    print("")

    return y_true, y_proba, y_pred, acc_ml, acc_score, zeroOne, fmeasure_score, pr_score, hamming_loss, jaccard_score_samples, jaccard_macro

# %%
def plot_classes(probability, y_true, y_test):
    precision = dict()
    recall = dict()
    average_precision = dict()

    n_classes = y_test.shape[1]

    for i in range(n_classes):
        precision[i], recall[i], _ = precision_recall_curve(y_true[:, i], probability[:, i])
        average_precision[i] = average_precision_score(y_true[:, i], probability[:, i])

    precision["micro"], recall["micro"], _ = precision_recall_curve(y_true.ravel(),probability.ravel())

    average_precision["micro"] = average_precision_score(y_true, probability, average="micro")

    print('Average precision score, micro-averaged over all classes: {0:0.2f}'
          .format(average_precision["micro"]))

    plt.figure()
    plt.step(recall['micro'], precision['micro'], where='post')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title(
        'Average precision score, micro-averaged over all classes: AP={0:0.2f}'
        .format(average_precision["micro"]))

# %%
import io
def confusion_matrix(y_true, y_pred, confusionMatrix, i):

    data = multilabel_confusion_matrix(y_true, y_pred)
    
    labels = ['Google Common', 'Test', 'SO', 'IO', 'UI', 'Network',
              'Security', 'OpenOffice Documents', 'Database','PDF',
              'Logging','Latex']
      
    metrics = pd.DataFrame()
    line = []
    dataLine = ""
    dataLine = "Label, TN, FP, FN, TP"
    line.append((dataLine))

    for j in range (0,12):
        print(j)
        row = data[j]
        dataLine=""
        dataLine = labels[j] 
        print(dataLine)
        for x in np.nditer(row):
            dataLine = dataLine + "," + str(x)
            print(dataLine)
        line.append((dataLine))
        print(line)
        
        metrics = pd.DataFrame(line)
    
    metrics.to_csv(confusionMatrix + str(i) +'.csv' , encoding='utf-8', header=True, index=False , sep=',')

# %%
#build the model 

def build_model(test_type):

    if test_type == "DecisionTree":
        clf = BinaryRelevance(classifier=DecisionTreeClassifier(), require_dense = [False, True])
        #clf = ClassifierChain(classifier=DecisionTreeClassifier(), require_dense = [False, True])
    if test_type == "LogisticRegression":
        clf = BinaryRelevance(classifier=LogisticRegression(random_state=0), require_dense = [False, True])
        #clf = ClassifierChain(classifier=LogisticRegression(random_state=0), require_dense = [False, True])
    if test_type == "RandomForest": 
        clf = BinaryRelevance(classifier=RandomForestClassifier(criterion='entropy',max_depth= 50, min_samples_leaf= 1, min_samples_split= 3, n_estimators= 50), require_dense = [False, True])
        #clf = ClassifierChain(classifier=RandomForestClassifier(criterion='entropy',max_depth= 50, min_samples_leaf= 1, min_samples_split= 3, n_estimators= 50), require_dense = [False, True])
    if test_type == "MLPClassifier":
        clf = BinaryRelevance(classifier=MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu',solver='adam',random_state=1), require_dense = [False, True])
        #clf = ClassifierChain(classifier=MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu',solver='adam',random_state=1), require_dense = [False, True])
    if test_type == "MLkNN":
        clf = BinaryRelevance(MLkNN(k=3))
        #clf = ClassifierChain(classifier=MLkNN(k=3))

    #This three works without probability
    if test_type == "LinearSVC":
        clf = BinaryRelevance(classifier=LinearSVC(), require_dense = [False, True])
    if test_type == "GaussianNB":
        clf = BinaryRelevance(classifier=GaussianNB(), require_dense = [False, True])
    if test_type == "RidgeClassifierCV":
        clf = BinaryRelevance(classifier=RidgeClassifierCV(alphas=[1e-3, 1e-2, 1e-1, 1]), require_dense = [False, True]) 
    if test_type == "BRkNNaClassifier":
        clf = BinaryRelevance(BRkNNaClassifier(k=3))

        
    return clf

# %%
def save_metrics(y_true, y_pred, acc_ml,acc_score,zeroOne,pr_score,hamming_loss,jaccard_score_samples,jaccard_macro, modelMatrix, metrics_by_class, i, configurationTFIDF ,num_feature ,stop_word ,size_test,test_type):

    line=[] 
    # line to csv report file
    
    names = ['Google Common',
'Test',
'SO',
'IO',
'UI',
'Network',
'Security',
'OpenOffice Documents',
'Database',
'PDF',
'Logging',
'Latex']
    

    prec, rec, fscore, sup = precision_recall_fscore_support(y_true,y_pred, average='micro')


    arr = [acc_ml,acc_score,zeroOne,pr_score,hamming_loss,jaccard_score_samples,jaccard_macro,prec,rec, fscore]
    columns = ['Accuracy','Acc-Score','zero_one_loss','AUC-PR','hamming loss average','Jaccard samples','Jaccard macro','Precision','Recall','Fmeasure']
  
    df_metrics2 = pd.DataFrame([arr],columns=columns)
    print(df_metrics2)

    print("---------")
    print("")

    x = precision_recall_fscore_support(y_true,y_pred, average=None)
    print("")
    print("")

    df_metrics_by_class = pd.DataFrame.from_records(x, columns=names, index=['precision','recall','f-measure','samples_tested'])
    print(df_metrics_by_class)

    print("---------")
    print("")

    df_metrics2.to_csv(modelMatrix, encoding='utf-8', header=True, index=False, sep=',')    

    df_metrics_by_class.to_csv(metrics_by_class, encoding='utf-8', header=True, index=False, sep=',')    

    dataLine = ""
    dataLine = "tf-IDFMin, tf-IDFMax, #_TopTerms,Stop_Word,Train/Test_Size,Algorithm,Accuracy_Score,Accuracy_Score_not_normalized,zero_one_loss, AUC-PR,hamming_loss_avg,Jaccard_samples,Jaccard_macro,Precision,Recall,Fmeasure_Score, i"
    line.append((dataLine))
    dataLine =  str(configurationTFIDF) + "," + str(num_feature) + "," + stop_word + "," + str(size_test) + "," + str(test_type) + "," + str(acc_ml) + ","+ str(acc_score) + ","+ str(zeroOne) + "," + str(pr_score) + ","+ str(hamming_loss) + ","+ str(jaccard_score_samples) + ","+ str(jaccard_macro)+"," + str(prec)+","+str(rec)+","+str(fscore)+","+str(i) 
    line.append((dataLine))
    print(line)

    metrics = pd.DataFrame(line)
    metrics.to_csv('./experiment/report'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+str(i)+'.csv', encoding='utf-8', header=False, index=False, sep=',')    
    np.savetxt(r'./experiment/report'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+str(i)+'.txt', metrics.values, fmt='%s', delimiter=',')

    return prec, rec, fscore, sup

# %%
import datetime

def persist_data(configurationTFIDF ,num_feature , stop_word , size_test , test_type , acc_ml , 
           acc_score , zeroOne , pr_score, hamming_loss, jaccard_score_samples, 
           jaccard_macro , prec , rec, fscore, i):
    now = datetime.datetime.now()

    templateData = pd.read_csv(template, sep=',')
    
    print ("Current date and time : ")
    print (now.strftime("%Y-%m-%d %H:%M:%S"))
    headerdf = ['date_time','tf-IDF', '#_TopTerms','Stop_Word','Train/Test_Size','Algorithm','Accuracy_Score',
                'Accuracy_Score_not_normalized','zero_one_loss', 'AUC-PR','hamming_loss_avg','Jaccard_samples',
                'Jaccard_macro','Precision','Recall','Fmeasure_Score','i']


    tup = ( now,str(configurationTFIDF) ,str(num_feature) , stop_word , str(size_test) , str(test_type) , str(acc_ml) , 
           str(acc_score) , str(zeroOne) , str(pr_score) , str(hamming_loss) , str(jaccard_score_samples) , 
           str(jaccard_macro) , str(prec) , str(rec) , str(fscore) ,str(i))

    print("tupla:", tup)
    print(len(tup))

    list_tup  = [ now,str(configurationTFIDF) ,str(num_feature) , stop_word , str(size_test) , str(test_type) , str(acc_ml) , 
           str(acc_score) , str(zeroOne) , str(pr_score) , str(hamming_loss) , str(jaccard_score_samples) , 
           str(jaccard_macro) , str(prec) , str(rec) , str(fscore) ,str(i)]


    dfTeste = pd.DataFrame.from_records(data=[tup], columns=[headerdf])

    data_list = templateData.values.tolist()
    data_list.append(list_tup)
    new_data = pd.DataFrame(data_list)  
    for row in templateData.itertuples():
        print(row)

    new_data.to_csv('./experiment/dfTeste.csv', encoding='utf-8', index=False, sep=',', header=headerdf)

# %%
def run_split(dataset_smote, test_type, confusionMatrix, modelMatrix, metrics_by_class, configurationTFIDF ,num_feature ,stop_word ,size_test):
    train = []
    test = []

    
    #our_X = data_classifier.iloc[:,16:916]
    #our_y = data_classifier.iloc[:,2:14]
    #dataset = pd.concat([our_y,our_X], axis=1)
    #dataset_smote = pd.concat([dataset, y_X_res], axis=0)
    
    #X = data_classifier
    X = dataset_smote
    splits = 10
    rs = ShuffleSplit(n_splits=splits, test_size= size_test, random_state=52)
    rs.get_n_splits(X)

    for train_index, test_index in rs.split(X):
         #print("%s %s" % (train_index, test_index))
         train.append(train_index)
         test.append(test_index)
        
    for i in range(0, len(train)):
 
        size_features = len(X.columns)
        #data = data_classifier.ix[train[i]]
        #data = data_classifier.iloc[train[i]]
        data = dataset_smote.iloc[train[i]]
        
        X_train = data.iloc[:,16:size_features]
        #X_train.to_csv('./experiment/X_train.csv', encoding='utf-8', index=False, sep=',')  
        #X_train1 = pd.concat([X_train, X_res])
        #X_train1.to_csv('./experiment/X_train1.csv', encoding='utf-8', index=False, sep=',') 
        #X_train1 = pd.read_csv('./experiment/X_train1.csv', sep=',')
        
        #X_train1.reset_index(inplace=True)
        #X_train1.drop(X_train1.index[[752,564]], inplace=True)
        
        #del X_train['issueNumberissueNumber']
        y_train = data.loc[:,'Google Common':'Latex']
        #y_train.to_csv('./experiment/y_train.csv', encoding='utf-8', index=False, sep=',')  

        #y_train1 = pd.concat([y_train, y_res])
        #y_train1 = y_train1.fillna(lambda x: x.median())
        #y_train1 = np.array(y_train, dtype=float)
        
        #y_train1.to_csv('./experiment/y_train1.csv', encoding='utf-8', index=False, sep=',')  
        #y_train1 = pd.read_csv('./experiment/y_train1.csv', sep=',')
                               
        #y_train1.reset_index(inplace=True)

        #y_train1.replace([np.inf, -np.inf], 0)

        #y_train1.dropna(inplace=True)

        #y_train1.dropna(axis=1)

        #X_train1.replace([np.inf, -np.inf], np.nan)
        
        #X_train.fillna(0)

        #X_train1.dropna(inplace=True)

        #X_train1.dropna(axis=1)
        
        #X_train1.to_csv('./experiment/X_train1_clear.csv', encoding='utf-8', index=False, sep=',') 


        #data = data_classifier.ix[test[i]]
        #data = data_classifier.iloc[test[i]]
        data = dataset_smote.iloc[test[i]]
        X_test = data.iloc[:,16:size_features]
        y_test = data.loc[:,'Google Common':'Latex']

        categories = y_test.columns.values.tolist()
        ids = y_test.index

        classifier_setup = build_model(test_type)
    
        clf = classifier_setup
        clf.fit(X_train,y_train)

        predict = clf.predict(X_test).toarray()
        probability = clf.predict_proba(X_test).toarray()

        predictions = pd.DataFrame(predict, index=ids, columns=categories) # with header
        probabilities = pd.DataFrame(probability, index=ids, columns=categories) # with header

        y_pred = predictions.values
        y_proba = probabilities.values

        y_true = y_test.to_numpy()

        y_true, y_proba, y_pred, acc_ml, acc_score, zeroOne, fmeasure_score, pr_score, hamming_loss, jaccard_score_samples, jaccard_macro = eval_metrics(predictions, probabilities, y_test)

        plot_classes(probability, y_true, y_test)

        confusion_matrix(y_true, y_pred, confusionMatrix, i)
        
        prec, rec, fscore, sup = save_metrics(y_true, y_pred, acc_ml,acc_score,zeroOne,pr_score,hamming_loss,jaccard_score_samples,jaccard_macro, modelMatrix, metrics_by_class, i, configurationTFIDF ,num_feature ,stop_word ,size_test,test_type)

        persist_data(configurationTFIDF ,num_feature , stop_word , size_test , test_type , acc_ml , 
           acc_score , zeroOne , pr_score, hamming_loss, jaccard_score_samples, 
           jaccard_macro , prec , rec, fscore, i)

# %%
#number of shuffles (folds)
splits=10

#defining paths
loggingFile = './experiment//TitleBody3GramTFIDF.txt'
binaryBodyTitle = './experiment/binaryBodyTitle.csv'
template = './experiment/dfTeste.csv'

configurationTFIDFList = [(1,1)]
#configurationTFIDFList = [(1,1),(2,2),(3,3),(4,4)]
#num_featureList = [25,50,100,500,1000,2500,5000]
num_featureList = [895]
size_testList = [0.2]
#size_testList = [0.2,0.3,0.4]
stop_wordList = ["Yes"]
#test_typeList = ["RandomForest","DecisionTree","LogisticRegression","MLPClassifier","MLkNN"]
test_typeList = ["RandomForest"]

#examples
#configurationTFIDFList = [(1,1),(2,2)]
#num_featureList = [25,50]
#size_testList = [0.2,0.3]
#stop_wordList = ["Yes","No"]
#test_typeList = ["RandomForest","DecisionTree"]

configurationTFIDF=(1,1)
num_feature=895

size_test=0.2

#stop_word = stop_wordList[i]
stop_word = "Yes"

test_type = "RandomForest"
# dont forget to have the file dfTeste.csv ready in the files folder only with the header!

def __main__():

    # getting length of list 
    lengthT = len(configurationTFIDFList) 
    lengthF = len(num_featureList) 
    lengthS = len(size_testList)
    lengthY = len(test_typeList)
    
    # Iterating the index 
    # same as 'for i in range(len(list))' 
    for t in range(lengthT): 
        for f in range(lengthF): 
            for s in range(lengthS):
                for y in range(lengthY):
                    print("----------------") 
                    print(configurationTFIDFList[t]) 
                    print(num_featureList[f]) 
                    print(size_testList[s]) 
                    print(test_typeList[y]) 
                    print("----------------") 

                    configurationTFIDF=configurationTFIDFList[t]
                    num_feature=num_featureList[f]

                    size_test=size_testList[s]

                    #stop_word = stop_wordList[i]
                    stop_word = "Yes"

                    test_type = test_typeList[y]
                    
                    tfIDFoutputFile = './experiment/tfIDFoutputFile'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    classifierFeatureInput='./experiment/train_file_test'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    termFrequencyTop50 = './experiment/termFrequencyTop50'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    predictions_result = './experiment/predict_file_'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    probabilities_result = './experiment/probability_file_'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    modelMatrix = './experiment/modelMatrix'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    metrics_by_class = './experiment/metrics_By_Class'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'  
                    confusionMatrix = './experiment/CM'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)
                    

                    data_classes = organize()
                    categories, IssuePRDataset = filtering(data_classes)
                    data_test1 = dataset_config(IssuePRDataset)
                    data_test1 = clean_data(data_test1)
                    
                    re_stop_words = remove_stop_words()
                    data_test1['corpus'] = data_test1['corpus'].apply(removeStopWords, re_stop_words=re_stop_words)
                    data = data_test1
                    data_test1 = apply_stem(data)
                    run_tf_idf(data_test1, configurationTFIDF, num_feature, tfIDFoutputFile)
                    
                    docs = analyze_top(data_test1, termFrequencyTop50)
                    data_classifier, categories = merging(data_test1, tfIDFoutputFile)
                    #SMOTE
                    our_X = data_classifier.iloc[:,16:916]
                    our_y = data_classifier.iloc[:,2:14]
                    dataset = pd.concat([our_y,our_X], axis=1)
                    #dataset.shape

                    X_sub, y_sub = get_minority_instace(our_X, our_y)   #Getting minority instance of that datframe
                    X_res,y_res =MLSMOTE(X_sub, y_sub, 100)     #Applying MLSMOTE to augment the dataframe
                    
                    y_X_res = pd.concat([y_res,X_res], axis=1)
                    #y_X_res.shape

                    dataset_smote = pd.concat([dataset, y_X_res], axis=0)
                    #dataset_smote.shape  
                    
                    #run_split(data_classifier, test_type, confusionMatrix, modelMatrix, metrics_by_class, configurationTFIDF ,num_feature ,stop_word ,size_test)
                    run_split(dataset_smote, test_type, confusionMatrix, modelMatrix, metrics_by_class, configurationTFIDF ,num_feature ,stop_word ,size_test)

# %%
__main__()
# Out:
# ----------------
# (1, 1)
# 895
# 0.2
# RandomForest
# ----------------
# 0      extract unifi gui action question reduc clutter caus inlin classesth class guiactionpa...
# 1      advanc support journal abbrevi mani export bibtex file eg dblp acm contain journal con...
# 2      increas save speed bugfix introduc clone oper take much time save databas entri check ...
# 3      featur right click text field possibl access case changer right click text field would...
# 4      doaj bibjson found directori open access journal provid api search return result bibjs...
# 5      improv dialog save discard chang exit better usabl room improv save chang exitfirst op...
# 6      utf instead utf discuss switch utf utf netsfjabrefimporteropendatabaseactiontestdefaul...
# 7      proxi authent support still support proxi authent unfortun usernam password specifi co...
# 8      biblatex mode per file set current global set control whatev use biblatex mode usual u...
# 9      rate colum header descript add descript especi sinc click insid column alway open rate...
# 10     tooltip titl long field ad tooltip know mean column headtitl r r q f p obvious field d...
# 11     gui click rank col header switch posit doi column entrytyp discov strang behavior clic...
# 12     move rank column move visual function still old place move rank column end entri tabl ...
# 13     main tabl right click doi field allow copi doi current popup doi allow click doi possi...
# 14                                                              open pdf file click pdf icon nan
# 15                                          add file link dialog open default file locat set nan
# 16     defin altern field display main tabl current entri author noth shown author column mai...
# 17     add close other databas tab menu file menu similar ide close open databas continu work...
# 18     biblatex mode per file set current global set control whatev use biblatex mode usual u...
# 19     code problem entri entri type problem entri entri type handl moment see background cur...
# 20     code problem entri entri type problem entri entri type handl moment see background cur...
# 21     defin optim serial format variat drop reviv format introduc follow new featur chang se...
# 22                                               highlightn stop work regular express activ grab
# 23     cite command seem effect texstudio configur cite command citep texstudio seem ignor se...
# 24     defin optim serial format variat drop reviv format introduc follow new featur chang se...
# 25     cannot insert refer list libreoffic use latest master build libreoffic ubuntu x connec...
# 26     acm fetcher cannot pars number hit search acm matter get follow error javaioioexcept c...
# 27     code problem entri entri type problem entri entri type handl moment see background cur...
# 28     copi format would great could right click refer copi refer format select style someth ...
# 29     error open bib helloi updat v open bibtex databas attach got error messag attach know ...
# 30     ver comment written correct file start bibtex item eg articl xxxxxx author xxxxxxxx us...
# 31     write bib file format read preambl field present omit newlin line preced encod line sa...
# 32     hash pound sign caus url link fail enter url url field url main tabl page click url do...
# 33     find unlink file freez use pdf use find unlink file work scan directori work fine pres...
# 34     move file sort button current offer sort save chang sort demandth sort function move s...
# 35     make bibtex biblatex mode file base bibtex biblatex mode store file avail detect bibda...
# 36     defin optim serial format variat drop reviv format introduc follow new featur chang se...
# 37     ver comment written correct file start bibtex item eg articl xxxxxx author xxxxxxxx us...
# 38     write bib file format read preambl field present omit newlin line preced encod line sa...
# 39     reformat entri save would like abil reformat entri bib file sinc otherwis whole entri ...
# 40     keyword separ possibl specifi keyword separ automat generat group method bibentri assu...
# 41     entri editor tab remain field moment bibtexentri requir option field remain field seen...
# 42     urldownload vs getresult current way fetch text internet urldownload getresult logicne...
# 43     error new databas except thread awt eventqueu javautilnosuchelementexcept valu present...
# 44     npe save reset save flag ive got npe save investig thread level logger msg n javalangn...
# 45     cant export mysql im use mysql cant export bib sql databas fine use dont know whyth er...
# 46                               copi clipboard disabl everi field fieldeditor avail text select
# 47     cant export mysql im use mysql cant export bib sql databas fine use dont know whyth er...
# 48     writeabl field caus rewrit whole entri entri unmark field markedentri remov field shor...
# 49     organ prefer current entri prefer follow pseudo model class preferenceentri string key...
# 50     cur brace ignor text citat refer manual softwar titl author develop team year version ...
# 51     openoffic manual connect click brows noth set libr ofifc connect around notic brows no...
# 52     chang case multipl refer dont know relev want chang case titl server refer need right ...
# 53     cleanup entri renam pdfs doesnt preserv key case filenam link pdf convert lowercas out...
# 54     npe cleanup pdf renam master abi follow bib entri articl mlu author ralph mietzner fra...
# 55     npe renam file v dev master abiv search entri lost somehow grab im drop pdf onto previ...
# 56     reset prefer tool clear registri notic use differ version time load differ file mean d...
# 57     add test check pars jabref metadata group etc add test bibtexparsertest make sure brea...
# 58     key bind work preview panel key bind print preview work introduc key bind copi preview...
# 59     find unlink file freez use pdf use find unlink file work scan directori work fine pres...
# 60     preview panel updat entri cut delet entri cut delet preview panel updatedtest current ...
# 61     web search display name databas current web search fetch arxivorg fetch inspir display...
# 62     undo cut delet entri doesnt work somehow entri restor undo cut delet entri thought mes...
# 63     web search display name databas current web search fetch arxivorg fetch inspir display...
# 64     tabl formatt issu summar avail formattersth aim improv name descriptionsi think practi...
# 65     field properti futur implement base earlier discuss eg koppor koppor seem make sens re...
# 66     click tab first field focus click tab edit part expect focus first editor field curren...
# 67     size databas properti dialog size databas properti dialog fix open dialog first time s...
# 68     insert entri empti databas lead keycollisionexcept dev snapshot master f window delet ...
# 69     save action better field select save sort order dialog select field would expect choic...
# 70     size databas properti dialog size databas properti dialog fix open dialog first time s...
# 71     error export endot ris format version avail box window dev snapshot master oper system...
# 72     dont catch except unit test unit test catch except call method call fail nasti disadva...
# 73                       autoset link infinit loop take age machin cancel still valid result set
# 74     immedi search increment search disabl option version onward includ win enterpris searc...
# 75     nicer serial databas bibtex mode switch bibtex mode write comment meta databas type bi...
# 76                       autoset link infinit loop take age machin cancel still valid result set
# 77     entri sort export version dev snapshot master f f cec ubuntu tri export databas differ...
# 78     npe getsortedentri export extern db dev master commit ed b b fd b f b cdcreproducables...
# 79                                                       fix width file field grab request stekk
# 80     render problem gtk look feel linux openjdk system ubuntu linux version generic buildd ...
# 81     gui blank ubuntu wake sleep monitor goe ubuntu goe sleep log user interfac look like g...
# 82     prefer open file open version dev snapshot master cf window step reproduc close open f...
# 83     unabl import ris file version window x dev snapshot master cf window cannot import ris...
# 84     normal bibtex name format rightclick formatt author field goe wrongminim exampl stefan...
# 85                               year sort doesnt work click year column doesnt affect sort tabl
# 86     preview panel updat entri cut delet entri cut delet preview panel updatedtest current ...
# 87     bibtextimport encod specifi importentri notic encod issu run gradlew check commandlin ...
# 88     file import current databas default still window version step reproduc file import cur...
# 89     preserv capit umlaut cleanup gypten titl field result gypten correct syntax result pdf...
# 90     warn display use illeg unescap charact bibtex field eg version step reproduc believ ht...
# 91     save file cannot read base discuss creat empti databas singl entri singl field contain...
# 92     structur import discov might problem intellij restructur import vs eclips run problem ...
# 93     warn display use illeg unescap charact bibtex field eg version step reproduc believ ht...
# 94     compil new custom import filter hi save simplecsvimporterjava compileallbat togeth ins...
# 95     jstyle file improp handl quotat mark version window step reproduc use citat file renam...
# 96     cleanup renam pdf work version linux work least step reproduc entri link pdf use clean...
# 97     code overwrit bibentryequ use test equal method bibentri overwritten compar entri base...
# 98     entri tabl author name display partial first name jar dev snapshot master f e jarlinux...
# 99     dialog enabl copi past version avail box dev snapshot master e f oper system version w...
# 100    menu help onlin help current help access menu help helpi think obvious user help henc ...
# 101    menu help onlin help current help access menu help helpi think obvious user help henc ...
# 102    small issu regard new style select dialog libreoffic version ubuntu new style dialog b...
# 103    view sort tab give npe version ced aefba e f b fdb ec master win x java step reproduc ...
# 104                                          updat contribut local inform see use gradl task now
# 105    open url work version dev window step reproduc creat entri url field simpler url like ...
# 106    small issu regard new style select dialog libreoffic version ubuntu new style dialog b...
# 107    updat bbtex key key fetch dialog display version master window x doent updat display b...
# 108    inconsist protect term behavior version osx step reproduc creat new bibtex databas add...
# 109               error consol resiz window show error consol window program output resizableref
# 110    bug dev number element contain group alway shown version dev snapshot master window bu...
# 111                                                                        unifi past action nan
# 112    file link contain blank broken non default viewer set version window upgrad version fi...
# 113    import pubm nbib format import pubm nbib format would nice addit importersa exampl see...
# 114    export html html code well form dev snapshot master f ewindow amd step reproduc take b...
# 115    posit variabl guiglob current architectur analysi stumbl part code id like discuss inf...
# 116    enhanc request repres chang case entri version os agnosticrecommend chang right click ...
# 117            auto download respect file pattern propos correct filenam current renam bibtexkey
# 118    author parser problem latex symbol author h e l grave e ne fiaux shown fiaux entri pre...
# 119    code placement pars write logic right pars serial handl uniform way see eg possibl des...
# 120       add auto updat develop build view regular releas schedul would nice perform auto updat
# 121    doi fetcher throw npe result found dev version window step reproduc entri doi fetcher ...
# 122                                                             backport remov splash screen nan
# 123    entri editor miss chang autocomplet set use releas bit window pro x java disabl autoco...
# 124    remov comment insid bibtex code lenhard intend thought keep sourc possibl tex author a...
# 125    static group convert dynam one dev version dev snapshot master f window issu found ver...
# 126    import pubm nbib format import pubm nbib format would nice addit importersa exampl see...
# 127    wrong number group version windowsxp know know thing happen ubuntu group display wrong...
# 128    export ms offic xml shorttitl miss version window export ms offic xml short titl infor...
# 129    implement getextens getdescript import follow method getextens getdescript implement a...
# 130    keyword manag work comma delimit run v window computerfor conveni practic reason use s...
# 131    journal abbrevi dialog mock javafx port want port journal abbrevi dialog javafx play d...
# 132    search bar differ bib file bug rather question user behaviorjabref construct work seve...
# 133    featur request clickabl crossref field click bibtex key crossref field lead parent par...
# 134    integr checker check odd number url field window x enter follow entri run integr check...
# 135      add html unicod formatt add html unicod formatt cleanup save action oscargus someth you
# 136    googleurlclean imho benefit googleurlcleanerjava clear extra action rightclick context...
# 137    caron render correct version mint escap charact v caron render proper main panel hand ...
# 138    get bibtex data doi remov mark right click mark entri main tabl success updat bibtex d...
# 139    compil new custom import filter hi save simplecsvimporterjava compileallbat togeth ins...
# 140    date formatt use biblatex format would like possibl date formatt could similar alreadi...
# 141    cleanup issn new issn integr check found issn miss dash db exampl x insead x would nic...
# 142    b menu item translat glitch b present beta menu item file save select plain bibtex loc...
# 143    libreoffic wrong number citat label version mac os x libreoffic step reproduc connect ...
# 144    desir architectur follow discuss today devcal come outlin desir high level architectur...
# 145    desir architectur follow discuss today devcal come outlin desir high level architectur...
# 146             instal add instal j instead icon instal app cloudentcom asset c b f f e f bb png
# 147                add setup icon instal j instal procedur creat instal icon use instal uninstal
# 148    latex command field display list refer version linux mageia step reproduc creat entri ...
# 149    unrobust read bad comment version got bib file comment clean couldnt read error open f...
# 150    import entri export bibtexml format fail versionjabref window amd java step reproduc s...
# 151    bibtexml syntax bibtexmlimport accept xml file tag syntax like otherwis read data even...
# 152    newli open bib file focus version step reproduc prerequisit regist default applic bib ...
# 153    cannot connect ot libreoffic ubuntu problem connect libreoffic use problem dev snapsho...
# 154    ooplugin shouldnt permit cite public doesnt bibtex key use libreoffic insert refer ent...
# 155    pars write entri field contain broken version devstep reproduc use charact field entri...
# 156    big undo redo text status bar advanc undo redo messag quit nice think realiz shown sta...
# 157    concurrentmodificationexcept remov field sourc editor version latest dev cento window ...
# 158    isbn bibtex add word seiten biblatex pagetot number version window x isbn bibtex fetch...
# 159    brace author editor name treat correct version window corpor author editor input cur b...
# 160    localis persian local persian file current directori directori chines local recent upd...
# 161    support relax author first name abbrevi version latest devstep reproduc use relax spec...
# 162    biblatex export word xml date field export window amd java import recogn year biblatex...
# 163    find duplic window add button open help file help page describ featur find duplic help...
# 164                              arxiv fetcher seem broken check current build travi ciorg build
# 165    wrong tabl background color author editor field dev snapshot fix scholar encod b windo...
# 166    work directori set full path includ filenam window amd java file open databas open bib...
# 167    url field vanish run check integr origin report sait umar forum note pleas use issu tr...
# 168    month field ascend descend sort swap version window bitwhen sort accord month ascend d...
# 169    b gui draw issu current beta b get window lot gui draw issu seem part window drawn dra...
# 170    imposs set etalstr empti version step reproduc use style author format follow articl f...
# 171    imposs set etalstr empti version step reproduc use style author format follow articl f...
# 172    open merg bibtex dialog multi monitor setup run multi monitor setup eg second screen m...
# 173    fulltext download dialog show doc latest select entri multipl time trigger window amd ...
# 174                     new databas mark chang complet new databas creat confirm requir close it
# 175    invalid bibtexkey freez dev snapshot master eb window amd java step reproduc entri edi...
# 176    key generat obtain lastnamelastnam wordsoftitlewithupperfirstlett version debian jessi...
# 177    featur move file subfold articlebook file directori workaround renam file via cleanup ...
# 178    integr check report year consist numer field year consist numer year format allow year...
# 179    integr check check field edit offici bibtex spec edit book exampl second ordin first l...
# 180    integr check extract checker file subtask extract checker class integitycheckjava file...
# 181    add support citationstyl user quick want copi past entri render specifi format either ...
# 182    ms offic xml import export follow todo export compani author corpoat languag lcid map ...
# 183    import export mod format sinc export mod format would nice import formatther xml schem...
# 184    use xmlunit xml comparison test atm xml file compar string major disadvantag hard spot...
# 185    keyword separ behaviour group perspect let rephras use keyword separ ambigu default se...
# 186    featur hierarch keyword hiim use quit long time im satisfi thank work im write phd the...
# 187    keyword separ possibl specifi keyword separ automat generat group method bibentri assu...
# 188    wrong error messag file directori version mac ox x step reproduc ensur main file direc...
# 189    improv javafx dialog follow click link stay blue see screenshot possibl link instead c...
# 190    url encod html charact shown violat regard integr check version dev latest window step...
# 191    toggl icon icon stay version dev snapshot master ff c b window amd java step reproduc ...
# 192    help point wrong web page version debian jessiestep reproduc click help insid browser ...
# 193    month field brace result warn window amd java step reproduc load pubm medlin entri id ...
# 194    action activ databas open ui menu entri enabl despit fact databas load instanc rank ac...
# 195    ris import work journal titl version earlier window ubuntu step reproduc import ris fi...
# 196                            ris import doi import work ris standard field patent import other
# 197    local test refer nonexist gradl task eg remov obsolet miss languag key gradlew b local...
# 198    bad web search error messag web search give inconsist wrong feedback tri fetch without...
# 199    shortcut copi url link name bibtexkey sort featur requestit would great provid shortcu...
# 200    main tabl right click doi field allow copi doi current popup doi allow click doi possi...
# 201    perform issu new search dev snapshot master c f window amd java current master branch ...
# 202    ignor updat work version window step reproduc open updat notif appear click ignor upda...
# 203    month field brace result warn window amd java step reproduc load pubm medlin entri id ...
# 204    regress unnecessari field tab ive observ regress certain condit field display better u...
# 205    import prefer dont set font size dev snapshot master afbb window amd java step reprodu...
# 206    cannot import non xml prefer cannot import bibtex key generat prefer version mac osx s...
# 207    regress unnecessari field tab ive observ regress certain condit field display better u...
# 208    googl search issu version fix devbuild helloalthough resolv issu googl search still pr...
# 209    namespac jaxb reli intern java comsun class follow problem tschechlovdev atm commit re...
# 210    perform issu new search dev snapshot master c f window amd java current master branch ...
# 211    cannot import non xml prefer cannot import bibtex key generat prefer version mac osx s...
# 212    perform issu new search dev snapshot master c f window amd java current master branch ...
# 213    empti modal error box save databas pars error version window step reproduc open creat ...
# 214    ctrl doesnt trigger pars error messag latest dev versionstep reproduc entri editor bib...
# 215                                              investig xml export import test execut notic in
# 216    new entri focus search activ open complexbib sort author editor search bard doubl clic...
# 217    fosshub hack affect fosshub hack see softwar instal infect malwar overwrit boot loader...
# 218    articl longer assign group via dragndrop dev snapshot latex free field e ewindow amd j...
# 219    subgroup longer creat use dragndrop dev snapshot latex free field e ewindow amd java c...
# 220    matcheshighlight doensnt respect html netsfjabreflogicsearchmatcheshighlighterhighligh...
# 221    ad fetcher test fail latest dev version see entri return fetcher contain field eid jav...
# 222    memori leak brows bibtex file editor open develop version mac os x step reproduc open ...
# 223    clear bibtexkey nullpointerexcept dev snapshot master f ae window amd java step reprod...
# 224    unexpect behaviour assign articl group use dragndrop dev snapshot master fb dwindow am...
# 225    shortcut check integr workflow check integr get import wish could default shortcut key...
# 226    move default focus search main tabl better handl past entri annoy current master creat...
# 227    improv error consol dev snapshot javafx e window amd java error consol see display fol...
# 228    improv error consol dev snapshot javafx e window amd java error consol see display fol...
# 229    look full text arxiv broken function ad broken current build name fail fetch pdf file ...
# 230    entri editor freez dev snapshot master ee window amd java step reproduc open entri edi...
# 231    astrophys data system fetcher broken seem implement astrophys data system fetcher brok...
# 232                 fetch medlin longer work enforc see issu detail githubcom helpjabreforg issu
# 233    month field shown biblatex mode dev snapshot master ca window amd java biblatex mode m...
# 234    proxi prefer work site version informationjabref version dev snapshot master f fa wind...
# 235    isbn bibtex fetch updat issu seem left tri return invalid isbn messag valid isbn isbn ...
# 236    collect usag statist automat cours anonym collect usag statist exampl chang prefer det...
# 237    chang file permiss databas version ubuntu save databas chang permiss file read write u...
# 238    cannot complet save databas empti key dev snapshot master cwindow amd java step reprod...
# 239    metadata lost reconnect share databas dev snapshot master ee blinux generic java deal ...
# 240    customiz drop menus general field gone drop menu set custom general fieldth code bib f...
# 241    dblp fetcher seem broken version master step reproduc search arbitrari search term use...
# 242    integr check report bibtex key fit expect scheme exampl custom type even type might mi...
# 243    reset prefer import prefer work custom entri type window amd java reset prefer import ...
# 244    custom entri type freez version mac os x x java step reproduc bibtex custom entri type...
# 245    save custom entri type bib file problem might occur custom type store file prefer name...
# 246    refactor entri type custom entri type logic work primari secondaryoptionalfield use bi...
# 247    custom entri type bug import prefer anoth custom entri type add restart display custom...
# 248    biblatex cleanup move year month date field work version think dit work tooaccord code...
# 249    look full text document shortcut download qualiti look full text document great want e...
# 250    better default save file prefer reset want download file suggest store c would prefer ...
# 251    integr check report empti bibtexkey problem version devstep reproduc creat entri bibte...
# 252    month field brace result warn window amd java step reproduc load pubm medlin entri id ...
# 253    latex code group version window step reproduc main menu group toggl group interfac aut...
# 254    group name match wrong version ubuntu group membership entri store group field group i...
# 255    remov entri select group remov entri similar name group window amd java step reproduc ...
# 256    doi bibtex fail catch journaltitl sciencedirect attempt import follow doi releas journ...
# 257    add support biblatex field alias biblatex document section field alias describ address...
# 258    wrong usag bibentri field id field id bibentri intern id use bibtexkey set use setcite...
# 259    relev read status cell doubl click behavior invert version window step reproduc enabl ...
# 260    add cleanup escap comment window amd java step reproduc import pubm id run pdflatex fi...
# 261    bibtexml vs bibtexmp seem offer second kind xml serial bibtex xmlns bibtex worth keep ...
# 262    integr check show wrong institut biblatex element version window amd java step reprodu...
# 263    group name includ bracket space filter group anymor v version organ static group name ...
# 264    timestamp work dev snapshot master cfbc jarjava version java tm se runtim environ buil...
# 265    group function requir lower case field name use name field use dynam group lower case ...
# 266    move file file directori overwrit file version step reproduc differ file attach paper ...
# 267    move link file move file app directori set bib directori version mac os x step reprodu...
# 268    cleanup renam accord format move file sinc hisinc problem renam file move directoriesm...
# 269    group interfac collaps subtre work function collaps subtre group ui work see http disc...
# 270    doi url generat creat entri doi version dev snapshot master e f window amd java step r...
# 271    doi url generat creat entri doi version dev snapshot master e f window amd java step r...
# 272    arxiv fetcher cannot deal arxiv prefix version dev snapshot master f cf linux fc x amd...
# 273    escap sequenc display correct entri tabl linux mint latex backslash tild escap diacrit...
# 274    escap sequenc display correct entri tabl linux mint latex backslash tild escap diacrit...
# 275    acm fetcher add junk databas window x biblatex mode web search acm portal guid comput ...
# 276    forc shutdown accept extern chang devwindow amd java extern chang mean longer shut nor...
# 277    cannot edit dynam group regular express activ descript group option dynam group entri ...
# 278    escap sequenc display correct entri preview window amd java step reproduc creat new en...
# 279    entri preview wrong display apostroph treat special charact version dev snapshot masr ...
# 280    import ris elsevi get journal name version ubuntu problem observ version step reproduc...
# 281    repeat clean sign abstract field result give latex error window amd java notic errorn ...
# 282    repeat clean sign abstract field result give latex error window amd java notic errorn ...
# 283    possibl save databas window x dev snapshot multicleanup ddecdfd fwindow java step repr...
# 284    download articl doi titl click new bibtex entri button past doi id field click generat...
# 285    latex unicod author field fail dev snapshot master df bwindow amd java author field en...
# 286    combin accent work unicod convert rememb anyon els unicod latex convert handl combin a...
# 287    switch latex unicod lib instead handl would solv serious issu idea use simpl extend gr...
# 288    clear rank rank tag bibtex remain rank instead remov found click clear rank rank tag s...
# 289    replac common collect googl guava current use apach common collect googl guava googl g...
# 290    renam packag netsfjabref orgjabref move away sourceforg thus packag renam toothi could...
# 291    edit keyword clear prioriti rank qualiti relev version window edit keyword clear field...
# 292    automat bug report dev snapshot master e e window amd java detail inform migrat old pr...
# 293    propos enhanc search group propos add search function group unfortun java knowledg nea...
# 294    goe mad click enabl save action databas properti version inform window amd java step r...
# 295    camel key doesnt seem work hi cant get camel key key pattern work reason im use latest...
# 296    bibtex key pattern result dont match expect hii encounterd unexpect behaviour creation...
# 297    databas corrupt due incorrect ad delet subgroup group number exceed version step repro...
# 298    cleanup window possibl resiz includ dev snapshot masr jar linux lmde betsyth cleanup w...
# 299    cannot call texstudio version ive set right path applic texstudioapp prefer click icon...
# 300                 cannot chang file folder download fulltext file possibl select differ folder
# 301    keyword group updat new entri save version slackwar hint use develop version ensur use...
# 302    rememb group expans status request hard implement moment sinc listen expand collaps ev...
# 303    import window display background im use b window x java updat set firefox open bib fil...
# 304    integr plugin automat bug report issu made direct result short issu see possibl show i...
# 305    cant connect open offic version mac os x connect openoffic fail messag file applic ope...
# 306    add crossreforg sourc web search complain forum googl scholar bibtex qualiti best good...
# 307    libreoffic plugin problem italic text titl version debian jessiestep reproduc open lib...
# 308           add option clear log insid error consol order reproduc issu without restart jabref
# 309    issu new group panel version dev snapshot brace check followup af ticket suppos mentio...
# 310    error consol updat new event dialog modal updat new event arriv ie need close open see...
# 311                                                 lookup doi sometim freez new develop version
# 312    filenam field file annot tab small filenam exceed length field happen filenam long def...
# 313    export ms offic xml author compani version window export ms offic xml name cur brace t...
# 314    featur hierarch keyword hiim use quit long time im satisfi thank work im write phd the...
# 315    improv architectur test notic architectur test current cover static import therefor mi...
# 316    group issu osx hi im issu ad delet etc group osx basic stop working experi problem gro...
# 317    get fulltext find mani file use regexp year auth extens version linux generic amd java...
# 318    click get fulltext trigger null pointer except databs open current directori version d...
# 319    replac databas librari translat follow discuss decid replac databas librari huge impac...
# 320    click get fulltext trigger null pointer except databs open current directori version d...
# 321    file annoat tab give npe pdf avaiabl entri link pdf file arellano natur languag proces...
# 322    illeg file annot type betawindow amd java happen strang behavior click group log detai...
# 323    entri editor rework possibl enter date manual enter date field click save enter field ...
# 324    use right click attch file open file dialog select directori dev snapshot master e e w...
# 325    allow select multipl group previous possibl select group relat group set intersect uni...
# 326    msbibentri offic xml import export yearaccess monthaccess dayaccess bug report import ...
# 327          allow resort group use drag drop resort group drag drop rais discuss githubcom issu
# 328    bibliograph field miss version snapshot debian jessi amd step reproduc launch select v...
# 329    dev snapshot master ebdjar display edit field version dev linux mint cinnamon ubuntu s...
# 330    custom keybind view open dev f b dbfefe fbdf ce f blinux manjaro amd java step reprodu...
# 331    dblp fetcher negat oper longer work server side issu updat pleas note disabl phrase se...
# 332    context menu file tabl general tab context menu miss delet assign file open file cloud...
# 333    keybind except ctrl z shift sth work latest masteredit entri chang author exampl code ...
# 334    way see relat articl link relat articl tab usual produc link sever articl click dont s...
# 335    command x work proper dev snapshot master ebdmac os x x java step reproduc select entr...
# 336    delet file entri editor delet file disk happenbi default old entri editorth file never...
# 337    look full text document shortcut download qualiti look full text document great want e...
# 338    shortcut copi url link name bibtexkey sort featur requestit would great provid shortcu...
# 339                                                           press escap close entri editor nan
# 340                          add menu option remov link file select remov link file context menu
# 341    duplic finder ignor book edit bibtex file contain edit book find duplic function consi...
# 342    entri editor trigger db chang event often alreadi notic sharelatex integr stuff databa...
# 343    chang group edit entri editor longer mark databas dirti group rais occur current devel...
# 344    autocomplet work perfect dev snapshot master e b ac cmac os x x java bug autocomplet w...
# 345    resiz window select file scale proper window scalabl move button intellig given ranges...
# 346    add prefer migrat keybind moment workaround either reset manual replac pref filemodifi...
# 347    string edit field updat match sourc field versionjabref dev snapshot master c c linux ...
# 348    anyon test docbook export recent export fail version dev snapshot master bee c ai use ...
# 349    key bind delet tri delet whole entri file select general tab select file general tab p...
# 350    sao nasa ad plugin write garbag bib file add use id base entri generat id type sao nas...
# 351    small font group panel entri editor high dpi screen version beta ubuntu open jdk high ...
# 352    ad doi generat timestamp version dev snapshot master e fbf linux generic amd java onub...
# 353    focus entri editor tab open entri editor open entri editortab focus press ctrl plus ct...
# 354    tab get updat edit biblatex sourc step reproduc open entri entri editor entri must fie...
# 355    chang sourc tab save correct without switch anoth tab version beta debian stretch amd ...
# 356    sourc panel entri editor updat correct circumst report wujastyk sourc panel updat corr...
# 357    move group work like add group version beta ubuntu oracl jvmstep reproduc add entri gr...
# 358    main tabl non updat proper newli assign articl group dev snapshot master window amd ja...
# 359    releas unus heap frequent seem memori leak entri editor current master latest commit e...
# 360    check integr action filter option select none tedious deselect issu first select singl...
# 361    miss normal bibtex name format function normal bibtex name format got lost beta beta g...
# 362    link file bad align text form field bad align sometim grey backgroundjabref dev snapsh...
# 363    general tab entri editor scrollabl version beta window amd java display clutter user i...
# 364    sever problem new entri editor beta window amd java step reproduc enter author editor ...
# 365    call function export pdfs select entri new folder time want share literatur pdfs frien...
# 366    add prefer option disabl field valid tobiasdiez introduc field valid entri editor clea...
# 367    valid messag display wrong posit latest master valid messag entri editor shift bottom ...
# 368    extern chang open entri sync back entri editor chang like generat new bibtexkey renam ...
# 369    protect term lead freez dev snapshot master abf linux generic amd java step reproduc e...
# 370    protect term add select text bring previous list dev snapshot master aalinux generic a...
# 371    sever problem new entri editor beta window amd java step reproduc enter author editor ...
# 372    cant remov move onlin file link use arxiv search find insert entri bib file onlin file...
# 373    undo entryeditor sourc tab lead except remov file link entri editor go sourc tab hit c...
# 374    left right key work search bar dev snapshot master b c mac os x x java step reproduc i...
# 375    rewrit logic consist check requir option bibtex field minim exampl articl bad cloud ti...
# 376    delet group via group interfac remov group refer bibtex sourc devlinux generic amd jav...
# 377    latexeditor defunct drop support latest version latexeditor see push latexeditor could...
# 378    lose hyphen prefix last name version mac os x x java normal ul somewher someon ul some...
# 379    descript linkedfil sync bibtex code databas exist file descript shown chang editingfol...
# 380    renam file fail silent renam link file fail alreadi exist file namein general tab entr...
# 381    improv error handl renam link file dev snapshot master b b window amd java step reprod...
# 382    except renam file main directori dev snapshot master b b window amd java step reproduc...
# 383    import entri clipboard websit offer bibliograph data machineread format eg bibtex oder...
# 384    bibtexkey generat use crossref inform dev snapshot master fcac linux fc x amd java see...
# 385    jabr x exit clean gui disappear run file quit menu return consolene press ctrl c sever...
# 386    connect libreoffic relat use lo debian connect work without problem tri connect previo...
# 387    pdf file highlight without comment file annot display n better leav empti version wind...
# 388    unabl open folder case filenam space version cento expect select open folder entri con...
# 389    cannot resolv textendash etc display articl titl version window see follow screenshot ...
# 390    mous group titl inaccur group descript display version java guess group titl mouseov m...
# 391             refresh button file annot tab refresh content close entri editor first afterward
# 392    except open bib file point dev develop start happen problem dev coupl week agoit unusu...
# 393    cite command employ betalinux fc x amd java mayb got someth wrong open prefer extern p...
# 394    filepath save window open linux linux generic amd java step reproduc creat identi fold...
# 395    automat set file link shortcut f work version linux generic amd java step reproduc sel...
# 396    crossref websearch fail parser error version linux gentoo amd java step reproduc searc...
# 397    check integr status use dev oct java linux x choos check integr relat larg bib file en...
# 398    npe save new databas entri databasechangemonitor null creat new databasecopi past bibt...
# 399    filepath save window open linux linux generic amd java step reproduc creat identi fold...
# 400    fatal error content allow prolog version dev snapshot master ebdea linux gentoo amd ja...
# 401    duplic field corrupt entri editor display data shorthand field get display keyword fie...
# 402    flag relev qualityassur cannot remov persist entri im use version archlinux linux arch...
# 403    html code tooltip search field dev snapshot master ea bc clinux gentoo amd java html c...
# 404                          auto creat group aux file creat group paper cite paper via aux file
# 405    java jdk compat block java jdk compat run java issu collect java relat problem start p...
# 406    make fileannotationtab look great implement fileannotationtab javafx manag creat work ...
# 407    indexoutofbound except chane entri type open entri editor got indexoutofbound except p...
# 408    check integr link entryeditor problem test latest master version problem persistsjabre...
# 409    space charact caus cursor jump start line dev snapshot master dlinux generic amd java ...
# 410    import acm digit librari hang select test latest master version problem persistsjabref...
# 411    citat preview increment increas memori usag preview window amd java ram use preview fu...
# 412    key generat fail pars colon seem mac version custom key generat author year veryshortt...
# 413    possibl delet attach file test latest master version problem persist icon right side s...
# 414    doubl click entri file list open pdf doubl click direct open pdf furthermor button ope...
# 415    default set filenam format autolink file dont play nice togeth ran need autolink file ...
# 416    search box miss newest version test latest master version problem persistsjabref versi...
# 417    extern group chang result npe current master open bib filemodifi bib file extern edito...
# 418    citat preview increment increas memori usag preview window amd java ram use preview fu...
# 419    custom data type field techreport store origin report forum test latest master version...
# 420    automat ad file link absolut instead relat path test latest master version problem per...
# 421    perform problem new group search filter larg databas dev snapshot master ebdwindow amd...
# 422    miss dot file export issu version finestep reproduc file export select ms xml format s...
# 423    delet entri caus npe except delet entri current master c b sever except thrown subscri...
# 424    colour item count group panel work reliabl dev snapshot maintabl updat f window amd ja...
# 425    latex textit reder correct main tabl entri reproduc articl abdala author fernando abda...
# 426    select new entri caus edit panel becom corrupt accept input maco java version version ...
# 427    npe exportfactori prevent start start npe tobiasdiez introduc circular dependencyin cr...
# 428    disabl autocomplet search field version start search databas drop menu appear search w...
# 429    miss dot file export issu version finestep reproduc file export select ms xml format s...
# 430    export dialog unclear format list issu version snapshot reproduc file export expect li...
# 431    entri preview editor blank test latest master version problem persistsjabref dev snaps...
# 432    biblatex export word xml date field export window amd java import recogn year biblatex...
# 433    ris import ignor l full text link field use debian unstablei export entri zotero ris f...
# 434    incorrect ris field greetingsim develop academ blogger toolkit plugin wordpress user d...
# 435    incorrect ris field greetingsim develop academ blogger toolkit plugin wordpress user d...
# 436    parameter test execut travi base discuss seem move junit somehow turn parameter test t...
# 437    chain modifi work case test latest master version problem persistsjabref version debia...
# 438                               delet disk default option select delet file tab button suffici
# 439    manual protect text case add around select text doesnt work test latest master version...
# 440    find duplic mark differ book chapter duplic qualiti find duplic mark differ chapter bo...
# 441    magnifi chang color search mode old version activ mode indict use differ color magnifi...
# 442    save custom entri type bib file definit store databas portabl anoth user open convert ...
# 443    bibtexml vs bibtexmp seem offer second kind xml serial bibtex xmlns bibtex worth keep ...
# 444    add cleanup oper replac ligatur add cleanup oper replac unicod ligatur charact normal ...
# 445    rewrit entir journal list addit versionjabref mac os x x java surpris file abbrvjabref...
# 446     menu bar wrong posit mac os version beta menu bar includ main window fix mac os menu bar
# 447    improv architectur test notic architectur test current cover static import therefor mi...
# 448    improv ux main toolbar press matter point take care moment current main toolbar look l...
# 449    osx maintabl beta joptionpan load backup file startup show freez sure inde problem sus...
# 450    throw except start anoth languag miss fxml local tri test koppor might actual use add ...
# 451    except tri save link file test latest master version problem persistsjabref dev snapsh...
# 452    download longer show progress test latest master version problem persistsrec masterste...
# 453    except tri save link file test latest master version problem persistsjabref dev snapsh...
# 454    except tri save link file test latest master version problem persistsjabref dev snapsh...
# 455    except entri editor brace dont match test latest master version problem persistsvers l...
# 456    magnifi chang color wrong offer search mode normal search grammar base advanc search s...
# 457    link file devonthink hello communiti jabreftobia diez suggest write problem thread hel...
# 458    group fast access view option version window often switch union intersect mode pleas r...
# 459    remov file link general edit entri lead errnon doubl remov test latest master dev pers...
# 460    fetcher messag mislead full text document download fail indic fail download access url...
# 461    add proper way set extern applic push search minut chang extern applic push emac vim f...
# 462    render problem gtk look feel linux openjdk system ubuntu linux version generic buildd ...
# 463    group fast access view option version window often switch union intersect mode pleas r...
# 464    url column miss maintabl beta version look screenshot user imagesentcom e ecc e dc e dpng
# 465    fetcher broken without anyon notic deactiv test travi notic failright lot actual broke...
# 466    problem find fulltext ieeexplor issu ieee full text importeri test latest master versi...
# 467    problem find fulltext ieeexplor issu ieee full text importeri test latest master versi...
# 468    featur suggest text file export find unlink file qualiti find unlink file handi use di...
# 469    ieee preview display month current refer preview without field month shown follow bib ...
# 470    ieee preview display month current refer preview without field month shown follow bib ...
# 471    add rfc standard fetcher rfcs doi doi import correspond real bibtex dataimplement tota...
# 472    copi clipboard version window select item contextu menu copi export clipboard noth hap...
# 473    unabl launch overriden font set test latest master version problem persistsjabref vers...
# 474    still freez maco high sierra step reproduc open file import new librari choos file cli...
# 475      reimplement tooltip url column followup tooltip url column activ display sensibl messag
# 476    custom export filter cannot use test latest master version problem persistsjabref vers...
# 477    fetcher titl remov space linux arch amd java step reproduc new entryctrl n id type tit...
# 478    problem web search acm tri fetch entri acm seem test latest master version problem per...
# 479    featur request openssl sql would realli nice includ ssl support share databas function...
# 480    cli work use sanit bibfil automat use jenkin newer releas work cli test latest master ...
# 481    overwrit exist key work option prefer bibtex key generatori check overwrit box bib ent...
# 482    longer push citat texstudio hijabref version maco high sierra java test step reproduc ...
# 483    entri editor produc constant load entri editor open experi constant high load jabrefth...
# 484    comment shown entri preview test latest master version problem persistsjabref version ...
# 485    ctrl open folder current directori bib file current use last open directori open file ...
# 486    move next entri entri editor longer support test latest master version problem persist...
# 487    singl word journal titl show alert sure problem introduc singl word journal titl show ...
# 488    clean oper move file file field pdf field afterward longer open direct im clean entri ...
# 489    set better default window size maintabl beta version quit ugli first startup maintabl ...
# 490    ctrl f select search field keyword shortcut short cut keybind key bind hotkey hot keyj...
# 491    encod issu relat articl tab found relat articl relat articl tab contain special charac...
# 492    dev respect standard directori dev snapshot master dd b window amd java test latest ma...
# 493    name standard bibtex format lc briand morasca vr basili space dot miss firstnamesalso ...
# ...
# 10
# Logging
# Logging,26
# Logging,26,45
# Logging,26,45,9
# Logging,26,45,9,99
# ['Label, TN, FP, FN, TP', 'Google Common,104,11,37,27', 'Test,104,15,38,22', 'SO,154,2,14,9', 'IO,11,30,7,131', 'UI,35,34,10,100', 'Network,108,8,28,35', 'Security,166,1,8,4', 'OpenOffice Documents,171,3,2,3', 'Database,163,2,8,6', 'PDF,169,2,4,4', 'Logging,26,45,9,99']
# 11
# Latex
# Latex,168
# Latex,168,1
# Latex,168,1,2
# Latex,168,1,2,8
# ['Label, TN, FP, FN, TP', 'Google Common,104,11,37,27', 'Test,104,15,38,22', 'SO,154,2,14,9', 'IO,11,30,7,131', 'UI,35,34,10,100', 'Network,108,8,28,35', 'Security,166,1,8,4', 'OpenOffice Documents,171,3,2,3', 'Database,163,2,8,6', 'PDF,169,2,4,4', 'Logging,26,45,9,99', 'Latex,168,1,2,8']
#    Accuracy  Acc-Score  zero_one_loss    AUC-PR  hamming loss average  \
# 0  0.184358         33       0.815642  0.791779              0.149441
#
#    Jaccard samples  Jaccard macro  Precision    Recall  Fmeasure
# 0         0.558562       0.582575   0.744186  0.728455  0.736237
# ---------
#
#
#
#                 Google Common       Test         SO          IO          UI  \
# precision            0.710526   0.594595   0.818182    0.813665    0.746269
# recall               0.421875   0.366667   0.391304    0.949275    0.909091
# f-measure            0.529412   0.453608   0.529412    0.876254    0.819672
# samples_tested      64.000000  60.000000  23.000000  138.000000  110.000000
#
#                   Network   Security  OpenOffice Documents   Database  \
# precision        0.813953   0.800000              0.500000   0.750000
# recall           0.555556   0.333333              0.600000   0.428571
# f-measure        0.660377   0.470588              0.545455   0.545455
# samples_tested  63.000000  12.000000              5.000000  14.000000
#
#                      PDF     Logging      Latex
# precision       0.666667    0.687500   0.888889
# recall          0.500000    0.916667   0.800000
# f-measure       0.571429    0.785714   0.842105
# samples_tested  8.000000  108.000000  10.000000
# ---------
#
# ['tf-IDFMin, tf-IDFMax, #_TopTerms,Stop_Word,Train/Test_Size,Algorithm,Accuracy_Score,Accuracy_Score_not_normalized,zero_one_loss, AUC-PR,hamming_loss_avg,Jaccard_samples,Jaccard_macro,Precision,Recall,Fmeasure_Score, i', '(1, 1),895,Yes,0.2,RandomForest,0.18435754189944134,33,0.8156424581005587,0.7917785115702365,0.1494413407821229,0.5585616742041323,0.5825747724317295,0.7441860465116279,0.7284552845528456,0.7362366474938373,8']
# Current date and time :
# 2021-02-25 05:17:42
# tupla: (datetime.datetime(2021, 2, 25, 5, 17, 42, 704478), '(1, 1)', '895', 'Yes', '0.2', 'RandomForest', '0.18435754189944134', '33', '0.8156424581005587', '0.7917785115702365', '0.1494413407821229', '0.5585616742041323', '0.5825747724317295', '0.7441860465116279', '0.7284552845528456', '0.7362366474938373', '8')
# 17
# Pandas(Index=0, date_time='2021-02-25 05:17:28.115368', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.21787709497206706, Accuracy_Score_not_normalized=39, zero_one_loss=0.782122905027933, _10=0.801627452687256, hamming_loss_avg=0.1424581005586592, Jaccard_samples=0.6093531080961249, Jaccard_macro=0.6165413533834586, Precision=0.7569230769230769, Recall=0.76875, Fmeasure_Score=0.7627906976744186, i=0)
# Pandas(Index=1, date_time='2021-02-25 05:17:29.943351', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.17318435754189945, Accuracy_Score_not_normalized=31, zero_one_loss=0.8268156424581006, _10=0.77312786989245, hamming_loss_avg=0.16061452513966482, Jaccard_samples=0.5382371198013656, Jaccard_macro=0.5418326693227091, Precision=0.7298747763864043, Recall=0.6777408637873754, Fmeasure_Score=0.7028423772609821, i=1)
# Pandas(Index=2, date_time='2021-02-25 05:17:31.848899', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.19553072625698328, Accuracy_Score_not_normalized=35, zero_one_loss=0.8044692737430168, _10=0.821665087400538, hamming_loss_avg=0.13221601489757914, Jaccard_samples=0.6019863438857852, Jaccard_macro=0.6151761517615176, Precision=0.7529021558872305, Recall=0.7707979626485568, Fmeasure_Score=0.7617449664429531, i=2)
# Pandas(Index=3, date_time='2021-02-25 05:17:33.690085', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.223463687150838, Accuracy_Score_not_normalized=40, zero_one_loss=0.7765363128491619, _10=0.7719554137496727, hamming_loss_avg=0.14338919925512106, Jaccard_samples=0.5701871064999556, Jaccard_macro=0.5968586387434555, Precision=0.7261146496815286, Recall=0.7702702702702703, Fmeasure_Score=0.7475409836065574, i=3)
# Pandas(Index=4, date_time='2021-02-25 05:17:35.508167', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2011173184357542, Accuracy_Score_not_normalized=36, zero_one_loss=0.7988826815642458, _10=0.7756171053734923, hamming_loss_avg=0.1568901303538175, Jaccard_samples=0.5517402678017203, Jaccard_macro=0.5673940949935815, Precision=0.7366666666666667, Recall=0.711755233494364, Fmeasure_Score=0.7239967239967242, i=4)
# Pandas(Index=5, date_time='2021-02-25 05:17:37.441186', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.223463687150838, Accuracy_Score_not_normalized=40, zero_one_loss=0.7765363128491619, _10=0.7944018081796109, hamming_loss_avg=0.14757914338919925, Jaccard_samples=0.5671322160148975, Jaccard_macro=0.5914948453608248, Precision=0.7524590163934426, Recall=0.7344, Fmeasure_Score=0.7433198380566802, i=5)
# Pandas(Index=6, date_time='2021-02-25 05:17:39.226858', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2011173184357542, Accuracy_Score_not_normalized=36, zero_one_loss=0.7988826815642458, _10=0.8192052895950795, hamming_loss_avg=0.1350093109869646, Jaccard_samples=0.585268688480979, Jaccard_macro=0.6143617021276596, Precision=0.7830508474576271, Recall=0.7403846153846154, Fmeasure_Score=0.7611202635914334, i=6)
# Pandas(Index=7, date_time='2021-02-25 05:17:40.904425', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2011173184357542, Accuracy_Score_not_normalized=36, zero_one_loss=0.7988826815642458, _10=0.8113819968494413, hamming_loss_avg=0.1419925512104283, Jaccard_samples=0.5807971978363039, Jaccard_macro=0.6033810143042913, Precision=0.7669421487603306, Recall=0.7388535031847133, Fmeasure_Score=0.7526358475263584, i=7)
# Accuracy Score
# 0.18994413407821228
# ---------
#
# Accuracy Score not normalized
# 34
# ---------
#
# zero_one_loss
# 0.8100558659217877
# ---------
#
# Fmeasure Score
# 0.7554479418886197
# ---------
#
# AUC-PR
# 0.833201208187975
# ---------
#
# hamming loss average
# 0.14106145251396648
# ---------
#
# Jaccard samples
# 0.5908042919216103
# ---------
#
# Jaccard macro
# 0.6070038910505836
# ---------
#
# Average precision score, micro-averaged over all classes: 0.83
# 0
# Google Common
# Google Common,115
# Google Common,115,7
# Google Common,115,7,29
# Google Common,115,7,29,28
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28']
# 1
# Test
# Test,108
# Test,108,12
# Test,108,12,40
# Test,108,12,40,19
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19']
# 2
# SO
# SO,155
# SO,155,3
# SO,155,3,11
# SO,155,3,11,10
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19', 'SO,155,3,11,10']
# 3
# IO
# IO,8
# IO,8,30
# IO,8,30,4
# IO,8,30,4,137
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19', 'SO,155,3,11,10', 'IO,8,30,4,137']
# 4
# UI
# UI,40
# UI,40,22
# UI,40,22,12
# UI,40,22,12,105
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19', 'SO,155,3,11,10', 'IO,8,30,4,137', 'UI,40,22,12,105']
# 5
# Network
# Network,101
# Network,101,9
# Network,101,9,34
# Network,101,9,34,35
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19', 'SO,155,3,11,10', 'IO,8,30,4,137', 'UI,40,22,12,105', 'Network,101,9,34,35']
# 6
# Security
# Security,162
# Security,162,4
# Security,162,4,7
# Security,162,4,7,6
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19', 'SO,155,3,11,10', 'IO,8,30,4,137', 'UI,40,22,12,105', 'Network,101,9,34,35', 'Security,162,4,7,6']
# 7
# OpenOffice Documents
# OpenOffice Documents,168
# OpenOffice Documents,168,4
# OpenOffice Documents,168,4,3
# OpenOffice Documents,168,4,3,4
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19', 'SO,155,3,11,10', 'IO,8,30,4,137', 'UI,40,22,12,105', 'Network,101,9,34,35', 'Security,162,4,7,6', 'OpenOffice Documents,168,4,3,4']
# 8
# Database
# Database,162
# Database,162,4
# Database,162,4,4
# Database,162,4,4,9
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19', 'SO,155,3,11,10', 'IO,8,30,4,137', 'UI,40,22,12,105', 'Network,101,9,34,35', 'Security,162,4,7,6', 'OpenOffice Documents,168,4,3,4', 'Database,162,4,4,9']
# 9
# PDF
# PDF,169
# PDF,169,1
# PDF,169,1,2
# PDF,169,1,2,7
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19', 'SO,155,3,11,10', 'IO,8,30,4,137', 'UI,40,22,12,105', 'Network,101,9,34,35', 'Security,162,4,7,6', 'OpenOffice Documents,168,4,3,4', 'Database,162,4,4,9', 'PDF,169,1,2,7']
# 10
# Logging
# Logging,19
# Logging,19,45
# Logging,19,45,15
# Logging,19,45,15,100
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19', 'SO,155,3,11,10', 'IO,8,30,4,137', 'UI,40,22,12,105', 'Network,101,9,34,35', 'Security,162,4,7,6', 'OpenOffice Documents,168,4,3,4', 'Database,162,4,4,9', 'PDF,169,1,2,7', 'Logging,19,45,15,100']
# 11
# Latex
# Latex,170
# Latex,170,0
# Latex,170,0,1
# Latex,170,0,1,8
# ['Label, TN, FP, FN, TP', 'Google Common,115,7,29,28', 'Test,108,12,40,19', 'SO,155,3,11,10', 'IO,8,30,4,137', 'UI,40,22,12,105', 'Network,101,9,34,35', 'Security,162,4,7,6', 'OpenOffice Documents,168,4,3,4', 'Database,162,4,4,9', 'PDF,169,1,2,7', 'Logging,19,45,15,100', 'Latex,170,0,1,8']
#    Accuracy  Acc-Score  zero_one_loss    AUC-PR  hamming loss average  \
# 0  0.189944         34       0.810056  0.833201              0.141061
#
#    Jaccard samples  Jaccard macro  Precision    Recall  Fmeasure
# 0         0.590804       0.607004   0.768473  0.742857  0.755448
# ---------
#
#
#
#                 Google Common       Test         SO          IO          UI  \
# precision            0.800000   0.612903   0.769231    0.820359    0.826772
# recall               0.491228   0.322034   0.476190    0.971631    0.897436
# f-measure            0.608696   0.422222   0.588235    0.889610    0.860656
# samples_tested      57.000000  59.000000  21.000000  141.000000  117.000000
#
#                   Network   Security  OpenOffice Documents   Database  \
# precision        0.795455   0.600000              0.500000   0.692308
# recall           0.507246   0.461538              0.571429   0.692308
# f-measure        0.619469   0.521739              0.533333   0.692308
# samples_tested  69.000000  13.000000              7.000000  13.000000
#
#                      PDF     Logging     Latex
# precision       0.875000    0.689655  1.000000
# recall          0.777778    0.869565  0.888889
# f-measure       0.823529    0.769231  0.941176
# samples_tested  9.000000  115.000000  9.000000
# ---------
#
# ['tf-IDFMin, tf-IDFMax, #_TopTerms,Stop_Word,Train/Test_Size,Algorithm,Accuracy_Score,Accuracy_Score_not_normalized,zero_one_loss, AUC-PR,hamming_loss_avg,Jaccard_samples,Jaccard_macro,Precision,Recall,Fmeasure_Score, i', '(1, 1),895,Yes,0.2,RandomForest,0.18994413407821228,34,0.8100558659217877,0.833201208187975,0.14106145251396648,0.5908042919216103,0.6070038910505836,0.7684729064039408,0.7428571428571429,0.7554479418886197,9']
# Current date and time :
# 2021-02-25 05:17:44
# tupla: (datetime.datetime(2021, 2, 25, 5, 17, 44, 432510), '(1, 1)', '895', 'Yes', '0.2', 'RandomForest', '0.18994413407821228', '34', '0.8100558659217877', '0.833201208187975', '0.14106145251396648', '0.5908042919216103', '0.6070038910505836', '0.7684729064039408', '0.7428571428571429', '0.7554479418886197', '9')
# 17
# Pandas(Index=0, date_time='2021-02-25 05:17:28.115368', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.21787709497206706, Accuracy_Score_not_normalized=39, zero_one_loss=0.782122905027933, _10=0.801627452687256, hamming_loss_avg=0.1424581005586592, Jaccard_samples=0.6093531080961249, Jaccard_macro=0.6165413533834586, Precision=0.7569230769230769, Recall=0.76875, Fmeasure_Score=0.7627906976744186, i=0)
# Pandas(Index=1, date_time='2021-02-25 05:17:29.943351', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.17318435754189945, Accuracy_Score_not_normalized=31, zero_one_loss=0.8268156424581006, _10=0.77312786989245, hamming_loss_avg=0.16061452513966482, Jaccard_samples=0.5382371198013656, Jaccard_macro=0.5418326693227091, Precision=0.7298747763864043, Recall=0.6777408637873754, Fmeasure_Score=0.7028423772609821, i=1)
# Pandas(Index=2, date_time='2021-02-25 05:17:31.848899', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.19553072625698328, Accuracy_Score_not_normalized=35, zero_one_loss=0.8044692737430168, _10=0.821665087400538, hamming_loss_avg=0.13221601489757914, Jaccard_samples=0.6019863438857852, Jaccard_macro=0.6151761517615176, Precision=0.7529021558872305, Recall=0.7707979626485568, Fmeasure_Score=0.7617449664429531, i=2)
# Pandas(Index=3, date_time='2021-02-25 05:17:33.690085', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.223463687150838, Accuracy_Score_not_normalized=40, zero_one_loss=0.7765363128491619, _10=0.7719554137496727, hamming_loss_avg=0.14338919925512106, Jaccard_samples=0.5701871064999556, Jaccard_macro=0.5968586387434555, Precision=0.7261146496815286, Recall=0.7702702702702703, Fmeasure_Score=0.7475409836065574, i=3)
# Pandas(Index=4, date_time='2021-02-25 05:17:35.508167', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2011173184357542, Accuracy_Score_not_normalized=36, zero_one_loss=0.7988826815642458, _10=0.7756171053734923, hamming_loss_avg=0.1568901303538175, Jaccard_samples=0.5517402678017203, Jaccard_macro=0.5673940949935815, Precision=0.7366666666666667, Recall=0.711755233494364, Fmeasure_Score=0.7239967239967242, i=4)
# Pandas(Index=5, date_time='2021-02-25 05:17:37.441186', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.223463687150838, Accuracy_Score_not_normalized=40, zero_one_loss=0.7765363128491619, _10=0.7944018081796109, hamming_loss_avg=0.14757914338919925, Jaccard_samples=0.5671322160148975, Jaccard_macro=0.5914948453608248, Precision=0.7524590163934426, Recall=0.7344, Fmeasure_Score=0.7433198380566802, i=5)
# Pandas(Index=6, date_time='2021-02-25 05:17:39.226858', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2011173184357542, Accuracy_Score_not_normalized=36, zero_one_loss=0.7988826815642458, _10=0.8192052895950795, hamming_loss_avg=0.1350093109869646, Jaccard_samples=0.585268688480979, Jaccard_macro=0.6143617021276596, Precision=0.7830508474576271, Recall=0.7403846153846154, Fmeasure_Score=0.7611202635914334, i=6)
# Pandas(Index=7, date_time='2021-02-25 05:17:40.904425', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2011173184357542, Accuracy_Score_not_normalized=36, zero_one_loss=0.7988826815642458, _10=0.8113819968494413, hamming_loss_avg=0.1419925512104283, Jaccard_samples=0.5807971978363039, Jaccard_macro=0.6033810143042913, Precision=0.7669421487603306, Recall=0.7388535031847133, Fmeasure_Score=0.7526358475263584, i=7)
# Pandas(Index=8, date_time='2021-02-25 05:17:42.704478', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1843575418994413, Accuracy_Score_not_normalized=33, zero_one_loss=0.8156424581005587, _10=0.7917785115702365, hamming_loss_avg=0.1494413407821229, Jaccard_samples=0.5585616742041323, Jaccard_macro=0.5825747724317295, Precision=0.7441860465116279, Recall=0.7284552845528456, Fmeasure_Score=0.7362366474938373, i=8)
