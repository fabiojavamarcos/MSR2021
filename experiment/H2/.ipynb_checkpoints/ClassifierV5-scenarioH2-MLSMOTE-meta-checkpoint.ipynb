# %%
import pandas as pd
import numpy as np
import csv 
import string
import nltk 
import re 
import time
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
import os
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import CountVectorizer
import sys
import warnings
from os import path
import ast
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from skmultilearn.problem_transform import BinaryRelevance
from skmultilearn.problem_transform import LabelPowerset
from skmultilearn.problem_transform import ClassifierChain
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score, average_precision_score, precision_recall_fscore_support
from sklearn.metrics import accuracy_score
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import zero_one_loss
from sklearn.metrics import jaccard_score
import sklearn.metrics as skm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
import numpy as np
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import time
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from skmultilearn.adapt import MLkNN
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from skmultilearn.adapt import BRkNNaClassifier
from sklearn.linear_model import RidgeClassifierCV

pd.options.display.max_seq_items = 2000
pd.options.display.max_colwidth = 90
pd.options.display.max_rows = 999

loggingFile = './experiment//TitleBody3GramTFIDF.txt'
binaryBodyTitle = './experiment/binaryBodyTitle.csv'
template = './experiment/dfTeste.csv'

# %%
# -*- coding: utf-8 -*-
# Importing required Library
import numpy as np
import pandas as pd
import random
from sklearn.datasets import make_classification
from sklearn.neighbors import NearestNeighbors

# %%
def create_dataset(n_sample=1000):
    ''' 
    Create a unevenly distributed sample data set multilabel  
    classification using make_classification function
    
    args
    nsample: int, Number of sample to be created
    
    return
    X: pandas.DataFrame, feature vector dataframe with 10 features 
    y: pandas.DataFrame, target vector dataframe with 5 labels
    '''
    X, y = make_classification(n_classes=5, class_sep=2, 
                           weights=[0.1,0.025, 0.205, 0.008, 0.9], n_informative=3, n_redundant=1, flip_y=0,
                           n_features=10, n_clusters_per_class=1, n_samples=1000, random_state=10)
    y = pd.get_dummies(y, prefix='class')
    return pd.DataFrame(X), y

def get_tail_label(df):
    """
    Give tail label colums of the given target dataframe
    
    args
    df: pandas.DataFrame, target label df whose tail label has to identified
    
    return
    tail_label: list, a list containing column name of all the tail label
    """
    columns = df.columns
    n = len(columns)
    irpl = np.zeros(n)
    for column in range(n):
        irpl[column] = df[columns[column]].value_counts()[1]
    irpl = max(irpl)/irpl
    mir = np.average(irpl)
    tail_label = []
    for i in range(n):
        if irpl[i] > mir:
            tail_label.append(columns[i])
    return tail_label

def get_index(df):
  """
  give the index of all tail_label rows
  args
  df: pandas.DataFrame, target label df from which index for tail label has to identified
    
  return
  index: list, a list containing index number of all the tail label
  """
  tail_labels = get_tail_label(df)
  index = set()
  for tail_label in tail_labels:
    sub_index = set(df[df[tail_label]==1].index)
    index = index.union(sub_index)
  return list(index)

def get_minority_instace(X, y):
    """
    Give minority dataframe containing all the tail labels
    
    args
    X: pandas.DataFrame, the feature vector dataframe
    y: pandas.DataFrame, the target vector dataframe
    
    return
    X_sub: pandas.DataFrame, the feature vector minority dataframe
    y_sub: pandas.DataFrame, the target vector minority dataframe
    """
    index = get_index(y)
    X_sub = X[X.index.isin(index)].reset_index(drop = True)
    y_sub = y[y.index.isin(index)].reset_index(drop = True)
    return X_sub, y_sub

def nearest_neighbour(X):
    """
    Give index of 5 nearest neighbor of all the instance
    
    args
    X: np.array, array whose nearest neighbor has to find
    
    return
    indices: list of list, index of 5 NN of each element in X
    """
    nbs=NearestNeighbors(n_neighbors=5,metric='euclidean',algorithm='kd_tree').fit(X)
    euclidean,indices= nbs.kneighbors(X)
    return indices

def MLSMOTE(X,y, n_sample):
    """
    Give the augmented data using MLSMOTE algorithm
    
    args
    X: pandas.DataFrame, input vector DataFrame
    y: pandas.DataFrame, feature vector dataframe
    n_sample: int, number of newly generated sample
    
    return
    new_X: pandas.DataFrame, augmented feature vector data
    target: pandas.DataFrame, augmented target vector data
    """
    indices2 = nearest_neighbour(X)
    n = len(indices2)
    new_X = np.zeros((n_sample, X.shape[1]))
    target = np.zeros((n_sample, y.shape[1]))
    for i in range(n_sample):
        reference = random.randint(0,n-1)
        neighbour = random.choice(indices2[reference,1:])
        all_point = indices2[reference]
        nn_df = y[y.index.isin(all_point)]
        ser = nn_df.sum(axis = 0, skipna = True)
        target[i] = np.array([1 if val>2 else 0 for val in ser])
        ratio = random.random()
        gap = X.loc[reference,:] - X.loc[neighbour,:]
        new_X[i] = np.array(X.loc[reference,:] + ratio * gap)
    new_X = pd.DataFrame(new_X, columns=X.columns)
    target = pd.DataFrame(target, columns=y.columns)
    new_X = pd.concat([X, new_X], axis=0)
    target = pd.concat([y, target], axis=0)
    return new_X, target

# %%
#organizing data_frame to issue order
def organize():
    data_classes = pd.read_csv(binaryBodyTitle, header = 0, sep=";")
    data_classes

    del data_classes['prIssue']
    del data_classes['issueTitle']
    del data_classes['issueBody']

    data_classes.rename(columns={'issueComments': 'prComments','Comments': 'prCodeReviewComments','issueTitleLink': 'issueTitle','issueBodyLink': 'issueBody','issueCommentsLink': 'issue_Comments','pr': 'prNumber','issue': 'issueNumber', 'Title': 'prTitle','Body': 'prBody'}, inplace=True)
    categories = data_classes.columns.values.tolist()


    data_classes = data_classes[['issueNumber', 'prNumber', 'issueTitle', 'issueBody', 'issue_Comments',
                            'prTitle','prBody','prComments','prCodeReviewComments','commitMessage','isPR','isTrain',
                             'Google Common','Test','SO','IO','UI','Network','Security',
                            'OpenOffice Documents','Database','Utils','PDF','Logging','Latex']]

    data_classes['issueNumber'] = data_classes['issueNumber'].astype('Int64')
    
    return data_classes

# %%
#Filtering issues with PRs
def filtering(data_classes):
    IssuePRDataset = data_classes[data_classes["isTrain"] == 0]

    #invalid number of issue = NaN
    IssuePRDataset = IssuePRDataset.drop([1805])

    categories = IssuePRDataset.columns.values.tolist()
    
    return categories, IssuePRDataset

# %%
# RQ1.a - o quão sensível o resultado é em relação ao algoritmo? 
#vários algoritmos - BinaryRelevance
#todas as palavras, bootstrap, unigram 
#somente o título
def dataset_config(IssuePRDataset):
    data_test1 = IssuePRDataset[['issueNumber','prNumber','issueBody','Google Common', 'Test', 'SO', 'IO', 'UI', 'Network', 'Security', 
                           'OpenOffice Documents', 'Database', 'Utils', 'PDF', 'Logging', 'Latex']].copy()

    #data_test1["corpus"] = data_test1["issueBody"].map(str)
    #del data_test1["issueBody"]
    data_test1["corpus"] = data_test1["issueTitle"].map(str) + ' ' + data_test1["issueBody"].map(str)
    del data_test1["issueTitle"]
    del data_test1["issueBody"]


    #removing utils because we won't to predict a so simple API that is basically used in all PRs
    del data_test1["Utils"]

    data_test1 = data_test1.reset_index(drop=True)
    
    return data_test1

# %%
#preprocessing text

#We first convert the comments to lower-case 
#then use custom made functions to remove html-tags, punctuation and non-alphabetic characters from the TitleBody.

def clean_data(data_test1):
    if not sys.warnoptions:
        warnings.simplefilter("ignore")

    def cleanHtml(sentence):
        cleanr = re.compile('<.*?>')
        cleantext = re.sub(cleanr, ' ', str(sentence))
        return cleantext

    def cleanPunc(sentence): #function to clean the word of any punctuation or special characters
        cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
        cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
        cleaned = cleaned.strip()
        cleaned = cleaned.replace("\n"," ")
        return cleaned

    def keepAlpha(sentence):
        alpha_sent = ""
        for word in sentence.split():
            alpha_word = re.sub('[^a-z A-Z]+', ' ', word)
            alpha_sent += alpha_word
            alpha_sent += " "
        alpha_sent = alpha_sent.strip()
        return alpha_sent

    #function pra remover palavras com menos de 3 tokens

    data_test1['corpus'] = data_test1['corpus'].str.lower()
    data_test1['corpus'] = data_test1['corpus'].apply(cleanHtml)
    data_test1['corpus'] = data_test1['corpus'].apply(cleanPunc)
    data_test1['corpus'] = data_test1['corpus'].apply(keepAlpha)
    
    return data_test1

# %%
#### removing stopwords

def remove_stop_words():
    stop_words = set(stopwords.words('english'))
    stop_words.update(['pr','zero','one','two','three','four','five','six','seven','eight','nine','ten','may','also','across','among','beside','however','yet','within','jabref','org','github','com','md','https','ad','changelog','','joelparkerhenderson','localizationupd',' localizationupd','localizationupd ','i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the','Mr', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now'])
    #stop_words.update(['i', 'me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the","Mr", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"])

    re_stop_words = re.compile(r"\b(" + "|".join(stop_words) + ")\\W", re.I)

    return re_stop_words

# %%
def removeStopWords(sentence, re_stop_words):
    #global re_stop_words
    #print(sentence)
    return re_stop_words.sub(" ", sentence)

#removing words with less than 3 characters
#data_classes['titleBody'] = data_classes['titleBody'].str.findall('\w{3,}').str.join(' ')

# %%
def apply_stem(data_test1):
    stemmer = SnowballStemmer("english")
    
    def stemming(sentence):
        stemSentence = ""
        for word in sentence.split():
            stem = stemmer.stem(word)
            stemSentence += stem
            stemSentence += " "
        stemSentence = stemSentence.strip()
        return stemSentence
    
    data_test1['corpus'] = data_test1['corpus'].apply(stemming)
    print(data_test1['corpus'])
    
    return data_test1

# %%
#TF-ID
def run_tf_idf(data, configurationTFIDF, num_feature, tfIDFoutputFile):
    #we need to text max_feature with 10, 20, 25, 50 
    #, max_features=num_feature
    vectorizer = TfidfVectorizer(strip_accents='unicode', analyzer='word', ngram_range = configurationTFIDF, max_features=num_feature)
        
    tf_idf_results = vectorizer.fit_transform(data['corpus'])

    features = vectorizer.get_feature_names()

    #print(features)

    scores = (tf_idf_results.toarray())
    output_tf_idf = pd.DataFrame(scores)
    
    output_tf_idf = pd.concat([data['issueNumber'], output_tf_idf], axis=1)

    output_tf_idf.to_csv(tfIDFoutputFile, encoding='utf-8', header=False, index=False, sep=',')


    # remove words occuring less than 5 times
    #tfidf = TfidfVectorizer(min_df=5)
    #you can also remove common words:

    # remove words occuring in more than half the documents
    #tfidf = TfidfVectorizer(max_df=0.5)
    #you can also remove stopwords like this:

# %%
#analyzing frequency of TOP 50 terms

def analyze_top(data, termFrequencyTop50):
    docs = data['corpus'].tolist()

    cv = CountVectorizer()
    cv_fit=cv.fit_transform(docs)

    #print(cv.get_feature_names())
    #print(cv_fit.toarray())

    word_list = cv.get_feature_names()   

    count_list = cv_fit.toarray().sum(axis=0)
    term_frequency = dict(zip(word_list,count_list))

    a = sorted(term_frequency.items(), key=lambda x: x[1], reverse=True) 
    
    #print('SIZE OF TERMS', len(a))
    
    top50 = a[:100]
    df_frequency = pd.DataFrame(top50, columns =['term', 'frequency'])  

    #print(df_frequency)

    df_frequency.to_csv(termFrequencyTop50, encoding='utf-8', header=False, index=False, sep=',')

    sns.set(font_scale = 2)
    plt.figure(figsize=(18,17))
    plt.xticks(rotation=90)
    plt.title("Frequency of terms ")
    plt.ylabel('term', fontsize=20)
    plt.xlabel('frequency', fontsize=20)
    ax = sns.barplot(x="frequency", y="term", data=df_frequency)
    
    return docs

# %%
#merging features TF-IDF with data_frame
def merging(data_test1, tfIDFoutputFile):
    feature = pd.read_csv(tfIDFoutputFile, header=None, sep=",")
    feature.rename(columns={0: 'issueNumber'}, inplace=True)

    data_classifier = data_test1.join(feature, lsuffix='issueNumber', rsuffix='issueNumber')

    categories = data_classifier.columns.values.tolist()
    
    return data_classifier, categories

# %%
def eval_metrics(predictions, probabilities, y_test):
    
    y_pred = predictions.values
    y_proba = probabilities.values

    #receiving the y_test true value from each pull request
    y_true = y_test.to_numpy()

    print("Accuracy Score")
    acc_ml = accuracy_score(y_true, y_pred)
    print(acc_ml)

    print("---------")
    print("")

    print("Accuracy Score not normalized")
    acc_score = accuracy_score(y_true, y_pred, normalize=False)
    print(acc_score)

    print("---------")
    print("")

    print("zero_one_loss")
    zeroOne = zero_one_loss(y_true, y_pred)
    print(zeroOne)

    print("---------")
    print("")

    print("Fmeasure Score")
    fmeasure_score = f1_score(y_true,y_pred, average='micro')
    #fmeasure_score = f1_score(y_true,y_pred, average='macro')
    print(fmeasure_score)

    print("---------")
    print("")

    #AUC-PR
    print("AUC-PR")
    pr_score = average_precision_score(y_true,y_proba,average='micro')
    print(pr_score)
    #pr_score = average_precision_score(y_true,y_proba,average='macro')

    print("---------")
    print("")


    print("hamming loss average")
    hamming_loss = skm.hamming_loss(y_true, y_pred)
    print(hamming_loss)

    print("---------")
    print("")

    print("Jaccard samples")
    jaccard_score_samples = jaccard_score(y_true, y_pred, average='samples')
    print(jaccard_score_samples)

    print("---------")
    print("")


    print("Jaccard macro")
    jaccard_macro = jaccard_score(y_true, y_pred, average='micro')
    print(jaccard_macro)
    #jaccard_score(y_true, y_pred, average=None)

    print("---------")
    print("")

    return y_true, y_proba, y_pred, acc_ml, acc_score, zeroOne, fmeasure_score, pr_score, hamming_loss, jaccard_score_samples, jaccard_macro

# %%
def plot_classes(probability, y_true, y_test):
    precision = dict()
    recall = dict()
    average_precision = dict()

    n_classes = y_test.shape[1]

    for i in range(n_classes):
        precision[i], recall[i], _ = precision_recall_curve(y_true[:, i], probability[:, i])
        average_precision[i] = average_precision_score(y_true[:, i], probability[:, i])

    precision["micro"], recall["micro"], _ = precision_recall_curve(y_true.ravel(),probability.ravel())

    average_precision["micro"] = average_precision_score(y_true, probability, average="micro")

    print('Average precision score, micro-averaged over all classes: {0:0.2f}'
          .format(average_precision["micro"]))

    plt.figure()
    plt.step(recall['micro'], precision['micro'], where='post')

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title(
        'Average precision score, micro-averaged over all classes: AP={0:0.2f}'
        .format(average_precision["micro"]))

# %%
import io
def confusion_matrix(y_true, y_pred, confusionMatrix, i):

    data = multilabel_confusion_matrix(y_true, y_pred)
    
    labels = ['Google Common', 'Test', 'SO', 'IO', 'UI', 'Network',
              'Security', 'OpenOffice Documents', 'Database','PDF',
              'Logging','Latex']
      
    metrics = pd.DataFrame()
    line = []
    dataLine = ""
    dataLine = "Label, TN, FP, FN, TP"
    line.append((dataLine))

    for j in range (0,12):
        print(j)
        row = data[j]
        dataLine=""
        dataLine = labels[j] 
        print(dataLine)
        for x in np.nditer(row):
            dataLine = dataLine + "," + str(x)
            print(dataLine)
        line.append((dataLine))
        print(line)
        
        metrics = pd.DataFrame(line)
    
    metrics.to_csv(confusionMatrix + str(i) +'.csv' , encoding='utf-8', header=True, index=False , sep=',')

# %%
#build the model 

def build_model(test_type):

    if test_type == "DecisionTree":
        clf = BinaryRelevance(classifier=DecisionTreeClassifier(), require_dense = [False, True])
        #clf = ClassifierChain(classifier=DecisionTreeClassifier(), require_dense = [False, True])
    if test_type == "LogisticRegression":
        clf = BinaryRelevance(classifier=LogisticRegression(random_state=0), require_dense = [False, True])
        #clf = ClassifierChain(classifier=LogisticRegression(random_state=0), require_dense = [False, True])
    if test_type == "RandomForest": 
        clf = BinaryRelevance(classifier=RandomForestClassifier(criterion='entropy',max_depth= 50, min_samples_leaf= 1, min_samples_split= 3, n_estimators= 50), require_dense = [False, True])
        #clf = ClassifierChain(classifier=RandomForestClassifier(criterion='entropy',max_depth= 50, min_samples_leaf= 1, min_samples_split= 3, n_estimators= 50), require_dense = [False, True])
    if test_type == "MLPClassifier":
        clf = BinaryRelevance(classifier=MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu',solver='adam',random_state=1), require_dense = [False, True])
        #clf = ClassifierChain(classifier=MLPClassifier(hidden_layer_sizes=(150,100,50), max_iter=300,activation = 'relu',solver='adam',random_state=1), require_dense = [False, True])
    if test_type == "MLkNN":
        clf = BinaryRelevance(MLkNN(k=3))
        #clf = ClassifierChain(classifier=MLkNN(k=3))

    #This three works without probability
    if test_type == "LinearSVC":
        clf = BinaryRelevance(classifier=LinearSVC(), require_dense = [False, True])
    if test_type == "GaussianNB":
        clf = BinaryRelevance(classifier=GaussianNB(), require_dense = [False, True])
    if test_type == "RidgeClassifierCV":
        clf = BinaryRelevance(classifier=RidgeClassifierCV(alphas=[1e-3, 1e-2, 1e-1, 1]), require_dense = [False, True]) 
    if test_type == "BRkNNaClassifier":
        clf = BinaryRelevance(BRkNNaClassifier(k=3))

        
    return clf

# %%
def save_metrics(y_true, y_pred, acc_ml,acc_score,zeroOne,pr_score,hamming_loss,jaccard_score_samples,jaccard_macro, modelMatrix, metrics_by_class, i, configurationTFIDF ,num_feature ,stop_word ,size_test,test_type):

    line=[] 
    # line to csv report file
    
    names = ['Google Common',
'Test',
'SO',
'IO',
'UI',
'Network',
'Security',
'OpenOffice Documents',
'Database',
'PDF',
'Logging',
'Latex']
    

    prec, rec, fscore, sup = precision_recall_fscore_support(y_true,y_pred, average='micro')


    arr = [acc_ml,acc_score,zeroOne,pr_score,hamming_loss,jaccard_score_samples,jaccard_macro,prec,rec, fscore]
    columns = ['Accuracy','Acc-Score','zero_one_loss','AUC-PR','hamming loss average','Jaccard samples','Jaccard macro','Precision','Recall','Fmeasure']
  
    df_metrics2 = pd.DataFrame([arr],columns=columns)
    print(df_metrics2)

    print("---------")
    print("")

    x = precision_recall_fscore_support(y_true,y_pred, average=None)
    print("")
    print("")

    df_metrics_by_class = pd.DataFrame.from_records(x, columns=names, index=['precision','recall','f-measure','samples_tested'])
    print(df_metrics_by_class)

    print("---------")
    print("")

    df_metrics2.to_csv(modelMatrix, encoding='utf-8', header=True, index=False, sep=',')    

    df_metrics_by_class.to_csv(metrics_by_class, encoding='utf-8', header=True, index=False, sep=',')    

    dataLine = ""
    dataLine = "tf-IDFMin, tf-IDFMax, #_TopTerms,Stop_Word,Train/Test_Size,Algorithm,Accuracy_Score,Accuracy_Score_not_normalized,zero_one_loss, AUC-PR,hamming_loss_avg,Jaccard_samples,Jaccard_macro,Precision,Recall,Fmeasure_Score, i"
    line.append((dataLine))
    dataLine =  str(configurationTFIDF) + "," + str(num_feature) + "," + stop_word + "," + str(size_test) + "," + str(test_type) + "," + str(acc_ml) + ","+ str(acc_score) + ","+ str(zeroOne) + "," + str(pr_score) + ","+ str(hamming_loss) + ","+ str(jaccard_score_samples) + ","+ str(jaccard_macro)+"," + str(prec)+","+str(rec)+","+str(fscore)+","+str(i) 
    line.append((dataLine))
    print(line)

    metrics = pd.DataFrame(line)
    metrics.to_csv('./experiment/report'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+str(i)+'.csv', encoding='utf-8', header=False, index=False, sep=',')    
    np.savetxt(r'./experiment/report'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+str(i)+'.txt', metrics.values, fmt='%s', delimiter=',')

    return prec, rec, fscore, sup

# %%
import datetime

def persist_data(configurationTFIDF ,num_feature , stop_word , size_test , test_type , acc_ml , 
           acc_score , zeroOne , pr_score, hamming_loss, jaccard_score_samples, 
           jaccard_macro , prec , rec, fscore, i):
    now = datetime.datetime.now()

    templateData = pd.read_csv(template, sep=',')
    
    print ("Current date and time : ")
    print (now.strftime("%Y-%m-%d %H:%M:%S"))
    headerdf = ['date_time','tf-IDF', '#_TopTerms','Stop_Word','Train/Test_Size','Algorithm','Accuracy_Score',
                'Accuracy_Score_not_normalized','zero_one_loss', 'AUC-PR','hamming_loss_avg','Jaccard_samples',
                'Jaccard_macro','Precision','Recall','Fmeasure_Score','i']


    tup = ( now,str(configurationTFIDF) ,str(num_feature) , stop_word , str(size_test) , str(test_type) , str(acc_ml) , 
           str(acc_score) , str(zeroOne) , str(pr_score) , str(hamming_loss) , str(jaccard_score_samples) , 
           str(jaccard_macro) , str(prec) , str(rec) , str(fscore) ,str(i))

    print("tupla:", tup)
    print(len(tup))

    list_tup  = [ now,str(configurationTFIDF) ,str(num_feature) , stop_word , str(size_test) , str(test_type) , str(acc_ml) , 
           str(acc_score) , str(zeroOne) , str(pr_score) , str(hamming_loss) , str(jaccard_score_samples) , 
           str(jaccard_macro) , str(prec) , str(rec) , str(fscore) ,str(i)]


    dfTeste = pd.DataFrame.from_records(data=[tup], columns=[headerdf])

    data_list = templateData.values.tolist()
    data_list.append(list_tup)
    new_data = pd.DataFrame(data_list)  
    for row in templateData.itertuples():
        print(row)

    new_data.to_csv('./experiment/dfTeste.csv', encoding='utf-8', index=False, sep=',', header=headerdf)

# %%
def run_split(dataset_smote, test_type, confusionMatrix, modelMatrix, metrics_by_class, configurationTFIDF ,num_feature ,stop_word ,size_test):
    train = []
    test = []

    
    #our_X = data_classifier.iloc[:,16:916]
    #our_y = data_classifier.iloc[:,2:14]
    #dataset = pd.concat([our_y,our_X], axis=1)
    #dataset_smote = pd.concat([dataset, y_X_res], axis=0)
    
    #X = data_classifier
    X = dataset_smote
    splits = 10
    rs = ShuffleSplit(n_splits=splits, test_size= size_test, random_state=52)
    rs.get_n_splits(X)

    for train_index, test_index in rs.split(X):
         #print("%s %s" % (train_index, test_index))
         train.append(train_index)
         test.append(test_index)
        
    for i in range(0, len(train)):
 
        size_features = len(X.columns)
        #data = data_classifier.ix[train[i]]
        #data = data_classifier.iloc[train[i]]
        data = dataset_smote.iloc[train[i]]
        
        X_train = data.iloc[:,16:size_features]
        #X_train.to_csv('./experiment/X_train.csv', encoding='utf-8', index=False, sep=',')  
        #X_train1 = pd.concat([X_train, X_res])
        #X_train1.to_csv('./experiment/X_train1.csv', encoding='utf-8', index=False, sep=',') 
        #X_train1 = pd.read_csv('./experiment/X_train1.csv', sep=',')
        
        #X_train1.reset_index(inplace=True)
        #X_train1.drop(X_train1.index[[752,564]], inplace=True)
        
        #del X_train['issueNumberissueNumber']
        y_train = data.loc[:,'Google Common':'Latex']
        #y_train.to_csv('./experiment/y_train.csv', encoding='utf-8', index=False, sep=',')  

        #y_train1 = pd.concat([y_train, y_res])
        #y_train1 = y_train1.fillna(lambda x: x.median())
        #y_train1 = np.array(y_train, dtype=float)
        
        #y_train1.to_csv('./experiment/y_train1.csv', encoding='utf-8', index=False, sep=',')  
        #y_train1 = pd.read_csv('./experiment/y_train1.csv', sep=',')
                               
        #y_train1.reset_index(inplace=True)

        #y_train1.replace([np.inf, -np.inf], 0)

        #y_train1.dropna(inplace=True)

        #y_train1.dropna(axis=1)

        #X_train1.replace([np.inf, -np.inf], np.nan)
        
        #X_train.fillna(0)

        #X_train1.dropna(inplace=True)

        #X_train1.dropna(axis=1)
        
        #X_train1.to_csv('./experiment/X_train1_clear.csv', encoding='utf-8', index=False, sep=',') 


        #data = data_classifier.ix[test[i]]
        #data = data_classifier.iloc[test[i]]
        data = dataset_smote.iloc[test[i]]
        X_test = data.iloc[:,16:size_features]
        y_test = data.loc[:,'Google Common':'Latex']

        categories = y_test.columns.values.tolist()
        ids = y_test.index

        classifier_setup = build_model(test_type)
    
        clf = classifier_setup
        clf.fit(X_train,y_train)

        predict = clf.predict(X_test).toarray()
        probability = clf.predict_proba(X_test).toarray()

        predictions = pd.DataFrame(predict, index=ids, columns=categories) # with header
        probabilities = pd.DataFrame(probability, index=ids, columns=categories) # with header

        y_pred = predictions.values
        y_proba = probabilities.values

        y_true = y_test.to_numpy()

        y_true, y_proba, y_pred, acc_ml, acc_score, zeroOne, fmeasure_score, pr_score, hamming_loss, jaccard_score_samples, jaccard_macro = eval_metrics(predictions, probabilities, y_test)

        plot_classes(probability, y_true, y_test)

        confusion_matrix(y_true, y_pred, confusionMatrix, i)
        
        prec, rec, fscore, sup = save_metrics(y_true, y_pred, acc_ml,acc_score,zeroOne,pr_score,hamming_loss,jaccard_score_samples,jaccard_macro, modelMatrix, metrics_by_class, i, configurationTFIDF ,num_feature ,stop_word ,size_test,test_type)

        persist_data(configurationTFIDF ,num_feature , stop_word , size_test , test_type , acc_ml , 
           acc_score , zeroOne , pr_score, hamming_loss, jaccard_score_samples, 
           jaccard_macro , prec , rec, fscore, i)

# %%
#number of shuffles (folds)
splits=10

#defining paths
loggingFile = './experiment//TitleBody3GramTFIDF.txt'
binaryBodyTitle = './experiment/binaryBodyTitle.csv'
template = './experiment/dfTeste.csv'

configurationTFIDFList = [(1,1)]
#configurationTFIDFList = [(1,1),(2,2),(3,3),(4,4)]
#num_featureList = [25,50,100,500,1000,2500,5000]
num_featureList = [895]
size_testList = [0.2]
#size_testList = [0.2,0.3,0.4]
stop_wordList = ["Yes"]
#test_typeList = ["RandomForest","DecisionTree","LogisticRegression","MLPClassifier","MLkNN"]
test_typeList = ["RandomForest"]

#examples
#configurationTFIDFList = [(1,1),(2,2)]
#num_featureList = [25,50]
#size_testList = [0.2,0.3]
#stop_wordList = ["Yes","No"]
#test_typeList = ["RandomForest","DecisionTree"]

configurationTFIDF=(1,1)
num_feature=895

size_test=0.2

#stop_word = stop_wordList[i]
stop_word = "Yes"

test_type = "RandomForest"
# dont forget to have the file dfTeste.csv ready in the files folder only with the header!

def __main__():

    # getting length of list 
    lengthT = len(configurationTFIDFList) 
    lengthF = len(num_featureList) 
    lengthS = len(size_testList)
    lengthY = len(test_typeList)
    
    # Iterating the index 
    # same as 'for i in range(len(list))' 
    for t in range(lengthT): 
        for f in range(lengthF): 
            for s in range(lengthS):
                for y in range(lengthY):
                    print("----------------") 
                    print(configurationTFIDFList[t]) 
                    print(num_featureList[f]) 
                    print(size_testList[s]) 
                    print(test_typeList[y]) 
                    print("----------------") 

                    configurationTFIDF=configurationTFIDFList[t]
                    num_feature=num_featureList[f]

                    size_test=size_testList[s]

                    #stop_word = stop_wordList[i]
                    stop_word = "Yes"

                    test_type = test_typeList[y]
                    
                    tfIDFoutputFile = './experiment/tfIDFoutputFile'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    classifierFeatureInput='./experiment/train_file_test'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    termFrequencyTop50 = './experiment/termFrequencyTop50'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    predictions_result = './experiment/predict_file_'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    probabilities_result = './experiment/probability_file_'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    modelMatrix = './experiment/modelMatrix'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'
                    metrics_by_class = './experiment/metrics_By_Class'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)+'.csv'  
                    confusionMatrix = './experiment/CM'+ str(configurationTFIDF) + str(num_feature) + stop_word + str(size_test)+ str(test_type)
                    

                    data_classes = organize()
                    categories, IssuePRDataset = filtering(data_classes)
                    data_test1 = dataset_config(IssuePRDataset)
                    data_test1 = clean_data(data_test1)
                    
                    re_stop_words = remove_stop_words()
                    data_test1['corpus'] = data_test1['corpus'].apply(removeStopWords, re_stop_words=re_stop_words)
                    data = data_test1
                    data_test1 = apply_stem(data)
                    run_tf_idf(data_test1, configurationTFIDF, num_feature, tfIDFoutputFile)
                    
                    docs = analyze_top(data_test1, termFrequencyTop50)
                    data_classifier, categories = merging(data_test1, tfIDFoutputFile)
                    #SMOTE
                    our_X = data_classifier.iloc[:,16:916]
                    our_y = data_classifier.iloc[:,2:14]
                    dataset = pd.concat([our_y,our_X], axis=1)
                    #dataset.shape

                    X_sub, y_sub = get_minority_instace(our_X, our_y)   #Getting minority instance of that datframe
                    X_res,y_res =MLSMOTE(X_sub, y_sub, 100)     #Applying MLSMOTE to augment the dataframe
                    
                    y_X_res = pd.concat([y_res,X_res], axis=1)
                    #y_X_res.shape

                    dataset_smote = pd.concat([dataset, y_X_res], axis=0)
                    #dataset_smote.shape  
                    
                    #run_split(data_classifier, test_type, confusionMatrix, modelMatrix, metrics_by_class, configurationTFIDF ,num_feature ,stop_word ,size_test)
                    run_split(dataset_smote, test_type, confusionMatrix, modelMatrix, metrics_by_class, configurationTFIDF ,num_feature ,stop_word ,size_test)

# %%
__main__()
# Out:
# ----------------
# (1, 1)
# 895
# 0.2
# RandomForest
# ----------------
# 0      question reduc clutter caus inlin classesth class guiactionparseactionjava good exampl...
# 1      mani export bibtex file eg dblp acm contain journal confer name togeth addit inform li...
# 2      bugfix introduc clone oper take much time save databas entri check whether clone oper ...
# 3      possibl access case changer right click text field would obvious drawback could access...
# 4      found directori open access journal provid api search return result bibjson would nice...
# 5      room improv save chang exitfirst open multipl bib file close dialog pop clear databas ...
# 6      discuss switch utf utf netsfjabrefimporteropendatabaseactiontestdefaultencod utf use c...
# 7      still support proxi authent unfortun usernam password specifi command line paramet pre...
# 8      current global set control whatev use biblatex mode usual use biblatex file parallel o...
# 9      add descript especi sinc click insid column alway open rate menu inconveni want open d...
# 10     ad tooltip know mean column headtitl r r q f p obvious field doesnt fit column width s...
# 11     discov strang behavior click rank column header doi column switch posit entrytyp entry...
# 12     move rank column end entri tabl use drag drop file url column took place click file ic...
# 13     current popup doi allow click doi possibl iss copi doi complet link copiedusecas quick...
# 14                                                                                           nan
# 15                                                                                           nan
# 16     current entri author noth shown author column main tabl would nice case would fall bac...
# 17                                       similar ide close open databas continu work new databas
# 18     current global set control whatev use biblatex mode usual use biblatex file parallel o...
# 19     problem entri entri type handl moment see background current near way access data stor...
# 20     problem entri entri type handl moment see background current near way access data stor...
# 21     introduc follow new featur chang serial bibtex entri first requir option field written...
# 22                                                                                          grab
# 23     configur cite command citep texstudio seem ignor set grab assum imposs set cite comman...
# 24     introduc follow new featur chang serial bibtex entri first requir option field written...
# 25     use latest master build libreoffic ubuntu x connect libreoffic via manual connect inse...
# 26     search acm matter get follow error javaioioexcept cannot pars number hit netsfjabrefim...
# 27     problem entri entri type handl moment see background current near way access data stor...
# 28     would great could right click refer copi refer format select style someth mendeley hel...
# 29     helloi updat v open bibtex databas attach got error messag attach know solveregardscam...
# 30     file start bibtex item eg articl xxxxxx author xxxxxxxx use save databas line break en...
# 31     preambl field present omit newlin line preced encod line save file result file readabl...
# 32     enter url url field url main tabl page click url doi link translat someth like url con...
# 33     use find unlink file work scan directori work fine press appli display import databas ...
# 34     current offer sort save chang sort demandth sort function move sort button follow popu...
# 35     bibtex biblatex mode store file avail detect bibdatabasetypedetect store remov bibtex ...
# 36     introduc follow new featur chang serial bibtex entri first requir option field written...
# 37     file start bibtex item eg articl xxxxxx author xxxxxxxx use save databas line break en...
# 38     preambl field present omit newlin line preced encod line save file result file readabl...
# 39     would like abil reformat entri bib file sinc otherwis whole entri mark chang version c...
# 40     possibl specifi keyword separ automat generat group method bibentri assum usedif keep ...
# 41     moment bibtexentri requir option field remain field seen sourc tab entri editor add ta...
# 42     current way fetch text internet urldownload getresult logicnetnetutil particular reaso...
# 43     except thread awt eventqueu javautilnosuchelementexcept valu present javautiloptionalg...
# 44     ive got npe save investig thread level logger msg n javalangnullpointerexcept netsfjab...
# 45     im use mysql cant export bib sql databas fine use dont know whyth error error sql synt...
# 46                                                                             avail text select
# 47     im use mysql cant export bib sql databas fine use dont know whyth error error sql synt...
# 48     entri unmark field markedentri remov field shorter complet entri chang align chang awa...
# 49     current entri prefer follow pseudo model class preferenceentri string key object valu ...
# 50     refer manual softwar titl author develop team year version version url cur brace autho...
# 51     set libr ofifc connect around notic brows nothinghowev direct insert correct path work...
# 52     dont know relev want chang case titl server refer need right click chang case everi re...
# 53     filenam link pdf convert lowercas outsid run cleanup renam pdfs renam move file back p...
# 54     master abi follow bib entri articl mlu author ralph mietzner frank leymann tobia unger...
# 55     v dev master abiv search entri lost somehow grab im drop pdf onto preview noth happen ...
# 56     notic use differ version time load differ file mean differ version read perhap differ ...
# 57                                    add test bibtexparsertest make sure break meta data format
# 58     key bind print preview work introduc key bind copi preview work mayb someth toolbar vi...
# 59     use find unlink file work scan directori work fine press appli display import databas ...
# 60     entri cut delet preview panel updatedtest current master aa c ea e c e e f c f b notup...
# 61     current web search fetch arxivorg fetch inspir display databas name display see pull r...
# 62                     somehow entri restor undo cut delet entri thought mess behav like merg in
# 63     current web search fetch arxivorg fetch inspir display databas name display see pull r...
# 64     issu summar avail formattersth aim improv name descriptionsi think practic way direct ...
# 65     base earlier discuss eg koppor koppor seem make sens redefin restructur properti field...
# 66     click tab edit part expect focus first editor field current press tab get focus first ...
# 67     size databas properti dialog fix open dialog first time seem high enoughth dialog fix ...
# 68     dev snapshot master f window delet entri databas refetch entri via doi bibtex convert ...
# 69     save sort order dialog select field would expect choic select field appli save action ...
# 70     size databas properti dialog fix open dialog first time seem high enoughth dialog fix ...
# 71     version avail box window dev snapshot master oper system version window enterpris edit...
# 72     unit test catch except call method call fail nasti disadvantag stacktrac real except h...
# 73                                                 take age machin cancel still valid result set
# 74     version onward includ win enterpris search larg mb bib file result immedi search block...
# 75     switch bibtex mode write comment meta databas type bibtex biblatex mode comment meta d...
# 76                                                 take age machin cancel still valid result set
# 77     version dev snapshot master f f cec ubuntu tri export databas differ format tri simple...
# 78     dev master commit ed b b fd b f b cdcreproducablestep reproduc open export extern sql ...
# 79                                                                            grab request stekk
# 80     system ubuntu linux version generic buildd lgw gcc version ubuntu ubuntu ubuntu smp fr...
# 81     monitor goe ubuntu goe sleep log user interfac look like grey recov minim maxim indivi...
# 82     version dev snapshot master cf window step reproduc close open file open preferencesre...
# 83     version window x dev snapshot master cf window cannot import ris file messag lower lef...
# 84     rightclick formatt author field goe wrongminim exampl stefan kolb j rg lenhard guido w...
# 85                                                     click year column doesnt affect sort tabl
# 86     entri cut delet preview panel updatedtest current master aa c ea e c e e f c f b notup...
# 87     notic encod issu run gradlew check commandlin window specifi line follow bibteximport ...
# 88     version step reproduc file import current databas select utf encodedbib use file view ...
# 89     gypten titl field result gypten correct syntax result pdf gypten field titl gypten pro...
# 90     version step reproduc believ html dash pull titl bib file creat ver revert back ver at...
# 91     base discuss creat empti databas singl entri singl field contain save encod utf articl...
# 92     discov might problem intellij restructur import vs eclips run problem would like discu...
# 93     version step reproduc believ html dash pull titl bib file creat ver revert back ver at...
# 94     hi save simplecsvimporterjava compileallbat togeth instal path run bat simplecsvimport...
# 95     version window step reproduc use citat file renam jstyle testtxt look bracketbefor bra...
# 96     version linux work least step reproduc entri link pdf use cleanup entri function selec...
# 97     equal method bibentri overwritten compar entri base id type field valu test parser imp...
# 98     jar dev snapshot master f e jarlinux mint lmdea chines first name written tse tung not...
# 99     version avail box dev snapshot master e f oper system version window step reproduc ope...
# 100    current help access menu help helpi think obvious user help henc inform menu help onli...
# 101    current help access menu help helpi think obvious user help henc inform menu help onli...
# 102    version ubuntu new style dialog beauti thank muchwhat miss file filter allow show jsty...
# 103    version ced aefba e f b fdb ec master win x java step reproduc open bib dbs click view...
# 104                                                                       see use gradl task now
# 105    version dev window step reproduc creat entri url field simpler url like work expect cl...
# 106    version ubuntu new style dialog beauti thank muchwhat miss file filter allow show jsty...
# 107    version master window x doent updat display bibtex key doi fetch dialog updat click ge...
# 108    version osx step reproduc creat new bibtex databas add articl entri librari base endf ...
# 109                                  window show error consol window program output resizableref
# 110    version dev snapshot master window bug current master branch bug found step reproduc c...
# 111                                                                                          nan
# 112    version window upgrad version file link contain blank broken use sumatra pdf tri open ...
# 113                           import pubm nbib format would nice addit importersa exampl see see
# 114    dev snapshot master f ewindow amd step reproduc take bib file press export html open h...
# 115    current architectur analysi stumbl part code id like discuss infam class guiglob sever...
# 116    version os agnosticrecommend chang right click chang case entri follow lower case lowe...
# 117                                                                      current renam bibtexkey
# 118                 author h e l grave e ne fiaux shown fiaux entri preview would expect fiaux h
# 119    right pars serial handl uniform way see eg possibl design come mind bibpars bibwrit co...
# 120                                    view regular releas schedul would nice perform auto updat
# 121    dev version window step reproduc entri doi fetcher cant find bibtex data exampl click ...
# 122                                                                                          nan
# 123    use releas bit window pro x java disabl autocomplet entri editor disappear immedi tri ...
# 124    lenhard intend thought keep sourc possibl tex author ahronovitz miha amrhein dustin an...
# 125    version dev snapshot master f window issu found version dev snapshot master bd c seem ...
# 126                           import pubm nbib format would nice addit importersa exampl see see
# 127    version windowsxp know know thing happen ubuntu group display wrong number entri examp...
# 128    version window export ms offic xml short titl inform miss generat xml file bib file ms...
# 129    follow method getextens getdescript implement almost import done ignor tag correspond ...
# 130    run v window computerfor conveni practic reason use semicolon delimit keyword listi sp...
# 131    want port journal abbrevi dialog javafx play dialog first didnt understand everyth mea...
# 132    bug rather question user behaviorjabref construct work sever bib file openat moment se...
# 133    click bibtex key crossref field lead parent parent indic exist children bibtex key cli...
# 134    window x enter follow entri run integr check get url odd number unescap biber etc hand...
# 135                              add html unicod formatt cleanup save action oscargus someth you
# 136    imho benefit googleurlcleanerjava clear extra action rightclick context menu clean goo...
# 137    version mint escap charact v caron render proper main panel hand v z render correct bt...
# 138    right click mark entri main tabl success updat bibtex data doi entri longer markedvers...
# 139    hi save simplecsvimporterjava compileallbat togeth instal path run bat simplecsvimport...
# 140    use biblatex format would like possibl date formatt could similar alreadi exist format...
# 141    new issn integr check found issn miss dash db exampl x insead x would nice could provi...
# 142    glitch b present beta menu item file save select plain bibtex local even ad key save s...
# 143    version mac os x libreoffic step reproduc connect libreoffic text document select styl...
# 144    follow discuss today devcal come outlin desir high level architectur data status quo r...
# 145    follow discuss today devcal come outlin desir high level architectur data status quo r...
# 146                                                         cloudentcom asset c b f f e f bb png
# 147                                                        creat instal icon use instal uninstal
# 148    version linux mageia step reproduc creat entri titl field contain latex command look t...
# 149    version got bib file comment clean couldnt read error open file gave inform messag nul...
# 150    versionjabref window amd java step reproduc select entri go file select export use bib...
# 151    bibtexmlimport accept xml file tag syntax like otherwis read data even file shouldnt p...
# 152    version step reproduc prerequisit regist default applic bib file close instanc open bi...
# 153    problem connect libreoffic use problem dev snapshot master f daacjar libreoffic java u...
# 154    use libreoffic insert refer entri assign bibtexkey entri get document click refresh ci...
# 155    version devstep reproduc use charact field entri save file entri look like articl asda...
# 156    advanc undo redo messag quit nice think realiz shown status bar undo redo think easies...
# 157    version latest dev cento window step reproduc remov field complet sourc editor save da...
# 158    version window x isbn bibtex fetcher includ word seiten pagetotalsampl isbn pagetot fi...
# 159    version window corpor author editor input cur brace mention section manual biblatex pa...
# 160    persian local persian file current directori directori chines local recent updat file ...
# 161    version latest devstep reproduc use relax specifi letter abbrevi author first name say...
# 162    window amd java import recogn year biblatex file cannot export xml word format year st...
# 163    help page describ featur find duplic helpjabreforg en finddupl help button ad find dup...
# 164                                                        check current build travi ciorg build
# 165    dev snapshot fix scholar encod b window amd java entrytyp articl author requir field b...
# 166    window amd java file open databas open bib file show prefer string work directori stri...
# 167    origin report sait umar forum note pleas use issu tracker bugreport featur request que...
# 168    version window bitwhen sort accord month ascend descend switchedfor year exampl descen...
# 169    current beta b get window lot gui draw issu seem part window drawn drag mous cursor wi...
# 170    version step reproduc use style author format follow articl format author lastfirstini...
# 171    version step reproduc use style author format follow articl format author lastfirstini...
# 172    run multi monitor setup eg second screen merg bibtex dialog alway appear first screen ...
# 173    window amd java step reproduc databas differ entri hit get fulltext entri eg abc searc...
# 174                                            complet new databas creat confirm requir close it
# 175    dev snapshot master eb window amd java step reproduc entri editor bibtexkey insert but...
# 176    version debian jessiehello would like set key generat produc key type author year titl...
# 177    workaround renam file via cleanup entri move file directori move subfold articlebooket...
# 178    field year consist numer year format allow year report check integrityedit format allo...
# 179    offici bibtex spec edit book exampl second ordin first letter capitalizeda check first...
# 180          subtask extract checker class integitycheckjava file would like improv code qualiti
# 181    user quick want copi past entri render specifi format either want past refer review wo...
# 182    follow todo export compani author corpoat languag lcid map support custom entri type h...
# 183    sinc export mod format would nice import formatther xml schema avail think would best ...
# 184    atm xml file compar string major disadvantag hard spot error errorwel discov awesom li...
# 185    let rephras use keyword separ ambigu default set lead stringtoken split ad keyword use...
# 186    hiim use quit long time im satisfi thank work im write phd thesi miss import featur hi...
# 187    possibl specifi keyword separ automat generat group method bibentri assum usedif keep ...
# 188    version mac ox x step reproduc ensur main file directori empti file prefer attempt dow...
# 189    follow click link stay blue see screenshot possibl link instead changelogmd releas rep...
# 190    version dev latest window step reproduc entri url field check integr url amp insid int...
# 191    version dev snapshot master ff c b window amd java step reproduc open see toggl global...
# 192    version debian jessiestep reproduc click help insid browser open depend fact oper syst...
# 193    window amd java step reproduc load pubm medlin entri id make sure sign abstract escap ...
# 194    ui menu entri enabl despit fact databas load instanc rank action default disabl action...
# 195    version earlier window ubuntu step reproduc import ris file scopus bib databas check j...
# 196                                       doi import work ris standard field patent import other
# 197    eg remov obsolet miss languag key gradlew b localizationgradl generatemissingtranslati...
# 198    web search give inconsist wrong feedback tri fetch without connect internet step repro...
# 199    sort featur requestit would great provid shortcut key copi url name bibtexkeydur discu...
# 200    current popup doi allow click doi possibl iss copi doi complet link copiedusecas quick...
# 201    dev snapshot master c f window amd java current master branch master c f signific decr...
# 202    version window step reproduc open updat notif appear click ignor updat close restart u...
# 203    window amd java step reproduc load pubm medlin entri id make sure sign abstract escap ...
# 204    ive observ regress certain condit field display better undo commit add new pull reques...
# 205    dev snapshot master afbb window amd java step reproduc chang prefer appear set tabl fo...
# 206    version mac osx step reproduc instal differ locat prefer bibtex key generat prefer app...
# 207    ive observ regress certain condit field display better undo commit add new pull reques...
# 208    helloalthough resolv issu googl search still problem googl search work hour tri set en...
# 209    follow problem tschechlovdev atm commit revert found discuss http stackoverflowcom que...
# 210    dev snapshot master c f window amd java current master branch master c f signific decr...
# 211    version mac osx step reproduc instal differ locat prefer bibtex key generat prefer app...
# 212    dev snapshot master c f window amd java current master branch master c f signific decr...
# 213    version window step reproduc open creat databas add entri use articl save databas skip...
# 214    latest dev versionstep reproduc entri editor bibtex sourc tab generat pars error examp...
# 215                                                                                     notic in
# 216    open complexbib sort author editor search bard doubl click bostr search hit entri edit...
# 217    fosshub hack see softwar instal infect malwar overwrit boot loadera ist offer fosshub ...
# 218    dev snapshot latex free field e ewindow amd java select item tri dragndrop onto exist ...
# 219    dev snapshot latex free field e ewindow amd java creat new group tri dragndrop group o...
# 220    netsfjabreflogicsearchmatcheshighlighterhighlightwordswithhtml doesnt respect exist ht...
# 221    latest dev version see entri return fetcher contain field eid javalangassertionerror e...
# 222    develop version mac os x step reproduc open small bib databas work entri open entri ed...
# 223    dev snapshot master f ae window amd java step reproduc entri editor clear field bibtex...
# 224    dev snapshot master fb dwindow amd java start coupl group item articl reassign articl ...
# 225                  workflow check integr get import wish could default shortcut keybind action
# 226    annoy current master creat entriesdelet entrycursor move seach fieldpast entri clipboa...
# 227    dev snapshot javafx e window amd java error consol see display follow grab scroll disp...
# 228    dev snapshot javafx e window amd java error consol see display follow grab scroll disp...
# 229    function ad broken current build name fail fetch pdf file generat empti file without e...
# 230    dev snapshot master ee window amd java step reproduc open entri editor chang entri fre...
# 231    seem implement astrophys data system fetcher brokenw get servic unavail error although...
# 232                                                 see issu detail githubcom helpjabreforg issu
# 233    dev snapshot master ca window amd java biblatex mode month field sourc shown entri edi...
# 234    version informationjabref version dev snapshot master f fa window amd java window issu...
# 235    issu seem left tri return invalid isbn messag valid isbn isbn site find book messag mi...
# 236    automat cours anonym collect usag statist exampl chang prefer determin better default ...
# 237    version ubuntu save databas chang permiss file read write user access anybodi els prob...
# 238    dev snapshot master cwindow amd java step reproduc open exist creat new databas creat ...
# 239    dev snapshot master ee blinux generic java deal share databas postgr least metadata da...
# 240    drop menu set custom general fieldth code bib file comment meta selector status approv...
# 241    version master step reproduc search arbitrari search term use dblp cachedthreadpool er...
# 242    exampl custom type even type might miss author field lead well form bibtex key except ...
# 243    window amd java reset prefer import prefer work custom entri typesstep reproduc reset ...
# 244       version mac os x x java step reproduc bibtex custom entri type chang entri click appli
# 245                    problem might occur custom type store file prefer name similar case handl
# 246    work primari secondaryoptionalfield use biblatex logic move gui code handl requir gui ...
# 247    import prefer anoth custom entri type add restart display custom entri type correct un...
# 248    version think dit work tooaccord code biblatex cleanup cleanup move field year month e...
# 249    qualiti look full text document great want entri shortcut list key bind multipl entri ...
# 250    prefer reset want download file suggest store c would prefer use sophist locat eg rela...
# 251    version devstep reproduc creat entri bibteykey otherwis field set run integr check int...
# 252    window amd java step reproduc load pubm medlin entri id make sure sign abstract escap ...
# 253    version window step reproduc main menu group toggl group interfac automat creat group ...
# 254    version ubuntu group membership entri store group field group identifi name multipl gr...
# 255    window amd java step reproduc creat bibtex file group mygroup mygroup altern assign en...
# 256    attempt import follow doi releas journal titl pick occur number doi suspect problem ge...
# 257    biblatex document section field alias describ address locat annot annot jurabib archiv...
# 258    field id bibentri intern id use bibtexkey set use setcitekey moreov id uniquehowev lot...
# 259    version window step reproduc enabl special field show relev show read status expect be...
# 260    window amd java step reproduc import pubm id run pdflatex file use failur compil due s...
# 261    seem offer second kind xml serial bibtex xmlns bibtex worth keep differ xml schema xml...
# 262    version window amd java step reproduc db bibtex mode techreport entri integr check rep...
# 263    version organ static group name like group aa subgroup bb subgroup b group aa subgroup...
# 264    dev snapshot master cfbc jarjava version java tm se runtim environ build b java hotspo...
# 265    use name field use dynam group lower case eg comment instead comment although field na...
# 266    version step reproduc differ file attach paper type ie pdf move file file directori tw...
# 267    version mac os x step reproduc creat bibliographi link pdf file field absolut path set...
# 268    hisinc problem renam file move directoriesmi folder structur like base directori mydat...
# 269    function collaps subtre group ui work see http discoursejabreforg subtre close doesnt ...
# 270    version dev snapshot master e f window amd java step reproduc creat entri doi z doi fi...
# 271    version dev snapshot master e f window amd java step reproduc creat entri doi z doi fi...
# 272    version dev snapshot master f cf linux fc x amd java fedora step reproduc tri fetch in...
# 273    linux mint latex backslash tild escap diacrit display correct entri tabl exampl bibtex...
# 274    linux mint latex backslash tild escap diacrit display correct entri tabl exampl bibtex...
# 275    window x biblatex mode web search acm portal guid comput lieratur search inform extrac...
# 276    devwindow amd java extern chang mean longer shut normal forc kill processstep reproduc...
# 277    descript group option dynam group entri search field keyword regular express check can...
# 278    window amd java step reproduc creat new entri pie n kowski g author author name correc...
# 279    version dev snapshot masr jar linux lmde betsystep reproduc creat new entri titl artic...
# 280    version ubuntu problem observ version step reproduc export ris journal articl scienced...
# 281    window amd java notic errorn biber compil clean sign without risk found bib file doubl...
# 282    window amd java notic errorn biber compil clean sign without risk found bib file doubl...
# 283    window x dev snapshot multicleanup ddecdfd fwindow java step reproduc open new databas...
# 284    click new bibtex entri button past doi id field click generat button success download ...
# 285    dev snapshot master df bwindow amd java author field entri editor sto anova ivanka aut...
# 286    rememb anyon els unicod latex convert handl combin accent ie u convert interest enough...
# 287            would solv serious issu idea use simpl extend grammarw would need convers htmlref
# 288    found click clear rank rank tag set rank instead remov prioriti tagperhap littl bug fe...
# 289    current use apach common collect googl guava googl guava seen replac common collect mo...
# 290    move away sourceforg thus packag renam toothi could make harder strengthen independ so...
# 291    version window edit keyword clear field prioriti rank qualiti relevancestep reproduc w...
# 292    dev snapshot master e e window amd java detail inform migrat old preferencesopen g abc...
# 293    propos add search function group unfortun java knowledg near non exist propos contribu...
# 294    version inform window amd java step reproduc open databas properti dialog click enabl ...
# 295    hi cant get camel key key pattern work reason im use latest releas key pattern auth ye...
# 296    hii encounterd unexpect behaviour creation key im use window amd java step reproduc pr...
# 297    version step reproduc creat empti databas creat group need add anyth add subgroup grou...
# 298    includ dev snapshot masr jar linux lmde betsyth cleanup window cannot resiz make impos...
# 299    version ive set right path applic texstudioapp prefer click icon menu bar receiv messa...
# 300                                                                 possibl select differ folder
# 301    version slackwar hint use develop version ensur use latest onestep reproduc add new ar...
# 302              request hard implement moment sinc listen expand collaps event easi wait javafx
# 303    im use b window x java updat set firefox open bib file jabrefex directori specif alrea...
# 304       issu made direct result short issu see possibl show issu templat ui forc user fill out
# 305    version mac os x connect openoffic fail messag file applic openofficeapp content resou...
# 306    complain forum googl scholar bibtex qualiti best good databas research disciplin prese...
# 307    version debian jessiestep reproduc open libreoffic document select bibliographi style ...
# 308                                                   order reproduc issu without restart jabref
# 309    dev snapshot brace check followup af ticket suppos mention problem implement group pan...
# 310                          dialog modal updat new event arriv ie need close open see new event
# 311                                                                          new develop version
# 312             happen filenam long default field length cloudentcom asset b c e e b c b f dbpng
# 313    version window export ms offic xml name cur brace treat compani export suchin section ...
# 314    hiim use quit long time im satisfi thank work im write phd thesi miss import featur hi...
# 315    notic architectur test current cover static import therefor miss least depend want for...
# 316    hi im issu ad delet etc group osx basic stop working experi problem group earlier vers...
# 317    version linux generic amd java ubuntu find file match year year author year auth exten...
# 318    version dev master commit e fc c run generic ubuntu smp fri dec utc x x x gnu linux li...
# 319    follow discuss decid replac databas librari huge impact code bibdatabas vs biblibrari ...
# 320    version dev master commit e fc c run generic ubuntu smp fri dec utc x x x gnu linux li...
# 321    entri link pdf file arellano natur languag process textual requirementspdf pdf pdf ava...
# 322    betawindow amd java happen strang behavior click group log detail detail inform open g...
# 323    enter date field click save enter field date inform gone enter date bibtex code date c...
# 324    dev snapshot master e e window amd java step reproduc right click entri choos attach f...
# 325                         previous possibl select group relat group set intersect union invert
# 326    bug report import field yearaccess monthaccess dayaccess offic xml file store format m...
# 327                                           resort group drag drop rais discuss githubcom issu
# 328    version snapshot debian jessi amd step reproduc launch select view bibliograph item fi...
# 329    version dev linux mint cinnamon ubuntu step reproduc open java jar select entri doubl ...
# 330    dev f b dbfefe fbdf ce f blinux manjaro amd java step reproduc start click option cust...
# 331    updat pleas note disabl phrase search oper boolean oper due technic problem time phras...
# 332            context menu miss delet assign file open file cloudentcom asset aa c c e bb f png
# 333    latest masteredit entri chang author exampl code editor remov valu type ctrl z except ...
# 334    relat articl tab usual produc link sever articl click dont see way go backward get lin...
# 335    dev snapshot master ebdmac os x x java step reproduc select entri doubl click select e...
# 336    happenbi default old entri editorth file never got delet filesystemso add second confi...
# 337    qualiti look full text document great want entri shortcut list key bind multipl entri ...
# 338    sort featur requestit would great provid shortcut key copi url name bibtexkeydur discu...
# 339                                                                                          nan
# 340                                                          select remov link file context menu
# 341    bibtex file contain edit book find duplic function consid duplic tri merg themalso sho...
# 342    alreadi notic sharelatex integr stuff databas chang event trigger everi charact insert...
# 343    group rais occur current develop build chang bibentri possibl solut main tabl listen c...
# 344    dev snapshot master e b ac cmac os x x java bug autocomplet work author journal field ...
# 345    window scalabl move button intellig given rangesc limit minimum maximum size select de...
# 346    moment workaround either reset manual replac pref filemodifi ctrl alt meta shift follo...
# 347    versionjabref dev snapshot master c c linux generic amd java step reproduc edit field ...
# 348    version dev snapshot master bee c ai use line java jar dev snapshot master bee c ajar ...
# 349    select file general tab press delet keyresult want delet whole entryexpect file assign...
# 350    add use id base entri generat id type sao nasa ad enter rspta result bib file look lik...
# 351    version beta ubuntu open jdk high dpi screenth scale menu tabl icon look good font siz...
# 352    version dev snapshot master e fbf linux generic amd java onubuntu step reproduc check ...
# 353    open entri editortab focus press ctrl plus ctrl minus navig notic focus still tabl the...
# 354    step reproduc open entri entri editor entri must field bibsourc switch biblatex sourc ...
# 355    version beta debian stretch amd step reproduc add book entri add titl author etc save ...
# 356    report wujastyk sourc panel updat correct casesstep add articl display bibtex sourc im...
# 357    version beta ubuntu oracl jvmstep reproduc add entri group right click press move grou...
# 358    dev snapshot master window amd java step reproduc start databas contain articl group a...
# 359    seem memori leak entri editor current master latest commit e c c dc f f c devwindow am...
# 360                                              tedious deselect issu first select singl fix it
# 361    function normal bibtex name format got lost beta beta grafik user imagesentcom bc e da...
# 362    text form field bad align sometim grey backgroundjabref dev snapshot master c ca e lin...
# 363             version beta window amd java display clutter user imagesentcom f ff c dd e b png
# 364    beta window amd java step reproduc enter author editor name lastnam matter alert trian...
# 365    time want share literatur pdfs friend easi select want entri hard pick selet pdfsi hop...
# 366    tobiasdiez introduc field valid entri editor clear benefici imag user want itw add pre...
# 367    latest master valid messag entri editor shift bottom appear fix constant user imagesen...
# 368                             chang like generat new bibtexkey renam file display entri editor
# 369    dev snapshot master abf linux generic amd java step reproduc edit requir field tab sel...
# 370    dev snapshot master aalinux generic amd java edit tab titl field select word right cli...
# 371    beta window amd java step reproduc enter author editor name lastnam matter alert trian...
# 372    use arxiv search find insert entri bib file onlin file link insert general tab there w...
# 373    remov file link entri editor go sourc tab hit ctrl z except occurshit whole entri dupl...
# 374    dev snapshot master b c mac os x x java step reproduc input leftright search bar tri u...
# 375    minim exampl articl bad cloud titl cloud comput synopsi recommend author badger lee ot...
# 376    devlinux generic amd java step reproduc open group interfac group toggl group interfac...
# 377                           latest version latexeditor see push latexeditor could remov jabref
# 378    version mac os x x java normal ul somewher someon ul somewher someon undesir presum si...
# 379                        exist file descript shown chang editingfollow githubcom issu issuecom
# 380    renam link file fail alreadi exist file namein general tab entri editor right click li...
# 381    dev snapshot master b b window amd java step reproduc link pdf entri open pdf right cl...
# 382    dev snapshot master b b window amd java step reproduc link pdf folder main file direct...
# 383    websit offer bibliograph data machineread format eg bibtex oder ris text download link...
# 384    dev snapshot master fcac linux fc x amd java seem bibtex key generat use cross ref inform
# 385    gui disappear run file quit menu return consolene press ctrl c sever timesstart comman...
# 386    relat use lo debian connect work without problem tri connect previous report connect p...
# 387    version window follow screenshot n seem littl intrus user na applic excerpt bibliograp...
# 388    version cento expect select open folder entri context menu folder contain articl openw...
# 389    version window see follow screenshot textendash cannot resolv correspond charact appli...
# 390    version java guess group titl mouseov method display group descript unfortun littl bit...
# 391                                                           close entri editor first afterward
# 392    point dev develop start happen problem dev coupl week agoit unusu except occur give bi...
# 393    betalinux fc x amd java mayb got someth wrong open prefer extern programm specifi cite...
# 394    linux generic amd java step reproduc creat identi folderstructur window linux fe use s...
# 395    version linux generic amd java step reproduc select entri without file link match file...
# 396    version linux gentoo amd java step reproduc search physrevlett select cachedthreadpool...
# 397    use dev oct java linux x choos check integr relat larg bib file entri appear likeit ha...
# 398    creat new databasecopi past bibtex entryhit ctrl awt eventqueu error orgjabrefguibasep...
# 399    linux generic amd java step reproduc creat identi folderstructur window linux fe use s...
# 400    version dev snapshot master ebdea linux gentoo amd java get stderr fatal error content...
# 401    data shorthand field get display keyword fieldjabref version dev snapshot master f fec...
# 402    im use version archlinux linux arch amd java step reproduc set option prefer entri tab...
# 403    dev snapshot master ea bc clinux gentoo amd java html code tooltip search field click ...
# 404                                                    creat group paper cite paper via aux file
# 405    run java issu collect java relat problem start point support jresthi present jre outpu...
# 406    implement fileannotationtab javafx manag creat work prototypedu limit develop resourc ...
# 407    got indexoutofbound except previous less could reproduc entri requir field set eg arti...
# 408    test latest master version problem persistsjabref version dev master aa window step re...
# 409    dev snapshot master dlinux generic amd java open jr go edit tab go end piec text like ...
# 410    test latest master version problem persistsjabref version dev snapshot master f linux ...
# 411    window amd java ram use preview fulli releas preview less releas run away usag occur p...
# 412    seem mac version custom key generat author year veryshorttitl generat key includ trail...
# 413                       test latest master version problem persist icon right side shouldnt it
# 414              doubl click direct open pdf furthermor button open pdf lupe search pdf open one
# 415    ran need autolink file generat bibtex key use reason default set auth year renam file ...
# 416    test latest master version problem persistsjabref version devstep reproduc look search...
# 417    current master open bib filemodifi bib file extern editor add exampl group tree inform...
# 418    window amd java ram use preview fulli releas preview less releas run away usag occur p...
# 419    origin report forum test latest master version problem persist creat techreport entri ...
# 420    test latest master version problem persistsjabref dev snapshot master ca linux generic...
# 421    dev snapshot master ebdwindow amd java newli implement group filter search exhibit mas...
# 422    issu version finestep reproduc file export select ms xml format saveexpect file save n...
# 423    delet entri current master c b sever except thrown subscrib method listen orgjabrefmod...
# 424    dev snapshot maintabl updat f window amd java select item main tabl associ group rathe...
# 425    entri reproduc articl abdala author fernando abdala titl redescript textit platycranie...
# 426    maco java version version dev snapshot master f jarinvok java jar command linei move u...
# 427    start npe tobiasdiez introduc circular dependencyin creation exportfactori getfileexte...
# 428    version start search databas drop menu appear search window although tri global disabl...
# 429    issu version finestep reproduc file export select ms xml format saveexpect file save n...
# 430    issu version snapshot reproduc file export expect list format ms xml format xml open d...
# 431    test latest master version problem persistsjabref dev snapshot master b dfwindow amd j...
# 432    window amd java import recogn year biblatex file cannot export xml word format year st...
# 433    use debian unstablei export entri zotero ris format includ extern file eg snapshot zot...
# 434    greetingsim develop academ blogger toolkit plugin wordpress user difficulti import ris...
# 435    greetingsim develop academ blogger toolkit plugin wordpress user difficulti import ris...
# 436    base discuss seem move junit somehow turn parameter test travi that bad mean import te...
# 437    test latest master version problem persistsjabref version debian buster sidstep reprod...
# 438                                                                               button suffici
# 439    test latest master version problem persistson window x java dev window x java step rep...
# 440    qualiti find duplic mark differ chapter book duplic see attach exampl dev snapshot mas...
# 441                search mode old version activ mode indict use differ color magnifi stay black
# 442                            definit store databas portabl anoth user open convert entri other
# 443    seem offer second kind xml serial bibtex xmlns bibtex worth keep differ xml schema xml...
# 444    add cleanup oper replac unicod ligatur charact normal expand form ie fi charact sinc h...
# 445    versionjabref mac os x x java surpris file abbrvjabreforg rewritten randomis order hap...
# 446                                 version beta menu bar includ main window fix mac os menu bar
# 447    notic architectur test current cover static import therefor miss least depend want for...
# 448    press matter point take care moment current main toolbar look like ubuntu img thing no...
# 449    sure inde problem suspect issu introduc made fx applic initi confirm dialog want load ...
# 450    tri test koppor might actual use add miss key languag file javafx applic thread error ...
# 451    test latest master version problem persistsjabref dev snapshot master bb dlinux generi...
# 452    test latest master version problem persistsrec masterstep reproduc creat entri go gene...
# 453    test latest master version problem persistsjabref dev snapshot master bb dlinux generi...
# 454    test latest master version problem persistsjabref dev snapshot master bb dlinux generi...
# 455    test latest master version problem persistsvers linux generic amd java step reproduc o...
# 456    offer search mode normal search grammar base advanc search see initi search normal sea...
# 457    hello communiti jabreftobia diez suggest write problem thread help forum couldnt solv ...
# 458    version window often switch union intersect mode pleas return abil quick switch set ex...
# 459    test latest master dev persistingjabref version window java x version updat step repro...
# 460                        full text document download fail indic fail download access url found
# 461    search minut chang extern applic push emac vim final found drop next tool bar buttonpl...
# 462    system ubuntu linux version generic buildd lgw gcc version ubuntu ubuntu ubuntu smp fr...
# 463    version window often switch union intersect mode pleas return abil quick switch set ex...
# 464                                          look screenshot user imagesentcom e ecc e dc e dpng
# 465    deactiv test travi notic failright lot actual broken think good situat awar thisthi ma...
# 466    issu ieee full text importeri test latest master version window follow problem encount...
# 467    issu ieee full text importeri test latest master version window follow problem encount...
# 468    qualiti find unlink file handi use discov old bib file unlink pdfshowev unlink file mo...
# 469    current refer preview without field month shown follow bib compil correct follow month...
# 470    current refer preview without field month shown follow bib compil correct follow month...
# 471    rfcs doi doi import correspond real bibtex dataimplement total easi add rfc number url...
# 472    version window select item contextu menu copi export clipboard noth happen tri differ ...
# 473    test latest master version problem persistsjabref version step reproduc java jar jarim...
# 474    step reproduc open file import new librari choos file click open freezessam thing happ...
# 475                                     followup tooltip url column activ display sensibl messag
# 476    test latest master version problem persistsjabref version fedora step reproduc add cus...
# 477    linux arch amd java step reproduc new entryctrl n id type titleid ultralumin starburst...
# 478    tri fetch entri acm seem test latest master version problem persistsjabref version dev...
# 479    would realli nice includ ssl support share databas functionup ssl encrypt communic tun...
# 480    use sanit bibfil automat use jenkin newer releas work cli test latest master version p...
# 481    option prefer bibtex key generatori check overwrit box bib entri key still overwritten...
# 482    hijabref version maco high sierra java test step reproduc launch texstudio select bibl...
# 483    entri editor open experi constant high load jabrefthi need evalu fix close entri edito...
# 484    test latest master version problem persistsjabref version ubuntu step reproduc open en...
# 485    current use last open directori open file possibl fire action open file start director...
# 486    test latest master version problem persistsjabref dev snapshot master ee window amd ja...
# 487    sure problem introduc singl word journal titl show orang alert triangl incorrect forma...
# 488    im clean entri link pdf move file field pdf field afterward longer open direct version...
# 489    quit ugli first startup maintabl beta version wont memor modif either modifi size bett...
# 490    keyword shortcut short cut keybind key bind hotkey hot keyjabref dev window amd java s...
# 491    found relat articl relat articl tab contain special charact render correct see screens...
# 492    dev snapshot master dd b window amd java test latest master version problem persistsst...
# 493    lc briand morasca vr basili space dot miss firstnamesalso remov dot end warn messag na...
# ...
# Pandas(Index=15, date_time='2021-02-25 04:45:55.283119', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1843575418994413, Accuracy_Score_not_normalized=33, zero_one_loss=0.8156424581005587, _10=0.7808555762098358, hamming_loss_avg=0.14990689013035385, Jaccard_samples=0.5441872838520883, Jaccard_macro=0.5706666666666667, Precision=0.7495621716287215, Recall=0.7051070840197694, Fmeasure_Score=0.7266553480475383, i=4)
# Pandas(Index=16, date_time='2021-02-25 04:45:57.351852', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2346368715083799, Accuracy_Score_not_normalized=42, zero_one_loss=0.7653631284916201, _10=0.7880136907907442, hamming_loss_avg=0.13640595903165734, Jaccard_samples=0.5926443202979516, Jaccard_macro=0.6164921465968587, Precision=0.7572347266881029, Recall=0.7683523654159871, Fmeasure_Score=0.7627530364372469, i=5)
# Pandas(Index=17, date_time='2021-02-25 04:45:59.414635', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.21787709497206706, Accuracy_Score_not_normalized=39, zero_one_loss=0.782122905027933, _10=0.8033488945970754, hamming_loss_avg=0.13687150837988826, Jaccard_samples=0.5875831338121841, Jaccard_macro=0.6131578947368421, Precision=0.7702479338842976, Recall=0.7504025764895329, Fmeasure_Score=0.7601957585644373, i=6)
# Pandas(Index=18, date_time='2021-02-25 04:46:01.471327', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2681564245810056, Accuracy_Score_not_normalized=48, zero_one_loss=0.7318435754189945, _10=0.8002241205737297, hamming_loss_avg=0.1424581005586592, Jaccard_samples=0.5848962490023942, Jaccard_macro=0.6061776061776062, Precision=0.7633711507293355, Recall=0.7464342313787639, Fmeasure_Score=0.7548076923076923, i=7)
# Accuracy Score
# 0.2346368715083799
# ---------
#
# Accuracy Score not normalized
# 42
# ---------
#
# zero_one_loss
# 0.7653631284916201
# ---------
#
# Fmeasure Score
# 0.7535999999999999
# ---------
#
# AUC-PR
# 0.8261420192952649
# ---------
#
# hamming loss average
# 0.14338919925512103
# ---------
#
# Jaccard samples
# 0.5854659927285626
# ---------
#
# Jaccard macro
# 0.6046213093709885
# ---------
#
# Average precision score, micro-averaged over all classes: 0.83
# 0
# Google Common
# Google Common,117
# Google Common,117,5
# Google Common,117,5,32
# Google Common,117,5,32,25
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25']
# 1
# Test
# Test,111
# Test,111,9
# Test,111,9,39
# Test,111,9,39,20
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20']
# 2
# SO
# SO,156
# SO,156,2
# SO,156,2,9
# SO,156,2,9,12
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20', 'SO,156,2,9,12']
# 3
# IO
# IO,2
# IO,2,35
# IO,2,35,7
# IO,2,35,7,135
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20', 'SO,156,2,9,12', 'IO,2,35,7,135']
# 4
# UI
# UI,30
# UI,30,33
# UI,30,33,11
# UI,30,33,11,105
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20', 'SO,156,2,9,12', 'IO,2,35,7,135', 'UI,30,33,11,105']
# 5
# Network
# Network,104
# Network,104,9
# Network,104,9,34
# Network,104,9,34,32
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20', 'SO,156,2,9,12', 'IO,2,35,7,135', 'UI,30,33,11,105', 'Network,104,9,34,32']
# 6
# Security
# Security,162
# Security,162,3
# Security,162,3,8
# Security,162,3,8,6
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20', 'SO,156,2,9,12', 'IO,2,35,7,135', 'UI,30,33,11,105', 'Network,104,9,34,32', 'Security,162,3,8,6']
# 7
# OpenOffice Documents
# OpenOffice Documents,169
# OpenOffice Documents,169,4
# OpenOffice Documents,169,4,2
# OpenOffice Documents,169,4,2,4
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20', 'SO,156,2,9,12', 'IO,2,35,7,135', 'UI,30,33,11,105', 'Network,104,9,34,32', 'Security,162,3,8,6', 'OpenOffice Documents,169,4,2,4']
# 8
# Database
# Database,162
# Database,162,2
# Database,162,2,4
# Database,162,2,4,11
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20', 'SO,156,2,9,12', 'IO,2,35,7,135', 'UI,30,33,11,105', 'Network,104,9,34,32', 'Security,162,3,8,6', 'OpenOffice Documents,169,4,2,4', 'Database,162,2,4,11']
# 9
# PDF
# PDF,168
# PDF,168,2
# PDF,168,2,1
# PDF,168,2,1,8
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20', 'SO,156,2,9,12', 'IO,2,35,7,135', 'UI,30,33,11,105', 'Network,104,9,34,32', 'Security,162,3,8,6', 'OpenOffice Documents,169,4,2,4', 'Database,162,2,4,11', 'PDF,168,2,1,8']
# 10
# Logging
# Logging,19
# Logging,19,44
# Logging,19,44,9
# Logging,19,44,9,107
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20', 'SO,156,2,9,12', 'IO,2,35,7,135', 'UI,30,33,11,105', 'Network,104,9,34,32', 'Security,162,3,8,6', 'OpenOffice Documents,169,4,2,4', 'Database,162,2,4,11', 'PDF,168,2,1,8', 'Logging,19,44,9,107']
# 11
# Latex
# Latex,169
# Latex,169,1
# Latex,169,1,3
# Latex,169,1,3,6
# ['Label, TN, FP, FN, TP', 'Google Common,117,5,32,25', 'Test,111,9,39,20', 'SO,156,2,9,12', 'IO,2,35,7,135', 'UI,30,33,11,105', 'Network,104,9,34,32', 'Security,162,3,8,6', 'OpenOffice Documents,169,4,2,4', 'Database,162,2,4,11', 'PDF,168,2,1,8', 'Logging,19,44,9,107', 'Latex,169,1,3,6']
#    Accuracy  Acc-Score  zero_one_loss    AUC-PR  hamming loss average  \
# 0  0.234637         42       0.765363  0.826142              0.143389
#
#    Jaccard samples  Jaccard macro  Precision    Recall  Fmeasure
# 0         0.585466       0.604621   0.759677  0.747619    0.7536
# ---------
#
#
#
#                 Google Common       Test         SO          IO          UI  \
# precision            0.833333   0.689655   0.857143    0.794118    0.760870
# recall               0.438596   0.338983   0.571429    0.950704    0.905172
# f-measure            0.574713   0.454545   0.685714    0.865385    0.826772
# samples_tested      57.000000  59.000000  21.000000  142.000000  116.000000
#
#                   Network   Security  OpenOffice Documents   Database  \
# precision        0.780488   0.666667              0.500000   0.846154
# recall           0.484848   0.428571              0.666667   0.733333
# f-measure        0.598131   0.521739              0.571429   0.785714
# samples_tested  66.000000  14.000000              6.000000  15.000000
#
#                      PDF     Logging     Latex
# precision       0.800000    0.708609  0.857143
# recall          0.888889    0.922414  0.666667
# f-measure       0.842105    0.801498  0.750000
# samples_tested  9.000000  116.000000  9.000000
# ---------
#
# ['tf-IDFMin, tf-IDFMax, #_TopTerms,Stop_Word,Train/Test_Size,Algorithm,Accuracy_Score,Accuracy_Score_not_normalized,zero_one_loss, AUC-PR,hamming_loss_avg,Jaccard_samples,Jaccard_macro,Precision,Recall,Fmeasure_Score, i', '(1, 1),895,Yes,0.2,RandomForest,0.2346368715083799,42,0.7653631284916201,0.8261420192952649,0.14338919925512103,0.5854659927285626,0.6046213093709885,0.7596774193548387,0.7476190476190476,0.7535999999999999,9']
# Current date and time :
# 2021-02-25 04:46:05
# tupla: (datetime.datetime(2021, 2, 25, 4, 46, 5, 578701), '(1, 1)', '895', 'Yes', '0.2', 'RandomForest', '0.2346368715083799', '42', '0.7653631284916201', '0.8261420192952649', '0.14338919925512103', '0.5854659927285626', '0.6046213093709885', '0.7596774193548387', '0.7476190476190476', '0.7535999999999999', '9')
# 17
# Pandas(Index=0, date_time='17:48.0', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.24581005600000005, Accuracy_Score_not_normalized=44, zero_one_loss=0.7541899440000001, _10=0.7943695340000001, hamming_loss_avg=0.141061453, Jaccard_samples=0.605823801, Jaccard_macro=0.617424242, Precision=0.760497667, Recall=0.76645768, Fmeasure_Score=0.763466042, i=0)
# Pandas(Index=1, date_time='22:23.5', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.223463687, Accuracy_Score_not_normalized=40, zero_one_loss=0.7765363129999999, _10=0.792715543, hamming_loss_avg=0.141061453, Jaccard_samples=0.605458012, Jaccard_macro=0.618387909, Precision=0.758887172, Recall=0.7695924759999999, Fmeasure_Score=0.764202335, i=1)
# Pandas(Index=2, date_time='28:15.5', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.229050279, Accuracy_Score_not_normalized=41, zero_one_loss=0.7709497209999999, _10=0.7918318040000001, hamming_loss_avg=0.138268156, Jaccard_samples=0.610621176, Jaccard_macro=0.622137405, Precision=0.7676609109999999, Recall=0.76645768, Fmeasure_Score=0.767058824, i=2)
# Pandas(Index=3, date_time='29:41.2', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.24581005600000005, Accuracy_Score_not_normalized=44, zero_one_loss=0.7541899440000001, _10=0.78443448, hamming_loss_avg=0.14152700199999999, Jaccard_samples=0.5995189320000001, Jaccard_macro=0.615676359, Precision=0.7609375, Recall=0.763322884, Fmeasure_Score=0.7621283259999999, i=3)
# Pandas(Index=4, date_time='31:05.8', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.21229050300000002, Accuracy_Score_not_normalized=38, zero_one_loss=0.787709497, _10=0.7954888840000001, hamming_loss_avg=0.141061453, Jaccard_samples=0.603828589, Jaccard_macro=0.614993647, Precision=0.7646129540000001, Recall=0.75862069, Fmeasure_Score=0.761605035, i=4)
# Pandas(Index=5, date_time='32:22.2', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.234636872, Accuracy_Score_not_normalized=42, zero_one_loss=0.765363128, _10=0.789154991, hamming_loss_avg=0.136871508, Jaccard_samples=0.6150815820000001, Jaccard_macro=0.627376426, Precision=0.76625387, Recall=0.7758620690000001, Fmeasure_Score=0.771028037, i=5)
# Pandas(Index=6, date_time='33:18.3', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.223463687, Accuracy_Score_not_normalized=40, zero_one_loss=0.7765363129999999, _10=0.79144104, hamming_loss_avg=0.140130354, Jaccard_samples=0.602099406, Jaccard_macro=0.617048346, Precision=0.766192733, Recall=0.7601880879999999, Fmeasure_Score=0.7631786, i=6)
# Pandas(Index=7, date_time='34:39.8', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.217877095, Accuracy_Score_not_normalized=39, zero_one_loss=0.782122905, _10=0.798414775, hamming_loss_avg=0.135009311, Jaccard_samples=0.60245411, Jaccard_macro=0.62962963, Precision=0.772727273, Recall=0.772727273, Fmeasure_Score=0.772727273, i=7)
# Pandas(Index=8, date_time='36:03.8', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.21229050300000002, Accuracy_Score_not_normalized=38, zero_one_loss=0.787709497, _10=0.793255789, hamming_loss_avg=0.140595903, Jaccard_samples=0.599314977, Jaccard_macro=0.6177215189999999, Precision=0.7625, Recall=0.764890282, Fmeasure_Score=0.763693271, i=8)
# Pandas(Index=9, date_time='37:00.3', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.223463687, Accuracy_Score_not_normalized=40, zero_one_loss=0.7765363129999999, _10=0.795832744, hamming_loss_avg=0.140130354, Jaccard_samples=0.605806065, Jaccard_macro=0.618987342, Precision=0.762870515, Recall=0.76645768, Fmeasure_Score=0.764659891, i=9)
# Pandas(Index=10, date_time='2021-02-25 04:40:11.375705', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.25139664804469275, Accuracy_Score_not_normalized=45, zero_one_loss=0.7486033519553073, _10=0.8040590783797035, hamming_loss_avg=0.14338919925512106, Jaccard_samples=0.6045424314977388, Jaccard_macro=0.6178660049627791, Precision=0.7466266866566716, Recall=0.7817896389324961, Fmeasure_Score=0.7638036809815951, i=0)
# Pandas(Index=11, date_time='2021-02-25 04:45:47.151441', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.223463687150838, Accuracy_Score_not_normalized=40, zero_one_loss=0.7765363128491619, _10=0.8169539153338261, hamming_loss_avg=0.14013035381750466, Jaccard_samples=0.6110933758978452, Jaccard_macro=0.623279098873592, Precision=0.7661538461538462, Recall=0.7697063369397218, Fmeasure_Score=0.7679259830377796, i=0)
# Pandas(Index=12, date_time='2021-02-25 04:45:49.169545', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1843575418994413, Accuracy_Score_not_normalized=33, zero_one_loss=0.8156424581005587, _10=0.7727554396294585, hamming_loss_avg=0.15595903165735567, Jaccard_samples=0.547375188436641, Jaccard_macro=0.5521390374331551, Precision=0.7309734513274336, Recall=0.6929530201342282, Fmeasure_Score=0.7114556416881997, i=1)
# Pandas(Index=13, date_time='2021-02-25 04:45:51.231438', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2402234636871509, Accuracy_Score_not_normalized=43, zero_one_loss=0.7597765363128491, _10=0.7988190035316733, hamming_loss_avg=0.13640595903165734, Jaccard_samples=0.5914627117141084, Jaccard_macro=0.6029810298102981, Precision=0.7478991596638656, Recall=0.7568027210884354, Fmeasure_Score=0.7523245984784447, i=2)
# Pandas(Index=14, date_time='2021-02-25 04:45:53.268340', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.19553072625698328, Accuracy_Score_not_normalized=35, zero_one_loss=0.8044692737430168, _10=0.7751053078440506, hamming_loss_avg=0.14478584729981378, Jaccard_samples=0.563241553604682, Jaccard_macro=0.5907894736842105, Precision=0.7265372168284789, Recall=0.7597292724196277, Fmeasure_Score=0.7427626137303558, i=3)
# Pandas(Index=15, date_time='2021-02-25 04:45:55.283119', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.1843575418994413, Accuracy_Score_not_normalized=33, zero_one_loss=0.8156424581005587, _10=0.7808555762098358, hamming_loss_avg=0.14990689013035385, Jaccard_samples=0.5441872838520883, Jaccard_macro=0.5706666666666667, Precision=0.7495621716287215, Recall=0.7051070840197694, Fmeasure_Score=0.7266553480475383, i=4)
# Pandas(Index=16, date_time='2021-02-25 04:45:57.351852', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2346368715083799, Accuracy_Score_not_normalized=42, zero_one_loss=0.7653631284916201, _10=0.7880136907907442, hamming_loss_avg=0.13640595903165734, Jaccard_samples=0.5926443202979516, Jaccard_macro=0.6164921465968587, Precision=0.7572347266881029, Recall=0.7683523654159871, Fmeasure_Score=0.7627530364372469, i=5)
# Pandas(Index=17, date_time='2021-02-25 04:45:59.414635', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.21787709497206706, Accuracy_Score_not_normalized=39, zero_one_loss=0.782122905027933, _10=0.8033488945970754, hamming_loss_avg=0.13687150837988826, Jaccard_samples=0.5875831338121841, Jaccard_macro=0.6131578947368421, Precision=0.7702479338842976, Recall=0.7504025764895329, Fmeasure_Score=0.7601957585644373, i=6)
# Pandas(Index=18, date_time='2021-02-25 04:46:01.471327', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2681564245810056, Accuracy_Score_not_normalized=48, zero_one_loss=0.7318435754189945, _10=0.8002241205737297, hamming_loss_avg=0.1424581005586592, Jaccard_samples=0.5848962490023942, Jaccard_macro=0.6061776061776062, Precision=0.7633711507293355, Recall=0.7464342313787639, Fmeasure_Score=0.7548076923076923, i=7)
# Pandas(Index=19, date_time='2021-02-25 04:46:03.623575', _2='(1, 1)', _3=895, Stop_Word='Yes', _5=0.2, Algorithm='RandomForest', Accuracy_Score=0.2290502793296089, Accuracy_Score_not_normalized=41, zero_one_loss=0.770949720670391, _10=0.7880792059495231, hamming_loss_avg=0.14851024208566108, Jaccard_samples=0.5617185421654695, Jaccard_macro=0.5851755526657998, Precision=0.7512520868113522, Recall=0.7258064516129032, Fmeasure_Score=0.7383100902379001, i=8)
